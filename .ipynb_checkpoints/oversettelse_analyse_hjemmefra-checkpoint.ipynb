# %% [markdown]
# ## Preamble
#
# Run these if notebook is in a new environment, otherwise just skip to `Import modules`

# %% [markdown]
# #### Boot cell
#
# Skip if `module_update.py` is in same folder as notebook, next cell downloads this file which in turn will download other files.

# %%
from dhlab.module_update import update, css

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
update('collocations')
# Out:
# Updated file `D:\Documents\GitHub\Oversettelse\collocations.py`

# %%
from collocations import dist_coll_urn

# %% [markdown]
# # Import modules
#
# Aktiver cellen nedenfor for å få alt til å virke.

# %%
import dhlab.nbtext as nb
from IPython.display import HTML
import requests
from bs4 import BeautifulSoup
import pandas as pd

def mods_digibok(urn, kind='marcxml'):
    """find information about serial number urn (or full urn) for books using NB API. 
    Parameter 'kind' is one of mods, marcxml or dublincore """
    
    if not str(urn).startswith('URN'):
        urnstr = "URN:NBN:no-nb_digibok_{urn}".format(urn=urn)
    r = requests.get("https://api.nb.no:443/catalog/v1/metadata/{ident}/{kind}".format(ident=urnstr, kind=kind))
    return r.text

def translator(urn):
    """Finds the translator for a book"""
    item = BeautifulSoup(mods_digibok(urn, kind='mods'), 'lxml')
    trans = []
    navn = item.find_all('name', {'type':'personal'})
    for i in navn:

        try:
            if i.roleterm.text == 'trl':
                trans.append(i.namepart.text)
        except:
            'nn'
    return ';'.join(trans)

# %% [markdown]
# ## Build corpus
#
# A corpus definition is a set of URNs. Those can be obtained in various ways and stored as text or in MS-Word file.

# %% [markdown]
# ### Define using metadata
#
# Lag korpus manuelt, fra excel eller andre kilder. Bare lim inn definisjonen mellom de triple """ """ under

# %%
korpus = nb.pure_urn("""
 .... lim inn URNer for korpusdefinisjon her som ren tekst ....
																
																
																
			Rammeverk:													
			-          Ikke nynorsk													
			-          1945 – 1955 og etter 2000													
			-          50 bøker i hver? – spørsmål til Lars. 100 i hver? 													
																
			-          Første oversettelse skal tas med, og den skal være publisert i de gitte periodene. 													
																
			            - Bøker som inneholder flere fortellinger har blitt utelatt. Kun hele romaner													
			            - En spredning på år og forfatter er forsøkt 													
			-          Ta notater på bøker som er oversatt to ganger – bare se på forskjellige oversettere – bare for å ha en liste 													
																
																
																
																
	Urn	Forfatter	Oversetter	År	Tittel	Forlag	Fra	Ord								
	2007012601009	Priestley, J.B.	Gjesdahl, Paul	1945	Mørklagt i Gretley	Aschehoug	eng	97 342,00	Spionroman							
	2007011501001	Han, Suyin	Feydt, Odd	1945	Morgen over Kina	Aschehoug	eng	132 830,00	Fictionalized autobiography							
	2014102708025	Beach, Rex	Grieg-Müller, John.	1945	Hevnerne	Nasjonalforl.	eng	73 671,00	Fiction							
	2012041308131	Norris, Frank	Skjønhaug, Arne.	1945	På eventyr i Stillehavet	Ekko	eng	49 039,00	Eventyrfiksjon							
	2016051148041	Lippincott, Joseph Wharton	Telnæs, Audun H.	1945	Villmarkens champion	Brann	eng	75553	Fiksjon, Ungdom							
	2007013101011	Williams, Valentine	Hopp, Egil Meidell	1945	Som kurér til Marrakesh	Bergendalh	eng	109 496,00	Fiksjon							
								537 931,00								
	2015042008014	Green, F.L.	Hav, Harald	1946	Siste mann ut	Bergendahl	             eng	115 082,00	Mysteriefortelling							
	2012101105071	Shute, Nevil	Toklum, Leif	1946	Livet og leken		eng	110 923,00	Fiksjon							
	2012111406019	Hemingway, Ernest	Gauguin, Paul	1946	Klokkene ringer for deg		eng	206 238,00	Krigsfortelling							
	2007020101046	Lewis, C.S.	Mannsåker, Randi Brun	1946	Djevelen dypper pennen		eng	37 523,00	Satire, brev, fiksjon							
	2015091406037	Johns, W.E.	Bjerre, Håkon;Braarvig, Hans	1946	Biggles i Spania	Damm	eng	39 119,00	Fiksjon							
	2011111708100	Hilton, James	Brenna, Anna-Cathrine	1946	Tilfeldighetens høst	Nasjonalforl.	eng	115 765,00	Krigsfortelling							
	2016102648133	Laurie-Long, E.	Coucheron, Olaf	1946	Spøkelset på S/S Dunsany	Green	eng	90 090,00	Fiksjon							
	2016020308166	Quentin, Patrick	Egge, Inger Borch.	1946	Døden i sirkus	Cappelen	eng	73 935,00	Fiksjon							
								788 675,00								
	2016010408096	Wilson, Dorothy Clarke	Andersen, Aage Hall.	1947	Broren	Lunde	eng	126597	Religiøs fiksjon							
	2014081508162	Brand, Max	Andresen, Per	1947	Jim Silver rydder opp	Nasjonalforl.	eng	54589	Fiksjon							
	2014102108180	Frank, Pat	Bjørge, Halvor	1947	Herr Adam	Mortensen	eng	99435	Fiksjon							
	2014120908100	Gray, Elisabeth Janet	Erichsen, Eivind.	1947	Sandy	Eide	eng	73 720,00	Kjærlighet, Ungdom							
	2011070606067	Maugham, W. Somerset	Fasting, Kaare	1947	Knivseggen	Gyldendal	eng	141 787,00	Dannelsesroman							
	2007012501047	Wright, Richard	Borgen, Johan	1947	Nigger	Gyldendal	eng	181587	Sosialroman, historisk							
								677 715,00								
	2012061406132	Dickens, Charles	Bjerke, Ejlert	1948	Store forventninger	Dreyer	eng	219 361,00	Dannelsesroman							
	2012061505152	Sinclair, Jo	Wahl, Trygve	1948	Yngste sønn	Tiden	eng	157 317,00	Fiksjon							
	2007012501054	Mason, Richard	Heddeland, Randi	1948	Vinden kan ikke lese	Gyldendal	eng	138 409,00	Krigsfortelling, fiksjon							
	2007060801007	Dickens, Charles	Ramstad, Petrine.	1948	Vesle Nelly		eng	54 104,00								
	2013082708199	Reymond, Dalton S.	Cappelen-Wangen, Else	1948	Skjebner i drift		eng	138 547,00								
	2013121106109	Flavin, Martin	Holmboe, Lotte	1948	Reise i mørke		eng	219 386,00								
	2016051048180	Joyce, James	Brøgger, Niels Chr.	1948	Portrett av kunstneren som ung mann	Mortensen	eng	98 744,00								
	2008042404018	Woolf, Virginia	Magnus, Peter	1948	De dro til fyret	Ernst G. Mortensen	eng	89 722,00								
	2007020701051	Hardy, Thomas	Malling, Liv	1948	Borgermesteren	Mortensen	eng	147 855,00								
	2007020500005	Sinclair, May	Wulfsberg, Camilla	1948	Røde valmuer	Dybwad	eng	29 670,00								
								1 293 115,00								
	2007022701076	Du Bois, William Pène	Johannessen, K. Stahl.;Ronold, Jan Arne;Ronold...	1949	Jorden rundt i ballong	Stabenfeldt	eng	37 075,00								
																
	2014021908080	Westcott, Jan	Wangen, Else Cappelen	1949	Stormfullt hav	Bergendahl	eng	132 113,00								
	2010102506020	Scott, Natalie Anderson	Kvam, Ragnar	1949	Mrs. Murphy		eng	217 088,00								
	2016041448248	Robbins, Harold	Johnssen, Arne	1949	Verden er min fiende		eng	186 084,00								
	2010102906108	Cain, James M.	Monrad, Knut	1949	Nattsvermeren	Høvik	eng	148 397,00								
	2014030308388	Margetson, Stella	Mossige, Sigrid Munthe	1949	Peters kone		eng	90 707,00								
	2013080608057	Buchan, John	Knudsen, Ranka	1949	De niogtredve trinnene	Aschehoug	eng	49 116,00								
								860 580,00								
	2008042204074	Kipling, Rudyard	Bergh, Kirsten	1950	Lyset som svant	Mortensen	eng	85 888,00								
	2011050420020	Christie, Agatha	Dahl, Fridtjof	1950	Ugler i mosen	Aschehoug	eng	84 889,00								
	2011030422001	Standish, Robert	Tranøy, B. S.	1950	Boomerang		eng	139 051,00								
	2016060848216	Orwell, George	Width, Trygve	1950	1984	Gyldendal	eng	118 115,00								
	2011030220007	Innes, Hammond	Jakobsen, Einar	1950	Blodspor i snøen	Cappelen	eng	77 850,00								
	2007022701074	Spring, Howard	Hoell, Andreas	1950	Til ærens tinde	Gyldendal	eng	313 664,00								
								819 457,00								
	2008042800117	Saville, Malcolm	Hagerup, Anders	1951	Varselsfuglen	Aschehoug	eng	67 952,00								
	2012022908008	Carroll, Lewis	Hopp, Zinken	1951	Gjennom speilet	Eide	eng	38 388,00								
	2016051148001	Twain, Mark	Hagerup, Inger	1951	Prinsen og fattiggutten		eng	51 403,00								
	2008042204160	Lea, Tom	Ørjasæter, Jo	1951	Tyrefekteren fra Guerreras	Dreyer	eng	86 961,00								
	2008042404035	Bristow, Gwen	Olden, Caro	1951	På spor etter lykken	Gyldendal	eng	274 784,00								
								519 488,00								
	2011070805079	Lawrence, D.H.	Strøm, Leo	1952	Lady Chatterleys elsker		eng	170 294,00								
	2011071406026	Forester, C.S.	Thommessen, Gunnar.	1952	Løytnant Hornblower	Aschehoug	eng	102 556,00								
	2013042508017	Lewisohn, Ludwig	Knutsen, Lalli	1952	Don Juan	Bladkompaniet	eng	70 981,00								
	2008050800070	Green, Henry	Lie, Nils	1952	Elskov	Gyldendal	eng	95 456,00								
	2011112308129	Richardson, Henry Handel	Tomtum, Ivar Widerøe	1952	Ungarsk blod		eng	111 335,00								
								550 622,00								
	2008043004049	Cousteau, Jacques-Yves	Braarvig, Hans	1953	Den tause verden	Eide	eng	73 131,00								
	2014101308071	Brown, Fredric	Knutsen, Fridtjof	1953	Statuetten som skrek	Forlagshuset	eng	75 872,00								
	2008051500097	Caine, Hall	Nissen-Drejer, Ruth	1953	Ralph Ray	Ansgar	eng	85 508,00								
	2011070108147	Hammett, Dashiell	Norum, Tryggve	1953	tynne mann	Gyldendal	eng	72 664,00								
	2012020908035	Rooke, Daphne	Prytz, Carl Frederik	1953	Mittie	Tiden	eng	114 062,00								
								421 237,00								
	2007061201007	Von Hagen, Christine	Døscher, Lise.	1954	Elvia i urskogen	Gyldendal	eng	48 537,00								
	2011111808052	McGraw, Eloise Jarvis	Farland, Erik.	1954	Sporet i villmarken	Green	eng	88 507,00								
	2007040201028	Douglas, Lloyd C.	Frodesen, Leiv	1954	Grønt lys	Nasjonalforl.	eng	132 742,00								
	2013042908150	MacDonald, John D.	Gunnufsen, H. Chr.	1954	Syndens sold	Bladkompaniet	eng	69 418,00								
	2014031808130	Bradbury, Ray	Hauge, Eivind	1954	Kom hjem! Kom hjem!	Eide	eng	91 274,00								
								430 478,00								
	2007022701037	Hanley, Gerald	Amlie, Axel	1955	Det store løveåret	Gyldendal	eng	117 455,00								
	2007022301048	Costain, Thomas B.	Gammelgaard, Arthur W.	1955	hellige ild		eng	238 666,00								
	2007020501008	Franken, Rose	Schjelderup, Daisy	1955	Ja til livet		eng	118 036,00								
	2013112708060	Popkin, Zelda	Bommen, Anton	1955	Døden spanderer	Bergendahl	eng	93 337,00								
	2011070710022	Fleming, Ian	Dalen, Erling.	1955	Å leve og la dø	Nasjonalforlaget	eng	76 018,00								
	2013042338078	Frazee, Steve	Faye-Lund, Hans	1955	Kvinnelist	Bladkompaniet	eng	63 363,00								
	2013050208018	Heckelmann, Charles N.	Gleditsch, Ulf	1955	Hevnens legion	Bladkompaniet	eng	63 849,00								
								770 724,00								
																
	Sum							7 670 022,00								

""")
len(korpus)
# Out:
# 70

# %%
korpus_nob = nb.get_urn({
                     'year':1950, 
                     'next':20,
                    'ddk':"839%",
                     'trans':'',
                     'limit':70})
len(korpus_nob)
# Out:
# 70

# %% [markdown]
# # Henter bøkene med ord
#
# Her defineres korpuset som en liste over bøker, med informasjon om oversettere. Er korpuset stort (flere hundre) vil det ta noen minutter å hente alle oversetterne, så det kan være lurt å kutte ned størrelsen litt. Inntil vi får på plass en rask måte å gjøre det på, får det her duge. Det er bare å smøre seg med tålmodighet.

# %% [markdown]
# ## Search corpus for concordances

# %%
from random import sample

# %%
nb.get_urnkonk('leende', {'urns':sample(korpus, 50)})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007022701076?searchText=leende' target='_blank' style='text-decoration:none'>Jorden rundt i ballong, Du Bois, William Pène, 1949</a>
#                 </td>
#                 <td>, » 8 a nnn</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014031808130?searchText=leende' target='_blank' style='text-decoration:none'>Kom hjem! Kom hjem!, Bradbury, Ray, 1954</a>
#                 </td>
#                 <td>menn og to kvinner kom</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>ut fra en bar .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008050800070?searchText=leende' target='_blank' style='text-decoration:none'>Elskov, Green, Henry, 1952</a>
#                 </td>
#                 <td>smuttet unna , mens hun</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>kavet med armene som om</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015042008014?searchText=leende' target='_blank' style='text-decoration:none'>Siste mann ut, Green, F.L., 1946</a>
#                 </td>
#                 <td>. De kom ropende og</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>langs baren . Nye ord</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015091406037?searchText=leende' target='_blank' style='text-decoration:none'>Biggles i Spania, Johns, W.E., 1946</a>
#                 </td>
#                 <td>Mennene ristet</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>på hodet og gikk sin</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007061201007?searchText=leende' target='_blank' style='text-decoration:none'>Elvia i urskogen, Von Hagen, Christine, 1954</a>
#                 </td>
#                 <td>i hodet . Glade og</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>sprang de bortover stien til</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016020308166?searchText=leende' target='_blank' style='text-decoration:none'>Døden i sirkus, Quentin, Patrick, 1946</a>
#                 </td>
#                 <td>Zelide Rose Annapoppaulos ved sin</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>brudgoms arm . Dette var</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016020308166?searchText=leende' target='_blank' style='text-decoration:none'>Døden i sirkus, Quentin, Patrick, 1946</a>
#                 </td>
#                 <td>store mustasjer og to tykke</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>kvinner som utførte det mest</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016020308166?searchText=leende' target='_blank' style='text-decoration:none'>Døden i sirkus, Quentin, Patrick, 1946</a>
#                 </td>
#                 <td>sirkus . Alle elsket denne</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>mørkøyde unge mannen, alle inklusive</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061505152?searchText=leende' target='_blank' style='text-decoration:none'>Yngste sønn, Sinclair, Jo, 1948</a>
#                 </td>
#                 <td>nær , heller ikke det</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>, lette vesenet eller den</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061505152?searchText=leende' target='_blank' style='text-decoration:none'>Yngste sønn, Sinclair, Jo, 1948</a>
#                 </td>
#                 <td>det være ! ropte han</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>og begynte å gjøre i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061505152?searchText=leende' target='_blank' style='text-decoration:none'>Yngste sønn, Sinclair, Jo, 1948</a>
#                 </td>
#                 <td>huset , et levende og</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>liv av hennes liv .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061505152?searchText=leende' target='_blank' style='text-decoration:none'>Yngste sønn, Sinclair, Jo, 1948</a>
#                 </td>
#                 <td>hestene gallopperende forbi med unge</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>menn på ryggen .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061505152?searchText=leende' target='_blank' style='text-decoration:none'>Yngste sønn, Sinclair, Jo, 1948</a>
#                 </td>
#                 <td>lyden , av alle de</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>menneskene som er ute og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011030422001?searchText=leende' target='_blank' style='text-decoration:none'>Boomerang, Standish, Robert, 1950</a>
#                 </td>
#                 <td>, kom en munter ,</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>og pratende flokk av menn</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011030422001?searchText=leende' target='_blank' style='text-decoration:none'>Boomerang, Standish, Robert, 1950</a>
#                 </td>
#                 <td>skarlagen , arbeidet kvinnene seg</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>bort fra hinannen , for</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011030422001?searchText=leende' target='_blank' style='text-decoration:none'>Boomerang, Standish, Robert, 1950</a>
#                 </td>
#                 <td>seg et øyeblikk etter ,</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>som to ungdommelige sammensvorne ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016041448248?searchText=leende' target='_blank' style='text-decoration:none'>Verden er min fiende, Robbins, Harold, 1949</a>
#                 </td>
#                 <td>skyld , » svarte han</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016041448248?searchText=leende' target='_blank' style='text-decoration:none'>Verden er min fiende, Robbins, Harold, 1949</a>
#                 </td>
#                 <td>snau , » medga jeg</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016041448248?searchText=leende' target='_blank' style='text-decoration:none'>Verden er min fiende, Robbins, Harold, 1

# %%
nb.get_urnkonk('leende', {'urns':sample(korpus_nob, 50)})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014072808161?searchText=leende' target='_blank' style='text-decoration:none'>Menneskejegerne, Frich, Øvre Richter, 1967</a>
#                 </td>
#                 <td>den alderstegne genteman , som</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>slang ned over gaten .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011120108026?searchText=leende' target='_blank' style='text-decoration:none'>Norske kjærlighetsdikt, , 1957</a>
#                 </td>
#                 <td>og gripe vildt i en</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>luft efter rosens røde sjæl</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011120108026?searchText=leende' target='_blank' style='text-decoration:none'>Norske kjærlighetsdikt, , 1957</a>
#                 </td>
#                 <td>i hans armer , forst</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>, så sky , sa</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008052204104?searchText=leende' target='_blank' style='text-decoration:none'>Kefir og chianti, Eidem, Odd, 1968</a>
#                 </td>
#                 <td>, og han holdt en</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>tale om bomber . «</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007032701062?searchText=leende' target='_blank' style='text-decoration:none'>Min ungdom var en annens, Rud, Nils Johan, 1963</a>
#                 </td>
#                 <td>tarten utentor et kotell mcci</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>Bkilt , Fikk lanF- Bomt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007050401073?searchText=leende' target='_blank' style='text-decoration:none'>Norsk lyrikk fra 1890 til i dag, , 1969</a>
#                 </td>
#                 <td>Da ropte lian</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>: lure — lure !</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007050401073?searchText=leende' target='_blank' style='text-decoration:none'>Norsk lyrikk fra 1890 til i dag, , 1969</a>
#                 </td>
#                 <td>indande alt dette milde ,</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>de levende BSndenvindBdraZ , se</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007050401073?searchText=leende' target='_blank' style='text-decoration:none'>Norsk lyrikk fra 1890 til i dag, , 1969</a>
#                 </td>
#                 <td>, menn og kvinner går</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>til arbeid ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007050401073?searchText=leende' target='_blank' style='text-decoration:none'>Norsk lyrikk fra 1890 til i dag, , 1969</a>
#                 </td>
#                 <td>av de dødes tegn ,</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>, lik hin avsindige hvis</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012102208044?searchText=leende' target='_blank' style='text-decoration:none'>Om det finnes en stillhet, Abrahamsen, Odd, 1962</a>
#                 </td>
#                 <td>regnet , noen barn løper</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>hjem , bare arbeiderne i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007051501031?searchText=leende' target='_blank' style='text-decoration:none'>Ballade i moll, Berg, Bjørg, 1968</a>
#                 </td>
#                 <td>små klynger , pratende og</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>, eller en og en</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007051501031?searchText=leende' target='_blank' style='text-decoration:none'>Ballade i moll, Berg, Bjørg, 1968</a>
#                 </td>
#                 <td>8 a plutBeliF. Lettet oz</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>tant de BeF Belv iF</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060701036?searchText=leende' target='_blank' style='text-decoration:none'>Velsignelsens arvtakere, Skrøvseth, Signe, 1956</a>
#                 </td>
#                 <td>del ! » utbrot ktav</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>, klen jeg ga meg</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007051604072?searchText=leende' target='_blank' style='text-decoration:none'>Trollkrittet, Hopp, Zinken, 1968</a>
#                 </td>
#                 <td>, dansende , glade og</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>. Og kaffekjelen og skjeene</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007052101034?searchText=leende' target='_blank' style='text-decoration:none'>Essays, Fangen, Ronald, 1965</a>
#                 </td>
#                 <td>Bil6cert at kan er et</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>elcBempel ris . utrettelig arbeidBomket</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007052101034?searchText=leende' target='_blank' style='text-decoration:none'>Essays, Fangen, Ronald, 1965</a>
#                 </td>
#                 <td>dem i ansiktet og gikk</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>avsted med dem . Det</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006110700014?searchText=leende' target='_blank' style='text-decoration:none'>Løsgjengeren, Olsen, Johanna Bugge, 1963</a>
#                 </td>
#                 <td>unge damen sa og bemerket</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>: - Han kan trenge</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073108067?searchText=leende' target='_blank' style='text-decoration:none'>Terje Viken, den norske los, Øines, Finn, 1966</a>
#                 </td>
#                 <td>menn ut . De gikk</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>oppover gaten .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007050201085?searchText=leende' target='_blank' style='text-decoration:none'>Kometene, Carling, Finn, 1964</a>
#                 </td>
#                 <td>, og den unge ,</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>munnen med de røde leppene</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007050201085?searchText=leende' target='_blank' style='text-decoration:none'>Kometene, Ca

# %% [markdown]
# # Definer teksten

# %% [markdown]
# Hen teksten - kan ta noe minutter. Kan lagres for senere bruk.

# %%
nb.frame(korpus)[0]
# Out:
# 0     2007012601009
# 1     2007011501001
# 2     2014102708025
# 3     2012041308131
# 4     2016051148041
# 5     2007013101011
# 6     2015042008014
# 7     2012101105071
# 8     2012111406019
# 9     2007020101046
# 10    2015091406037
# 11    2011111708100
# 12    2016102648133
# 13    2016020308166
# 14    2016010408096
# 15    2014081508162
# 16    2014102108180
# 17    2014120908100
# 18    2011070606067
# 19    2007012501047
# 20    2012061406132
# 21    2012061505152
# 22    2007012501054
# 23    2007060801007
# 24    2013082708199
# 25    2013121106109
# 26    2016051048180
# 27    2008042404018
# 28    2007020701051
# 29    2007020500005
#           ...
# 40    2016060848216
# 41    2011030220007
# 42    2007022701074
# 43    2008042800117
# 44    2012022908008
# 45    2016051148001
# 46    2008042204160
# 47    2008042404035
# 48    2011070805079
# 49    2011071406026
# 50    2013042508017
# 51    2008050800070
# 52    2011112308129
# 53    2008043004049
# 54    2014101308071
# 55    2008051500097
# 56    2011070108147
# 57    2012020908035
# 58    2007061201007
# 59    2011111808052
# 60    2007040201028
# 61    2013042908150
# 62    2014031808130
# 63    2007022701037
# 64    2007022301048
# 65    2007020501008
# 66    2013112708060
# 67    2011070710022
# 68    2013042338078
# 69    2013050208018
# Name: 0, Length: 70, dtype: object

# %%
#TEXT = nb.get_corpus_text(list(nb.frame(korpus)[0]))

#with open ('korpus_file.csv','w',encoding="utf-8") as f:
    TEXT.to_csv(path_or_buf=f)

#TEXT_NOB = nb.get_corpus_text(list(nb.frame(korpus_nob)[0]))

#with open ('korpus_file_nob.csv','w',encoding="utf-8") as f:
#    TEXT_NOB.to_csv(path_or_buf=f)

# %%
TEXT = pd.read_csv("korpus_file.csv",index_col=0 )

# %%
TEXT_NOB = pd.read_csv('korpus_file_nob.csv', index_col=0)

# %% [markdown]
# #### convertet to md
# import pandas as pd
# with open ('korpus_file.csv','r', encoding="utf-8") as f:
#     text = pd.read_csv(f)

# %%
TEXT.sort_values(by=TEXT.columns[0], ascending=False)[:10]
# Out:
#      2007012601009  2007011501001  2014102708025  2012041308131  \
# .           5119.0         6330.0         4262.0         2732.0
# ,           3527.0         5232.0         3146.0         1855.0
# «           2013.0          370.0         1909.0          117.0
# »           1953.0          581.0         1885.0          119.0
# og          1683.0         3876.0         1844.0         1540.0
# jeg         1657.0          705.0          840.0          266.0
# en          1574.0         2161.0          950.0          689.0
# i           1541.0         2557.0         1131.0          985.0
# 6           1516.0         2273.0            2.0            2.0
# ^           1514.0         1182.0            4.0            2.0
#
#      2016051148041  2007013101011  2015042008014  2012101105071  \
# .           3218.0         6288.0         6811.0         7284.0
# ,           2741.0         3777.0         5739.0         3907.0
# «            372.0          242.0           16.0         2824.0
# »            377.0          158.0           15.0         2798.0
# og          2625.0         1680.0         3392.0         3122.0
# jeg          115.0         1361.0          460.0          789.0
# en           926.0         1744.0         1386.0         1536.0
# i           1294.0         2235.0         2244.0         1805.0
# 6              3.0          604.0            2.0            1.0
# ^             12.0          939.0            1.0            1.0
#
#      2012111406019  2007020101046  ...  2007040201028  2013042908150  \
# .          13751.0         1313.0  ...         5692.0         4223.0
# ,           7524.0         1269.0  ...         4970.0         4268.0
# «            513.0          248.0  ...         2202.0           38.0
# »            496.0          236.0  ...         2143.0           31.0
# og          7468.0          773.0  ...         2592.0         2133.0
# jeg         1692.0          157.0  ...          553.0         1551.0
# en          2228.0          575.0  ...         2074.0         1049.0
# i           3114.0          624.0  ...         2091.0         1030.0
# 6              3.0           52.0  ...         1054.0            1.0
# ^              NaN           74.0  ...         1829.0            1.0
#
#      2014031808130  2007022701037  2007022301048  2007020501008  \
# .           5729.0         6111.0        10654.0         6327.0
# ,           4904.0         4984.0         9318.0         5005.0
# «           2322.0          433.0         4502.0         4164.0
# »           2309.0          483.0         4201.0         3948.0
# og          3194.0         3066.0         5199.0         1842.0
# jeg          565.0          547.0         1576.0          819.0
# en          1195.0         1928.0         3274.0         1184.0
# i           1681.0         1863.0         3966.0         1568.0
# 6              4.0         1325.0         1941.0         1108.0
# ^              2.0          848.0         4363.0         1998.0
#
#      2013112708060  2011070710022  2013042338078  2013050208018
# .           7132.0         4732.0         4091.0         3498.0
# ,           3500.0         2801.0         2476.0         2182.0
# «           2517.0         1080.0         1442.0           26.0
# »           2487.0         1037.0         1413.0           24.0
# og          1800.0         2442.0         1521.0         1818.0
# jeg          703.0          307.0          286.0          312.0
# en          1282.0         1188.0          955.0          911.0
# i           1449.0         1535.0          986.0         1291.0
# 6              2.0            3.0            4.0            1.0
# ^              NaN            1.0            4.0           14.0
#
# [10 rows x 70 columns]

# %% [markdown]
# ### Starter med listen over mulige partisipper

# %%
TEXT.index = TEXT.index.map(str)

# %%
poss_part = list ({x for x in TEXT.index if x.endswith('ende')})

# %%
TEXT.index
# Out:
# Index([' Akkurat', ' Belønningen', ' Deriblant', ' Donimer', ' Etter',
#        ' Forresten', ' Frosty', ' Holland,', ' Hvorledes', ' Kanskje',
#        ...
#        '„', '•', '€', '™', '■', '►', '▼', '♦', '✓', '❖'],
#       dtype='object', length=226376)

# %% [markdown]
# ### Henter ut de 100 mest frekvente

# %%
N = 100
test_words = list(TEXT.loc[TEXT.index.str.contains(".*ende")].sum(axis=1).sort_values(ascending=False)[:N].index)

# %%
variants = dict()
for w in test_words:
    variants[w] = nb.word_paradigm(w)

# %%
forms = dict()
for w in test_words:
    forms[w] = nb.word_form(w)

# %%
nb.frame(variants)
# Out:
#                                                                 0  \
# hendene         [subs, [henda, hende, hendene, hender, hendet,...
# stående                           [adj, [stående, stått, ståtte]]
# hender                           [adj, [hendende, hendt, hendte]]
# endelig         [adj, [endelig, endelige, endeligere, endeligs...
# hende                     [adj, [hendende, hendt, hendte, hende]]
# levende         [adj, [levd, levde, levede, levende, levet, le...
# sende                            [adj, [sendende, sendt, sendte]]
# enden                        [subs, [ende, enden, endene, ender]]
# rasende                       [adj, [rasa, rasende, rast, raste]]
# sittende                 [adj, [sitne, sitten, sittende, sittet]]
# ende                                [adj, [endende, endt, endte]]
# strålende                     [adj, [strålende, strålt, strålte]]
# liggende                 [adj, [liggen, liggende, ligget, ligne]]
# smilende                         [adj, [smilende, smilt, smilte]]
# vende                            [adj, [vendende, vendt, vendte]]
# skjelvende      [adj, [skjelven, skjelvende, skjelvet, skjelvne]]
# skinnende                       [adj, [skinnende, skint, skinte]]
# brennende                       [adj, [brennende, brent, brente]]
# utseende                       [adj, [utseende, utsett, utsette]]
# spennende                       [adj, [spennende, spent, spente]]
# gående                               [adj, [gående, gått, gåtte]]
# uendelig        [adj, [uendelig, uendelige, uendeligere, uende...
# hengende                         [adj, [hengende, hengt, hengte]]
# truende         [adj, [trudd, trudde, truende, trua, truede, t...
# løpende                      [adj, [løpende, løpet, løpt, løpte]]
# passende        [adj, [passa, passede, passende, passet, passe...
# sender                           [adj, [sendende, sendt, sendte]]
# tilsynelatende                            [adj, [tilsynelatende]]
# lignende        [adj, [ligna, lignede, lignende, lignet, ligne...
# triumferende         [adj, [triumferende, triumfert, triumferte]]
# ...                                                           ...
# irriterende             [adj, [irriterende, irritert, irriterte]]
# advarende                     [adj, [advarende, advart, advarte]]
# avgjørende                 [adj, [avgjort, avgjorte, avgjørende]]
# tiltalende        [adj, [tiltala, tiltalende, tiltalt, tiltalte]]
# overveldende    [adj, [overvelda, overveldede, overveldende, o...
# sovende                     [adj, [soven, sovende, sovet, sovne]]
# nåværende                                      [adj, [nåværende]]
# leende          [adj, [ledd, ledde, leende, lea, leede, leet, ...
# medfølende                                                   None
# trykkende       [adj, [trykka, trykkede, trykkende, trykket, t...
# bølgende        [adj, [bølga, bølgede, bølgende, bølget, bølge...
# tiltrekkende    [adj, [tiltrekkende, tiltrukken, tiltrukket, t...
# angående                       [adj, [angående, angått, angåtte]]
# styrtende       [adj, [styrta, styrtede, styrtende, styrtet, s...
# stikkende            [adj, [stikkende, stukken, stukket, stukne]]
# flytende                         [adj, [flytende, flytt, flytte]]
# middelaldrende                            [adj, [middelaldrende]]
# hviskende       [adj, [hviska, hviskede, hviskende, hvisket, h...
# påfallende                                    [adj, [påfallende]]
# bydende                [adj, [budt, budte, bydd, bydde, bydende]]
# flakkende       [adj, [flakka, flakkede, flakkende, flakket, f...
# ender                               [adj, [endende, endt, endte]]
# vender                           [adj, [vendende, vendt, vendte]]
# kvelende          [adj, [kvalt, kvalte, kvelende, kvelt, kvelte]]
# attende                                          [adj, [attende]]
# anstrengende         [adj, [anstrengende, anstrengt, anstrengte]]
# tvilende                         [adj, [tvilende, tvilt, tvilte]]
# motstrebende                                [adj, [motstrebende]]
# sjarmerende             [adj, [sjarmerende, sjarmert, sjarmerte]]
# bartenderen     [subs, [bartender, bartendere, bartenderen, ba...
#
#                                                                 1  \
# hendene                                                      None
# stående         [verb, [sto, stod, stå, ståes, står, stås, stå...
# hender          [subs, [henda, hende, hendene, hender, hendet,...
# endelig                                                      None
# hende             [subs, [henda, hende, hendene, hender, hendet]]
# levende         [verb, [lev, levd, levde, leve, lever, leves, ...
# sende           [verb, [send, sende, sender, sendes, sendt, se...
# enden                                                        None
# rasende                                          [adv, [rasende]]
# sittende        [verb, [satt, sitt, sitte, sitter, sittes, sit...
# ende                                                [adv, [ende]]
# strålende       [verb, [strål, stråle, stråler, stråles, strål...
# liggende        [verb, [ligg, ligge, ligger, ligges, ligget, l...
# smilende        [verb, [smil, smile, smiler, smiles, smilt, sm...
# vende             [subs, [venda, vende, venden, vendene, vender]]
# skjelvende      [verb, [skalv, skjelv, skjelve, skjelver, skje...
# skinnende       [verb, [skein, skinn, skinne, skinner, skinnes...
# brennende       [verb, [brenn, brenne, brenner, brennes, brent...
# utseende        [subs, [utseende, utseendene, utseender, utsee...
# spennende       [verb, [spenn, spenne, spenner, spennes, spent...
# gående            [verb, [gikk, gjekk, gå, gåes, går, gås, gått]]
# uendelig                                                     None
# hengende        [verb, [heng, henge, henger, henges, hengt, he...
# truende         [verb, [tru, trudd, trudde, trur, trus, trua, ...
# løpende            [verb, [løp, løpe, løper, løpes, løpet, løpt]]
# passende        [verb, [pass, passa, passe, passer, passes, pa...
# sender          [subs, [sender, sendere, senderen, senderer, s...
# tilsynelatende                                               None
# lignende        [verb, [lign, ligna, ligne, ligner, lignes, li...
# triumferende    [verb, [triumfer, triumfere, triumferer, trium...
# ...                                                           ...
# irriterende     [verb, [irriter, irritere, irriterer, irritere...
# advarende       [verb, [advar, advare, advarer, advares, advar...
# avgjørende      [verb, [avgjorde, avgjort, avgjør, avgjøre, av...
# tiltalende      [verb, [tiltal, tiltala, tiltale, tiltaler, ti...
# overveldende    [verb, [overveld, overvelda, overvelde, overve...
# sovende                  [verb, [sov, sove, sover, soves, sovet]]
# nåværende                                                    None
# leende          [verb, [le, ledd, ler, les, lo, lea, lee, leer...
# medfølende                                                   None
# trykkende       [verb, [trykk, trykka, trykke, trykker, trykke...
# bølgende        [verb, [bølg, bølga, bølge, bølger, bølges, bø...
# tiltrekkende    [verb, [tiltrakk, tiltrekk, tiltrekke, tiltrek...
# angående                                       [prep, [angående]]
# styrtende       [verb, [styrt, styrta, styrte, styrter, styrte...
# stikkende       [verb, [stakk, stikk, stikke, stikker, stikkes...
# flytende        [verb, [flaut, flyt, flyte, flyter, flytes, fl...
# middelaldrende                                               None
# hviskende       [verb, [hvisk, hviska, hviske, hvisker, hviske...
# påfallende                                                   None
# bydende         [verb, [baud, budt, byd, bydd, bydde, byde, by...
# flakkende       [verb, [flakk, flakka, flakke, flakker, flakke...
# ender                                              [adv, [ender]]
# vender          [subs, [venda, vende, venden, vendene, vender,...
# kvelende        [verb, [kvalt, kvalte, kvel, kvele, kveler, kv...
# attende                                         [prep, [attende]]
# anstrengende    [verb, [anstreng, anstrenge, anstrenger, anstr...
# tvilende        [verb, [tvil, tvile, tviler, tviles, tvilt, tv...
# motstrebende                                                 None
# sjarmerende     [verb, [sjarmer, sjarmere, sjarmerer, sjarmere...
# bartenderen                                                  None
#
#                                                                 2  \
# hendene                                                      None
# stående                                                      None
# hender          [verb, [hend, hende, hender, hendes, hendt, he...
# endelig                                                      None
# hende           [verb, [hend, hende, hender, hendes, hendt, he...
# levende                                                      None
# sende                                                        None
# enden                                                        None
# rasende         [verb, [ras, rasa, rase, raser, rases, rast, r...
# sittende                                                     None
# ende                         [subs, [ende, enden, endene, ender]]
# strålende                                                    None
# liggende                                                     None
# smilende                                                     None
# vende           [verb, [vend, vende, vender, vendes, vendt, ve...
# skjelvende                                                   None
# skinnende                                                    None
# brennende                                                    None
# utseende        [verb, [utse, utsees, utser, utses, utsett, ut...
# spennende                                                    None
# gående                                                       None
# uendelig                                                     None
# hengende                                                     None
# truende                                                      None
# løpende                                                      None
# passende                                                     None
# sender          [verb, [send, sende, sender, sendes, sendt, se...
# tilsynelatende                                               None
# lignende                                                     None
# triumferende                                                 None
# ...                                                           ...
# irriterende                                                  None
# advarende                                                    None
# avgjørende                                                   None
# tiltalende                                                   None
# overveldende                                                 None
# sovende                                                      None
# nåværende                                                    None
# leende                                                       None
# medfølende                                                   None
# trykkende                                                    None
# bølgende                                                     None
# tiltrekkende                                                 None
# angående        [verb, [angikk, angjekk, angå, angåes, angår, ...
# styrtende                                                    None
# stikkende                                                    None
# flytende                                                     None
# middelaldrende                                               None
# hviskende                                                    None
# påfallende                                                   None
# bydende                                                      None
# flakkende                                                    None
# ender           [subs, [and, anda, anden, endene, ender, ende,...
# vender          [verb, [vend, vende, vender, vendes, vendt, ve...
# kvelende                                                     None
# attende                                                      None
# anstrengende                                                 None
# tvilende                                                     None
# motstrebende                                                 None
# sjarmerende                                                  None
# bartenderen                                                  None
#
#                                                              3
# hendene                                                   None
# stående                                                   None
# hender                                                    None
# endelig                                                   None
# hende                                                     None
# levende                                                   None
# sende                                                     None
# enden                                                     None
# rasende                                                   None
# sittende                                                  None
# ende            [verb, [end, ende, ender, endes, endt, endte]]
# strålende                                                 None
# liggende                                                  None
# smilende                                                  None
# vende                                                     None
# skjelvende                                                None
# skinnende                                                 None
# brennende                                                 None
# utseende                                                  None
# spennende                                                 None
# gående                                                    None
# uendelig                                                  None
# hengende                                                  None
# truende                                                   None
# løpende                                                   None
# passende                                                  None
# sender                                                    None
# tilsynelatende                                            None
# lignende                                                  None
# triumferende                                              None
# ...                                                        ...
# irriterende                                               None
# advarende                                                 None
# avgjørende                                                None
# tiltalende                                                None
# overveldende                                              None
# sovende                                                   None
# nåværende                                                 None
# leende                                                    None
# medfølende                                                None
# trykkende                                                 None
# bølgende                                                  None
# tiltrekkende                                              None
# angående                                                  None
# styrtende                                                 None
# stikkende                                                 None
# flytende                                                  None
# middelaldrende                                            None
# hviskende                                                 None
# påfallende                                                None
# bydende                                                   None
# flakkende                                                 None
# ender           [verb, [end, ende, ender, endes, endt, endte]]
# vender                                                    None
# kvelende                                                  None
# attende                                                   None
# anstrengende                                              None
# tvilende                                                  None
# motstrebende                                              None
# sjarmerende                                               None
# bartenderen                                               None
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Velg former
#
# Plukk ut partisippformene, dersom formen opptrer både som adjektiv og som verb, ellers ut. Nedenfor plukkes ut de alternative verbformene som kan sammenlignes med partisippen.
#
# Her benyttes en enkelt heuristikk. Partisippformen må være oppført både som et adjektiv og et verb, i tillegg må ikke formen selv være blandt verbene.

# %%
participles = dict()
for w in variants:
    # finn POS for alle variantene
    kinds = [x[0] for x in variants[w]]
    
    # sjekk at både adj og verb er blant dem
    if 'adj' and 'verb' in kinds:
        
        # Ta ut de som har formen blant verbene (partisippet er ikke verd i NO)
        F = [k[1] for k in variants[w] if k[0] == 'verb' and not w in k[1] ]
        if F != []:
            participles[w] = F

# %% [markdown]
# ## Se på resultatet

# %%
participles
# Out:
# {'stående': [['sto', 'stod', 'stå', 'ståes', 'står', 'stås', 'stått']],
#  'levende': [['lev', 'levd', 'levde', 'leve', 'lever', 'leves', 'levet']],
#  'rasende': [['ras', 'rasa', 'rase', 'raser', 'rases', 'rast', 'raste']],
#  'sittende': [['satt', 'sitt', 'sitte', 'sitter', 'sittes', 'sittet']],
#  'strålende': [['strål', 'stråle', 'stråler', 'stråles', 'strålt', 'strålte']],
#  'liggende': [['ligg', 'ligge', 'ligger', 'ligges', 'ligget', 'lå', 'låg']],
#  'smilende': [['smil', 'smile', 'smiler', 'smiles', 'smilt', 'smilte']],
#  'skjelvende': [['skalv',
#    'skjelv',
#    'skjelve',
#    'skjelver',
#    'skjelves',
#    'skjelvet']],
#  'skinnende': [['skein',
#    'skinn',
#    'skinne',
#    'skinner',
#    'skinnes',
#    'skint',
#    'skinte']],
#  'brennende': [['brenn',
#    'brenne',
#    'brenner',
#    'brennes',
#    'brent',
#    'brente',
#    'brann',
#    'brant']],
#  'utseende': [['utse', 'utsees', 'utser', 'utses', 'utsett', 'utså', 'utsåg']],
#  'spennende': [['spenn', 'spenne', 'spenner', 'spennes', 'spent', 'spente']],
#  'gående': [['gikk', 'gjekk', 'gå', 'gåes', 'går', 'gås', 'gått']],
#  'hengende': [['heng',
#    'henge',
#    'henger',
#    'henges',
#    'hengt',
#    'hengte',
#    'hang']],
#  'truende': [['tru',
#    'trudd',
#    'trudde',
#    'trur',
#    'trus',
#    'trua',
#    'true',
#    'truer',
#    'trues',
#    'truet']],
#  'løpende': [['løp', 'løpe', 'løper', 'løpes', 'løpet', 'løpt']],
#  'passende': [['pass', 'passa', 'passe', 'passer', 'passes', 'passet']],
#  'lignende': [['lign', 'ligna', 'ligne', 'ligner', 'lignes', 'lignet']],
#  'triumferende': [['triumfer',
#    'triumfere',
#    'triumferer',
#    'triumferes',
#    'triumfert',
#    'triumferte']],
#  'glimrende': [['glimr', 'glimra', 'glimre', 'glimrer', 'glimres', 'glimret']],
#  'spørrende': [['spurt', 'spurte', 'spør', 'spørre', 'spørres']],
#  'glødende': [['glød',
#    'gløda',
#    'glødd',
#    'glødde',
#    'gløde',
#    'gløder',
#    'glødes',
#    'glødet']],
#  'beroligende': [['berolig',
#    'beroliga',
#    'berolige',
#    'beroliger',
#    'beroliges',
#    'beroliget']],
#  'vedkommende': [['vedkom',
#    'vedkomme',
#    'vedkommer',
#    'vedkommes',
#    'vedkommet']],
#  'lysende': [['lys', 'lyse', 'lyser', 'lyses', 'lyst', 'lyste']],
#  'skremmende': [['skrem',
#    'skremme',
#    'skremmer',
#    'skremmes',
#    'skremt',
#    'skremte']],
#  'gjennomtrengende': [['gjennomtreng',
#    'gjennomtrenge',
#    'gjennomtrenger',
#    'gjennomtrenges',
#    'gjennomtrengt',
#    'gjennomtrengte']],
#  'ertende': [['ert', 'erta', 'erte', 'erter', 'ertes', 'ertet']],
#  'følgende': [['følg',
#    'følgje',
#    'følgjer',
#    'følgjes',
#    'følgt',
#    'følgte',
#    'fulgt',
#    'fulgte',
#    'følge',
#    'følger',
#    'følges']],
#  'imponerende': [['imponer',
#    'imponere',
#    'imponerer',
#    'imponeres',
#    'imponert',
#    'imponerte']],
#  'oppmuntrende': [['oppmuntr',
#    'oppmuntra',
#    'oppmuntre',
#    'oppmuntrer',
#    'oppmuntres',
#    'oppmuntret']],
#  'undersøkende': [['undersøk',
#    'undersøke',
#    'undersøker',
#    'undersøkes',
#    'undersøkt',
#    'undersøkte']],
#  'bebreidende': [['bebreid',
#    'bebreida',
#    'bebreide',
#    'bebreider',
#    'bebreides',
#    'bebreidet']],
#  'forbausende': [['forbaus',
#    'forbausa',
#    'forbause',
#    'forbauser',
#    'forbauses',
#    'forbauset']],
#  'glitrende': [['glitr', 'glitra', 'glitre', 'glitrer', 'glitres', 'glitret']],
#  'nølende': [['nøl', 'nøle', 'nøler', 'nøles', 'nølt', 'nølte']],
#  'skrikende': [['skreik',
#    'skrek',
#    'skreket',
#    'skrik',
#    'skrike',
#    'skriker',
#    'skrikes']],
#  'utelukkende': [['utelukk',
#    'utelukka',
#    'utelukke',
#    'utelukker',
#    'utelukkes',
#    'utelukket']],
#  'utfordrende': [['utfordr',
#    'utfordra',
#    'utfordre',
#    'utfordrer',
#    'utfordres',
#    'utfordret']],
#  'flammende': [['flam', 'flamma', 'flamme', 'flammer', 'flammes', 'flammet']],
#  'rørende': [['rør', 'røre', 'rører', 'røres', 'rørt', 'rørte']],
#  'skingrende': [['skingr',
#    'skingra',
#    'skingre',
#    'skingrer',
#    'skingres',
#    'skingret']],
#  'blendende': [['blend', 'blenda', 'blende', 'blender', 'blendes', 'blendet']],
#  'overraskende': [['overrask',
#    'overraska',
#    'overraske',
#    'overrasker',
#    'overraskes',
#    'overrasket']],
#  'beundrende': [['beundr',
#    'beundra',
#    'beundre',
#    'beundrer',
#    'beundres',
#    'beundret']],
#  'farende': [['far', 'fare', 'farer', 'fares', 'fart', 'for']],
#  'irriterende': [['irriter',
#    'irritere',
#    'irriterer',
#    'irriteres',
#    'irritert',
#    'irriterte']],
#  'advarende': [['advar', 'advare', 'advarer', 'advares', 'advart', 'advarte']],
#  'avgjørende': [['avgjorde', 'avgjort', 'avgjør', 'avgjøre', 'avgjøres']],
#  'tiltalende': [['tiltal',
#    'tiltala',
#    'tiltale',
#    'tiltaler',
#    'tiltales',
#    'tiltalt',
#    'tiltalte']],
#  'overveldende': [['overveld',
#    'overvelda',
#    'overvelde',
#    'overvelder',
#    'overveldes',
#    'overveldet']],
#  'sovende': [['sov', 'sove', 'sover', 'soves', 'sovet']],
#  'leende': [['le',
#    'ledd',
#    'ler',
#    'les',
#    'lo',
#    'lea',
#    'lee',
#    'leer',
#    'lees',
#    'leet']],
#  'trykkende': [['trykk',
#    'trykka',
#    'trykke',
#    'trykker',
#    'trykkes',
#    'trykket',
#    'trykt',
#    'trykte']],
#  'bølgende': [['bølg', 'bølga', 'bølge', 'bølger', 'bølges', 'bølget']],
#  'tiltrekkende': [['tiltrakk',
#    'tiltrekk',
#    'tiltrekke',
#    'tiltrekker',
#    'tiltrekkes',
#    'tiltrukket']],
#  'angående': [['angikk',
#    'angjekk',
#    'angå',
#    'angåes',
#    'angår',
#    'angås',
#    'angått']],
#  'styrtende': [['styrt', 'styrta', 'styrte', 'styrter', 'styrtes', 'styrtet']],
#  'stikkende': [['stakk', 'stikk', 'stikke', 'stikker', 'stikkes', 'stukket']],
#  'flytende': [['flaut',
#    'flyt',
#    'flyte',
#    'flyter',
#    'flytes',
#    'flytt',
#    'fløt',
#    'fløyt']],
#  'hviskende': [['hvisk', 'hviska', 'hviske', 'hvisker', 'hviskes', 'hvisket']],
#  'bydende': [['baud',
#    'budt',
#    'byd',
#    'bydd',
#    'bydde',
#    'byde',
#    'byder',
#    'bydes',
#    'bød']],
#  'flakkende': [['flakk', 'flakka', 'flakke', 'flakker', 'flakkes', 'flakket']],
#  'kvelende': [['kvalt',
#    'kvalte',
#    'kvel',
#    'kvele',
#    'kveler',
#    'kveles',
#    'kvelt',
#    'kvelte']],
#  'anstrengende': [['anstreng',
#    'anstrenge',
#    'anstrenger',
#    'anstrenges',
#    'anstrengt',
#    'anstrengte']],
#  'tvilende': [['tvil', 'tvile', 'tviler', 'tviles', 'tvilt', 'tvilte']],
#  'sjarmerende': [['sjarmer',
#    'sjarmere',
#    'sjarmerer',
#    'sjarmeres',
#    'sjarmert',
#    'sjarmerte']]}

# %% [markdown]
# Nå lager vi en ny statistikk der alle ordene telles opp fra datarammen for sammenligning

# %%
counts = dict()
for w in participles:
    counts[w] = max(1, TEXT.loc[list(set(participles[w][0]) & set(TEXT.index))].sum(axis=1).sum())

# %%
counts_nob = dict()
for w in participles:
    counts_nob[w] = max(1, TEXT_NOB.loc[list(set(participles[w][0]) & set(TEXT_NOB.index))].sum(axis=1).sum())

# %%
counts_nob
# Out:
# {'stående': 4984.0,
#  'levende': 1113.0,
#  'rasende': 105.0,
#  'sittende': 4226.0,
#  'strålende': 71.0,
#  'liggende': 2850.0,
#  'smilende': 1057.0,
#  'skjelvende': 177.0,
#  'skinnende': 218.0,
#  'brennende': 369.0,
#  'utseende': 5.0,
#  'spennende': 197.0,
#  'gående': 9346.0,
#  'hengende': 608.0,
#  'truende': 745.0,
#  'løpende': 548.0,
#  'passende': 405.0,
#  'lignende': 239.0,
#  'triumferende': 12.0,
#  'glimrende': 4.0,
#  'spørrende': 1390.0,
#  'glødende': 71.0,
#  'beroligende': 42.0,
#  'vedkommende': 20.0,
#  'lysende': 1300.0,
#  'skremmende': 138.0,
#  'gjennomtrengende': 1,
#  'ertende': 128.0,
#  'følgende': 935.0,
#  'imponerende': 31.0,
#  'oppmuntrende': 20.0,
#  'undersøkende': 102.0,
#  'bebreidende': 24.0,
#  'forbausende': 120.0,
#  'glitrende': 48.0,
#  'nølende': 54.0,
#  'skrikende': 588.0,
#  'utelukkende': 13.0,
#  'utfordrende': 11.0,
#  'flammende': 83.0,
#  'rørende': 300.0,
#  'skingrende': 4.0,
#  'blendende': 20.0,
#  'overraskende': 65.0,
#  'beundrende': 76.0,
#  'farende': 21459.0,
#  'irriterende': 64.0,
#  'advarende': 47.0,
#  'avgjørende': 117.0,
#  'tiltalende': 57.0,
#  'overveldende': 26.0,
#  'sovende': 530.0,
#  'leende': 1523.0,
#  'trykkende': 412.0,
#  'bølgende': 79.0,
#  'tiltrekkende': 9.0,
#  'angående': 103.0,
#  'styrtende': 118.0,
#  'stikkende': 531.0,
#  'flytende': 106.0,
#  'hviskende': 303.0,
#  'bydende': 133.0,
#  'flakkende': 42.0,
#  'kvelende': 70.0,
#  'anstrengende': 38.0,
#  'tvilende': 330.0,
#  'sjarmerende': 4.0}

# %%
counts
# Out:
# {'stående': 10851.0,
#  'levende': 2227.0,
#  'rasende': 302.0,
#  'sittende': 11015.0,
#  'strålende': 248.0,
#  'liggende': 6238.0,
#  'smilende': 3862.0,
#  'skjelvende': 802.0,
#  'skinnende': 580.0,
#  'brennende': 788.0,
#  'utseende': 18.0,
#  'spennende': 574.0,
#  'gående': 27203.0,
#  'hengende': 1613.0,
#  'truende': 543.0,
#  'løpende': 2311.0,
#  'passende': 1659.0,
#  'lignende': 549.0,
#  'triumferende': 36.0,
#  'glimrende': 11.0,
#  'spørrende': 7751.0,
#  'glødende': 166.0,
#  'beroligende': 161.0,
#  'vedkommende': 32.0,
#  'lysende': 4092.0,
#  'skremmende': 521.0,
#  'gjennomtrengende': 9.0,
#  'ertende': 335.0,
#  'følgende': 2955.0,
#  'imponerende': 114.0,
#  'oppmuntrende': 150.0,
#  'undersøkende': 582.0,
#  'bebreidende': 162.0,
#  'forbausende': 673.0,
#  'glitrende': 111.0,
#  'nølende': 320.0,
#  'skrikende': 1485.0,
#  'utelukkende': 59.0,
#  'utfordrende': 40.0,
#  'flammende': 350.0,
#  'rørende': 1234.0,
#  'skingrende': 28.0,
#  'blendende': 66.0,
#  'overraskende': 426.0,
#  'beundrende': 275.0,
#  'farende': 55037.0,
#  'irriterende': 287.0,
#  'advarende': 234.0,
#  'avgjørende': 337.0,
#  'tiltalende': 100.0,
#  'overveldende': 114.0,
#  'sovende': 1576.0,
#  'leende': 3117.0,
#  'trykkende': 808.0,
#  'bølgende': 291.0,
#  'tiltrekkende': 101.0,
#  'angående': 267.0,
#  'styrtende': 539.0,
#  'stikkende': 2225.0,
#  'flytende': 281.0,
#  'hviskende': 1178.0,
#  'bydende': 190.0,
#  'flakkende': 110.0,
#  'kvelende': 238.0,
#  'anstrengende': 206.0,
#  'tvilende': 936.0,
#  'sjarmerende': 4.0}

# %% [markdown]
# # Legg til opptellinger for partisippene

# %%
count_frame = {x: {'verb_paradigm': counts[x], 'participle': TEXT.loc[x].sum()} for x in counts}

# %%
count_frame_nob = {x: {'verb_paradigm': counts_nob[x], 'participle': TEXT_NOB.loc[x].sum()} for x in counts_nob}

# %%
count_frame
# Out:
# {'stående': {'verb_paradigm': 10851.0, 'participle': 1122.0},
#  'levende': {'verb_paradigm': 2227.0, 'participle': 599.0},
#  'rasende': {'verb_paradigm': 302.0, 'participle': 572.0},
#  'sittende': {'verb_paradigm': 11015.0, 'participle': 561.0},
#  'strålende': {'verb_paradigm': 248.0, 'participle': 508.0},
#  'liggende': {'verb_paradigm': 6238.0, 'participle': 388.0},
#  'smilende': {'verb_paradigm': 3862.0, 'participle': 362.0},
#  'skjelvende': {'verb_paradigm': 802.0, 'participle': 312.0},
#  'skinnende': {'verb_paradigm': 580.0, 'participle': 304.0},
#  'brennende': {'verb_paradigm': 788.0, 'participle': 259.0},
#  'utseende': {'verb_paradigm': 18.0, 'participle': 246.0},
#  'spennende': {'verb_paradigm': 574.0, 'participle': 246.0},
#  'gående': {'verb_paradigm': 27203.0, 'participle': 236.0},
#  'hengende': {'verb_paradigm': 1613.0, 'participle': 211.0},
#  'truende': {'verb_paradigm': 543.0, 'participle': 186.0},
#  'løpende': {'verb_paradigm': 2311.0, 'participle': 183.0},
#  'passende': {'verb_paradigm': 1659.0, 'participle': 174.0},
#  'lignende': {'verb_paradigm': 549.0, 'participle': 161.0},
#  'triumferende': {'verb_paradigm': 36.0, 'participle': 155.0},
#  'glimrende': {'verb_paradigm': 11.0, 'participle': 149.0},
#  'spørrende': {'verb_paradigm': 7751.0, 'participle': 149.0},
#  'glødende': {'verb_paradigm': 166.0, 'participle': 148.0},
#  'beroligende': {'verb_paradigm': 161.0, 'participle': 135.0},
#  'vedkommende': {'verb_paradigm': 32.0, 'participle': 135.0},
#  'lysende': {'verb_paradigm': 4092.0, 'participle': 122.0},
#  'skremmende': {'verb_paradigm': 521.0, 'participle': 107.0},
#  'gjennomtrengende': {'verb_paradigm': 9.0, 'participle': 106.0},
#  'ertende': {'verb_paradigm': 335.0, 'participle': 104.0},
#  'følgende': {'verb_paradigm': 2955.0, 'participle': 104.0},
#  'imponerende': {'verb_paradigm': 114.0, 'participle': 104.0},
#  'oppmuntrende': {'verb_paradigm': 150.0, 'participle': 102.0},
#  'undersøkende': {'verb_paradigm': 582.0, 'participle': 102.0},
#  'bebreidende': {'verb_paradigm': 162.0, 'participle': 101.0},
#  'forbausende': {'verb_paradigm': 673.0, 'participle': 100.0},
#  'glitrende': {'verb_paradigm': 111.0, 'participle': 99.0},
#  'nølende': {'verb_paradigm': 320.0, 'participle': 97.0},
#  'skrikende': {'verb_paradigm': 1485.0, 'participle': 93.0},
#  'utelukkende': {'verb_paradigm': 59.0, 'participle': 93.0},
#  'utfordrende': {'verb_paradigm': 40.0, 'participle': 92.0},
#  'flammende': {'verb_paradigm': 350.0, 'participle': 89.0},
#  'rørende': {'verb_paradigm': 1234.0, 'participle': 89.0},
#  'skingrende': {'verb_paradigm': 28.0, 'participle': 88.0},
#  'blendende': {'verb_paradigm': 66.0, 'participle': 87.0},
#  'overraskende': {'verb_paradigm': 426.0, 'participle': 87.0},
#  'beundrende': {'verb_paradigm': 275.0, 'participle': 85.0},
#  'farende': {'verb_paradigm': 55037.0, 'participle': 85.0},
#  'irriterende': {'verb_paradigm': 287.0, 'participle': 82.0},
#  'advarende': {'verb_paradigm': 234.0, 'participle': 82.0},
#  'avgjørende': {'verb_paradigm': 337.0, 'participle': 80.0},
#  'tiltalende': {'verb_paradigm': 100.0, 'participle': 80.0},
#  'overveldende': {'verb_paradigm': 114.0, 'participle': 80.0},
#  'sovende': {'verb_paradigm': 1576.0, 'participle': 80.0},
#  'leende': {'verb_paradigm': 3117.0, 'participle': 79.0},
#  'trykkende': {'verb_paradigm': 808.0, 'participle': 78.0},
#  'bølgende': {'verb_paradigm': 291.0, 'participle': 78.0},
#  'tiltrekkende': {'verb_paradigm': 101.0, 'participle': 78.0},
#  'angående': {'verb_paradigm': 267.0, 'participle': 77.0},
#  'styrtende': {'verb_paradigm': 539.0, 'participle': 77.0},
#  'stikkende': {'verb_paradigm': 2225.0, 'participle': 75.0},
#  'flytende': {'verb_paradigm': 281.0, 'participle': 73.0},
#  'hviskende': {'verb_paradigm': 1178.0, 'participle': 72.0},
#  'bydende': {'verb_paradigm': 190.0, 'participle': 71.0},
#  'flakkende': {'verb_paradigm': 110.0, 'participle': 70.0},
#  'kvelende': {'verb_paradigm': 238.0, 'participle': 69.0},
#  'anstrengende': {'verb_paradigm': 206.0, 'participle': 68.0},
#  'tvilende': {'verb_paradigm': 936.0, 'participle': 68.0},
#  'sjarmerende': {'verb_paradigm': 4.0, 'participle': 67.0}}

# %%
COUNTS = nb.frame(count_frame)

# %%
COUNTS.head()
# Out:
#               verb_paradigm  participle
# advarende             234.0        82.0
# angående              267.0        77.0
# anstrengende          206.0        68.0
# avgjørende            337.0        80.0
# bebreidende           162.0       101.0

# %%
COUNTS_NOB = nb.frame(count_frame_nob)

# %%
COUNTS_NOB.head()
# Out:
#               verb_paradigm  participle
# advarende              47.0        20.0
# angående              103.0        17.0
# anstrengende           38.0        17.0
# avgjørende            117.0        73.0
# bebreidende            24.0        15.0

# %%
TOT = nb.totals(50000)

# %%
TOT = nb.frame(TOT)

# %% [markdown]
# Legg til en kolonne med ratioen melllom de to første.

# %%
COUNTS['ratio'] = COUNTS['participle']/(COUNTS['participle']+COUNTS['verb_paradigm'])

# %%
COUNTS_NOB['ratio'] = COUNTS_NOB['participle']/(COUNTS_NOB['participle']+COUNTS_NOB['verb_paradigm'])

# %% [markdown]
# # Sortér på ratio
#
# Her ser vi klart at det kanskje ikke er ekte partisipper på topp, mer typiske ord i partisippform.
#
# De mest interessante ordene (tror jeg) er på bunnen her, som 'smilende', 'løpende', 'liggende', 'spørrende'. Og den ratioen kan sammenlignes med norsk sett.

# %%
COUNTS.sort_values(by='ratio', ascending=False)
# Out:
#                   verb_paradigm  participle     ratio
# sjarmerende                 4.0        67.0  0.943662
# utseende                   18.0       246.0  0.931818
# glimrende                  11.0       149.0  0.931250
# gjennomtrengende            9.0       106.0  0.921739
# triumferende               36.0       155.0  0.811518
# vedkommende                32.0       135.0  0.808383
# skingrende                 28.0        88.0  0.758621
# utfordrende                40.0        92.0  0.696970
# strålende                 248.0       508.0  0.671958
# rasende                   302.0       572.0  0.654462
# utelukkende                59.0        93.0  0.611842
# blendende                  66.0        87.0  0.568627
# imponerende               114.0       104.0  0.477064
# glitrende                 111.0        99.0  0.471429
# glødende                  166.0       148.0  0.471338
# beroligende               161.0       135.0  0.456081
# tiltalende                100.0        80.0  0.444444
# tiltrekkende              101.0        78.0  0.435754
# overveldende              114.0        80.0  0.412371
# oppmuntrende              150.0       102.0  0.404762
# flakkende                 110.0        70.0  0.388889
# bebreidende               162.0       101.0  0.384030
# skinnende                 580.0       304.0  0.343891
# spennende                 574.0       246.0  0.300000
# skjelvende                802.0       312.0  0.280072
# bydende                   190.0        71.0  0.272031
# advarende                 234.0        82.0  0.259494
# truende                   543.0       186.0  0.255144
# anstrengende              206.0        68.0  0.248175
# brennende                 788.0       259.0  0.247373
# ...                         ...         ...       ...
# levende                  2227.0       599.0  0.211960
# bølgende                  291.0        78.0  0.211382
# flytende                  281.0        73.0  0.206215
# flammende                 350.0        89.0  0.202733
# avgjørende                337.0        80.0  0.191847
# skremmende                521.0       107.0  0.170382
# overraskende              426.0        87.0  0.169591
# undersøkende              582.0       102.0  0.149123
# forbausende               673.0       100.0  0.129366
# styrtende                 539.0        77.0  0.125000
# hengende                 1613.0       211.0  0.115680
# passende                 1659.0       174.0  0.094926
# stående                 10851.0      1122.0  0.093711
# trykkende                 808.0        78.0  0.088036
# smilende                 3862.0       362.0  0.085701
# løpende                  2311.0       183.0  0.073376
# tvilende                  936.0        68.0  0.067729
# rørende                  1234.0        89.0  0.067271
# skrikende                1485.0        93.0  0.058935
# liggende                 6238.0       388.0  0.058557
# hviskende                1178.0        72.0  0.057600
# sittende                11015.0       561.0  0.048462
# sovende                  1576.0        80.0  0.048309
# følgende                 2955.0       104.0  0.033998
# stikkende                2225.0        75.0  0.032609
# lysende                  4092.0       122.0  0.028951
# leende                   3117.0        79.0  0.024718
# spørrende                7751.0       149.0  0.018861
# gående                  27203.0       236.0  0.008601
# farende                 55037.0        85.0  0.001542
#
# [67 rows x 3 columns]

# %%
COUNTS_NOB.sort_values(by='ratio', ascending=False)
# Out:
#                    verb_paradigm  participle     ratio
# gjennomtrengende             2.0        25.0  0.925926
# sjarmerende                  1.0         6.0  0.857143
# vedkommende                 14.0        50.0  0.781250
# utseende                     7.0        25.0  0.781250
# utfordrende                  6.0        19.0  0.760000
# utelukkende                 12.0        34.0  0.739130
# triumferende                11.0        29.0  0.725000
# skingrende                   5.0        11.0  0.687500
# oppmuntrende                19.0        22.0  0.536585
# nølende                     27.0        31.0  0.534483
# glitrende                   28.0        28.0  0.500000
# strålende                   72.0        71.0  0.496503
# blendende                   16.0        14.0  0.466667
# fortryllende                 7.0         6.0  0.461538
# overveldende                44.0        36.0  0.450000
# flakkende                   27.0        22.0  0.448980
# rasende                    145.0       107.0  0.424603
# avgjørende                  95.0        69.0  0.420732
# beroligende                 22.0        15.0  0.405405
# angående                    45.0        28.0  0.383562
# tilfredsstillende           15.0         9.0  0.375000
# glimrende                   12.0         6.0  0.333333
# imponerende                 33.0        15.0  0.312500
# glødende                    59.0        24.0  0.289157
# skinnende                  213.0        86.0  0.287625
# tiltalende                  25.0        10.0  0.285714
# overraskende                77.0        30.0  0.280374
# bebreidende                 26.0        10.0  0.277778
# advarende                   37.0        14.0  0.274510
# blomstrende                 44.0        15.0  0.254237
# ...                          ...         ...       ...
# smilende                   966.0        88.0  0.083491
# hviskende                  276.0        23.0  0.076923
# tvilende                   327.0        27.0  0.076271
# drømmende                  386.0        30.0  0.072115
# hengende                   549.0        41.0  0.069492
# styrtende                  108.0         8.0  0.068966
# rørende                    251.0        18.0  0.066914
# truende                    869.0        62.0  0.066595
# undersøkende                85.0         6.0  0.065934
# liknende                   103.0         7.0  0.063636
# bydende                    104.0         7.0  0.063063
# løpende                    421.0        24.0  0.053933
# stående                   4656.0       265.0  0.053851
# ridende                    272.0        15.0  0.052265
# ertende                    202.0        11.0  0.051643
# passende                   497.0        26.0  0.049713
# følgende                   939.0        48.0  0.048632
# liggende                  2632.0       134.0  0.048445
# stikkende                  539.0        27.0  0.047703
# trykkende                  508.0        22.0  0.041509
# sovende                    589.0        25.0  0.040717
# skrikende                  548.0        23.0  0.040280
# sittende                  4288.0       158.0  0.035538
# springende                 551.0        19.0  0.033333
# spørrende                 1360.0        45.0  0.032028
# døende                     737.0        23.0  0.030263
# lysende                   1336.0        39.0  0.028364
# leende                    1910.0        30.0  0.015464
# gående                    8631.0        82.0  0.009411
# farende                  19232.0        17.0  0.000883
#
# [82 rows x 3 columns]

# %% [markdown]
# # Sammenligner ratio for oversatt mot NOB

# %%
COMP = COUNTS['ratio']/COUNTS_NOB['ratio']

# %%
HTML(nb.frame(COMP.sort_values(ascending=False)).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>bydende</th>
#       <td>3.890038</td>
#     </tr>
#     <tr>
#       <th>undersøkende</th>
#       <td>2.684211</td>
#     </tr>
#     <tr>
#       <th>tvilende</th>
#       <td>2.551129</td>
#     </tr>
#     <tr>
#       <th>farende</th>
#       <td>2.069699</td>
#     </tr>
#     <tr>
#       <th>trykkende</th>
#       <td>1.997030</td>
#     </tr>
#     <tr>
#       <th>truende</th>
#       <td>1.967597</td>
#     </tr>
#     <tr>
#       <th>ertende</th>
#       <td>1.921539</td>
#     </tr>
#     <tr>
#       <th>tiltalende</th>
#       <td>1.851852</td>
#     </tr>
#     <tr>
#       <th>skrikende</th>
#       <td>1.709125</td>
#     </tr>
#     <tr>
#       <th>kvelende</th>
#       <td>1.655019</td>
#     </tr>
#     <tr>
#       <th>angående</th>
#       <td>1.580027</td>
#     </tr>
#     <tr>
#       <th>skinnende</th>
#       <td>1.572880</td>
#     </tr>
#     <tr>
#       <th>sjarmerende</th>
#       <td>1.572770</td>
#     </tr>
#     <tr>
#       <th>hengende</th>
#       <td>1.551054</td>
#     </tr>
#     <tr>
#       <th>beundrende</th>
#       <td>1.517857</td>
#     </tr>
#     <tr>
#       <th>blendende</th>
#       <td>1.516340</td>
#     </tr>
#     <tr>
#       <th>flakkende</th>
#       <td>1.409722</td>
#     </tr>
#     <tr>
#       <th>irriterende</th>
#       <td>1.407407</td>
#     </tr>
#     <tr>
#       <th>brennende</th>
#       <td>1.388383</td>
#     </tr>
#     <tr>
#       <th>stående</th>
#       <td>1.376829</td>
#     </tr>
#     <tr>
#       <th>utfordrende</th>
#       <td>1.335859</td>
#     </tr>
#     <tr>
#       <th>glødende</th>
#       <td>1.307962</td>
#     </tr>
#     <tr>
#       <th>flytende</th>
#       <td>1.299153</td>
#     </tr>
#     <tr>
#       <th>imponerende</th>
#       <td>1.298675</td>
#     </tr>
#     <tr>
#       <th>spennende</th>
#       <td>1.195455</td>
#     </tr>
#     <tr>
#       <th>rørende</th>
#       <td>1.188461</td>
#     </tr>
#     <tr>
#       <th>stikkende</th>
#       <td>1.186957</td>
#     </tr>
#     <tr>
#       <th>skjelvende</th>
#       <td>1.181394</td>
#     </tr>
#     <tr>
#       <th>sittende</th>
#       <td>1.179964</td>
#     </tr>
#     <tr>
#       <th>gående</th>
#       <td>1.173586</td>
#     </tr>
#     <tr>
#       <th>skremmende</th>
#       <td>1.150080</td>
#     </tr>
#     <tr>
#       <th>triumferende</th>
#       <td>1.097937</td>
#     </tr>
#     <tr>
#       <th>strålende</th>
#       <td>1.086818</td>
#     </tr>
#     <tr>
#       <th>utelukkende</th>
#       <td>1.079721</td>
#     </tr>
#     <tr>
#       <th>rasende</th>
#       <td>1.070938</td>
#     </tr>
#     <tr>
#       <th>utseende</th>
#       <td>1.051282</td>
#     </tr>
#     <tr>
#       <th>vedkommende</th>
#       <td>1.049692</td>
#     </tr>
#     <tr>
#       <th>glimrende</th>
#       <td>1.037679</td>
#     </tr>
#     <tr>
#       <th>sovende</th>
#       <td>1.033073</td>
#     </tr>
#     <tr>
#       <th>passende</th>
#       <td>1.032613</td>
#     </tr>
#     <tr>
#       <th>gjennomtrengende</th>
#       <td>1.013913</td>
#     </tr>
#     <tr>
#       <th>bebreidende</th>
#       <td>0.998479</td>
#     </tr>
#     <tr>
#       <th>lignende</th>
#       <td>0.969168</td>
#     </tr>
#     <tr>
#       <th>smilende</th>
#       <td>0.948422</td>
#     </tr>
#     <tr>
#       <th>beroligende</th>
#       <td>0.947245</td>
#     </tr>
#     <tr>
#       <th>leende</th>
#       <td>0.942916</td>
#     </tr>
#     <tr>
#       <th>løpende</th>
#       <td>0.928910</td>
#     </tr>
#     <tr>
#       <th>skingrende</th>
#       <td>0.927203</td>
#     </tr>
#     <tr>
#       <th>glitrende</th>
#       <td>0.906593</td>
#     </tr>
#     <tr>
#       <th>styrtende</th>
#       <td>0.901316</td>
#     </tr>
#     <tr>
#       <th>overveldende</th>
#       <td>0.878530</td>
#     </tr>
#     <tr>
#       <th>advarende</th>
#       <td>0.869304</td>
#     </tr>
#     <tr>
#       <th>liggende</th>
#       <td>0.842069</td>
#     </tr>
#     <tr>
#       <th>tiltrekkende</th>
#       <td>0.827933</td>
#     </tr>
#     <tr>
#       <th>levende</th>
#       <td>0.827918</td>
#     </tr>
#     <tr>
#       <th>overraskende</th>
#       <td>0.818025</td>
#     </tr>
#     <tr>
#       <th>flammende</th>
#       <td>0.803693</td>
#     </tr>
#     <tr>
#       <th>anstrengende</th>
#       <td>0.802920</td>
#     </tr>
#     <tr>
#       <th>spørrende</th>
#       <td>0.767902</td>
#     </tr>
#     <tr>
#       <th>bølgende</th>
#       <td>0.733232</td>
#     </tr>
#     <tr>
#       <th>oppmuntrende</th>
#       <td>0.716117</td>
#     </tr>
#     <tr>
#       <th>forbausende</th>
#       <td>0.704327</td>
#     </tr>
#     <tr>
#       <th>nølende</th>
#       <td>0.613255</td>
#     </tr>
#     <tr>
#       <th>hviskende</th>
#       <td>0.529297</td>
#     </tr>
#     <tr>
#       <th>avgjørende</th>
#       <td>0.499327</td>
#     </tr>
#     <tr>
#       <th>lysende</th>
#       <td>0.447134</td>
#     </tr>
#     <tr>
#       <th>følgende</th>
#       <td>0.274817</td>
#     </tr>
#   </tbody>
# </table>

# %%
counts_tot = dict()
for w in participles:
    counts_tot[w] = max(1, TOT.loc[list(set(participles[w][0]) & set(TOT.index))].sum(axis=1).sum())

# %%
counts_tot
# Out:
# {'stående': 19437983,
#  'levende': 5312408,
#  'rasende': 635995,
#  'sittende': 19514023,
#  'strålende': 323529,
#  'liggende': 14864068,
#  'smilende': 3740043,
#  'skjelvende': 683719,
#  'skinnende': 864480,
#  'brennende': 1559790,
#  'utseende': 73206,
#  'spennende': 751509,
#  'gående': 39842605,
#  'hengende': 2623103,
#  'truende': 2250953,
#  'løpende': 4492046,
#  'passende': 3018854,
#  'lignende': 1124850,
#  'triumferende': 1,
#  'glimrende': 1,
#  'spørrende': 7493284,
#  'glødende': 214013,
#  'beroligende': 161135,
#  'vedkommende': 67666,
#  'lysende': 5765415,
#  'skremmende': 643472,
#  'gjennomtrengende': 1,
#  'ertende': 492511,
#  'følgende': 8535735,
#  'imponerende': 200342,
#  'oppmuntrende': 242364,
#  'undersøkende': 1342556,
#  'bebreidende': 122541,
#  'forbausende': 400348,
#  'glitrende': 131025,
#  'nølende': 385535,
#  'skrikende': 1517043,
#  'utelukkende': 329885,
#  'utfordrende': 224945,
#  'flammende': 286779,
#  'rørende': 1620765,
#  'skingrende': 1,
#  'blendende': 45274,
#  'overraskende': 561859,
#  'beundrende': 310904,
#  'farende': 209473618,
#  'irriterende': 424946,
#  'advarende': 336853,
#  'avgjørende': 1212211,
#  'tiltalende': 361018,
#  'overveldende': 91829,
#  'sovende': 1918683,
#  'leende': 11129835,
#  'trykkende': 2244371,
#  'bølgende': 428659,
#  'tiltrekkende': 202167,
#  'angående': 572794,
#  'styrtende': 887095,
#  'stikkende': 2465419,
#  'flytende': 644943,
#  'hviskende': 1065417,
#  'bydende': 495097,
#  'flakkende': 57799,
#  'kvelende': 220722,
#  'anstrengende': 247621,
#  'tvilende': 1672519,
#  'sjarmerende': 1}

# %%
count_frame_tot = {x: {'verb_paradigm': counts_tot[x], 'participle': TOT.loc[x].sum()} for x in counts_tot}

# %%
TOTCOUNT = nb.frame(count_frame_tot)

# %%
TOTCOUNT
# Out:
#                   verb_paradigm  participle
# advarende                336853       66111
# angående                 572794      267385
# anstrengende             247621       72006
# avgjørende              1212211     1008752
# bebreidende              122541       42515
# beroligende              161135      171112
# beundrende               310904       55098
# blendende                 45274       67854
# brennende               1559790      243684
# bydende                  495097       39578
# bølgende                 428659       70373
# ertende                  492511       71882
# farende               209473618       71677
# flakkende                 57799       48374
# flammende                286779       75943
# flytende                 644943      331672
# forbausende              400348      134308
# følgende                8535735     2978403
# gjennomtrengende              1       53225
# glimrende                     1      185539
# glitrende                131025      112910
# glødende                 214013      155430
# gående                 39842605      296548
# hengende                2623103      249810
# hviskende               1065417       78075
# imponerende              200342      204546
# irriterende              424946       89848
# kvelende                 220722       45950
# leende                 11129835       99493
# levende                 5312408     1504034
# ...                         ...         ...
# overveldende              91829      155546
# passende                3018854      479242
# rasende                  635995      557062
# rørende                 1620765       78769
# sittende               19514023      673395
# sjarmerende                   1      103095
# skingrende                    1       70651
# skinnende                864480      258618
# skjelvende               683719      224829
# skremmende               643472      242144
# skrikende               1517043       74460
# smilende                3740043      276899
# sovende                 1918683      108536
# spennende                751509      508995
# spørrende               7493284      166140
# stikkende               2465419       66512
# strålende                323529      346513
# styrtende                887095       42938
# stående                19437983     1229940
# tiltalende               361018       90415
# tiltrekkende             202167      109016
# triumferende                  1       96177
# truende                 2250953      272187
# trykkende               2244371       72605
# tvilende                1672519       73501
# undersøkende            1342556       40720
# utelukkende              329885      389967
# utfordrende              224945      143066
# utseende                  73206      348198
# vedkommende               67666     1744651
#
# [67 rows x 2 columns]

# %%
TOTCOUNT['ratio'] = TOTCOUNT['participle']/(TOTCOUNT['participle']+TOTCOUNT['verb_paradigm'])

# %%
TOTCOUNT.sort_values(by='ratio', ascending=False)
# Out:
#                   verb_paradigm  participle     ratio
# glimrende                     1      185539  0.999995
# sjarmerende                   1      103095  0.999990
# triumferende                  1       96177  0.999990
# skingrende                    1       70651  0.999986
# gjennomtrengende              1       53225  0.999981
# vedkommende               67666     1744651  0.962663
# utseende                  73206      348198  0.826281
# overveldende              91829      155546  0.628786
# blendende                 45274       67854  0.599798
# utelukkende              329885      389967  0.541732
# strålende                323529      346513  0.517151
# beroligende              161135      171112  0.515014
# imponerende              200342      204546  0.505192
# rasende                  635995      557062  0.466920
# lignende                1124850      983244  0.466414
# glitrende                131025      112910  0.462869
# flakkende                 57799       48374  0.455615
# avgjørende              1212211     1008752  0.454196
# glødende                 214013      155430  0.420714
# spennende                751509      508995  0.403803
# utfordrende              224945      143066  0.388755
# overraskende             561859      324682  0.366235
# tiltrekkende             202167      109016  0.350328
# flytende                 644943      331672  0.339614
# angående                 572794      267385  0.318248
# oppmuntrende             242364       98647  0.289278
# skremmende               643472      242144  0.273419
# følgende                8535735     2978403  0.258674
# bebreidende              122541       42515  0.257579
# forbausende              400348      134308  0.251205
# ...                         ...         ...       ...
# irriterende              424946       89848  0.174532
# kvelende                 220722       45950  0.172309
# advarende                336853       66111  0.164062
# beundrende               310904       55098  0.150540
# bølgende                 428659       70373  0.141019
# passende                3018854      479242  0.137001
# brennende               1559790      243684  0.135119
# ertende                  492511       71882  0.127362
# truende                 2250953      272187  0.107876
# hengende                2623103      249810  0.086954
# løpende                 4492046      424976  0.086430
# bydende                  495097       39578  0.074023
# smilende                3740043      276899  0.068933
# hviskende               1065417       78075  0.068278
# stående                19437983     1229940  0.059510
# sovende                 1918683      108536  0.053539
# liggende               14864068      792308  0.050606
# skrikende               1517043       74460  0.046786
# rørende                 1620765       78769  0.046347
# styrtende                887095       42938  0.046168
# tvilende                1672519       73501  0.042096
# lysende                 5765415      205146  0.034360
# sittende               19514023      673395  0.033357
# trykkende               2244371       72605  0.031336
# undersøkende            1342556       40720  0.029437
# stikkende               2465419       66512  0.026269
# spørrende               7493284      166140  0.021691
# leende                 11129835       99493  0.008860
# gående                 39842605      296548  0.007388
# farende               209473618       71677  0.000342
#
# [67 rows x 3 columns]

# %%
COMPTOT = COUNTS['ratio']/TOTCOUNT['ratio']

# %%
HTML(nb.frame(COMPTOT.sort_values(ascending=False)).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>undersøkende</th>
#       <td>5.065766</td>
#     </tr>
#     <tr>
#       <th>farende</th>
#       <td>4.508085</td>
#     </tr>
#     <tr>
#       <th>bydende</th>
#       <td>3.674971</td>
#     </tr>
#     <tr>
#       <th>trykkende</th>
#       <td>2.809415</td>
#     </tr>
#     <tr>
#       <th>leende</th>
#       <td>2.789855</td>
#     </tr>
#     <tr>
#       <th>styrtende</th>
#       <td>2.707488</td>
#     </tr>
#     <tr>
#       <th>truende</th>
#       <td>2.365154</td>
#     </tr>
#     <tr>
#       <th>tiltalende</th>
#       <td>2.219066</td>
#     </tr>
#     <tr>
#       <th>ertende</th>
#       <td>1.860074</td>
#     </tr>
#     <tr>
#       <th>brennende</th>
#       <td>1.830779</td>
#     </tr>
#     <tr>
#       <th>utfordrende</th>
#       <td>1.792826</td>
#     </tr>
#     <tr>
#       <th>tvilende</th>
#       <td>1.608908</td>
#     </tr>
#     <tr>
#       <th>advarende</th>
#       <td>1.581682</td>
#     </tr>
#     <tr>
#       <th>stående</th>
#       <td>1.574718</td>
#     </tr>
#     <tr>
#       <th>beundrende</th>
#       <td>1.568426</td>
#     </tr>
#     <tr>
#       <th>bølgende</th>
#       <td>1.498962</td>
#     </tr>
#     <tr>
#       <th>skinnende</th>
#       <td>1.493414</td>
#     </tr>
#     <tr>
#       <th>bebreidende</th>
#       <td>1.490921</td>
#     </tr>
#     <tr>
#       <th>sittende</th>
#       <td>1.452831</td>
#     </tr>
#     <tr>
#       <th>rørende</th>
#       <td>1.451459</td>
#     </tr>
#     <tr>
#       <th>rasende</th>
#       <td>1.401659</td>
#     </tr>
#     <tr>
#       <th>oppmuntrende</th>
#       <td>1.399214</td>
#     </tr>
#     <tr>
#       <th>hengende</th>
#       <td>1.330363</td>
#     </tr>
#     <tr>
#       <th>kvelende</th>
#       <td>1.304375</td>
#     </tr>
#     <tr>
#       <th>strålende</th>
#       <td>1.299345</td>
#     </tr>
#     <tr>
#       <th>irriterende</th>
#       <td>1.273247</td>
#     </tr>
#     <tr>
#       <th>skrikende</th>
#       <td>1.259680</td>
#     </tr>
#     <tr>
#       <th>tiltrekkende</th>
#       <td>1.243848</td>
#     </tr>
#     <tr>
#       <th>smilende</th>
#       <td>1.243251</td>
#     </tr>
#     <tr>
#       <th>stikkende</th>
#       <td>1.241324</td>
#     </tr>
#     <tr>
#       <th>gående</th>
#       <td>1.164171</td>
#     </tr>
#     <tr>
#       <th>liggende</th>
#       <td>1.157118</td>
#     </tr>
#     <tr>
#       <th>skjelvende</th>
#       <td>1.131788</td>
#     </tr>
#     <tr>
#       <th>utelukkende</th>
#       <td>1.129418</td>
#     </tr>
#     <tr>
#       <th>utseende</th>
#       <td>1.127726</td>
#     </tr>
#     <tr>
#       <th>glødende</th>
#       <td>1.120327</td>
#     </tr>
#     <tr>
#       <th>anstrengende</th>
#       <td>1.101623</td>
#     </tr>
#     <tr>
#       <th>glitrende</th>
#       <td>1.018492</td>
#     </tr>
#     <tr>
#       <th>flammende</th>
#       <td>0.968304</td>
#     </tr>
#     <tr>
#       <th>levende</th>
#       <td>0.960627</td>
#     </tr>
#     <tr>
#       <th>blendende</th>
#       <td>0.948031</td>
#     </tr>
#     <tr>
#       <th>nølende</th>
#       <td>0.945045</td>
#     </tr>
#     <tr>
#       <th>imponerende</th>
#       <td>0.944323</td>
#     </tr>
#     <tr>
#       <th>sjarmerende</th>
#       <td>0.943671</td>
#     </tr>
#     <tr>
#       <th>glimrende</th>
#       <td>0.931255</td>
#     </tr>
#     <tr>
#       <th>gjennomtrengende</th>
#       <td>0.921756</td>
#     </tr>
#     <tr>
#       <th>sovende</th>
#       <td>0.902312</td>
#     </tr>
#     <tr>
#       <th>beroligende</th>
#       <td>0.885570</td>
#     </tr>
#     <tr>
#       <th>spørrende</th>
#       <td>0.869523</td>
#     </tr>
#     <tr>
#       <th>flakkende</th>
#       <td>0.853547</td>
#     </tr>
#     <tr>
#       <th>løpende</th>
#       <td>0.848970</td>
#     </tr>
#     <tr>
#       <th>hviskende</th>
#       <td>0.843614</td>
#     </tr>
#     <tr>
#       <th>lysende</th>
#       <td>0.842592</td>
#     </tr>
#     <tr>
#       <th>vedkommende</th>
#       <td>0.839736</td>
#     </tr>
#     <tr>
#       <th>triumferende</th>
#       <td>0.811527</td>
#     </tr>
#     <tr>
#       <th>skingrende</th>
#       <td>0.758631</td>
#     </tr>
#     <tr>
#       <th>spennende</th>
#       <td>0.742937</td>
#     </tr>
#     <tr>
#       <th>angående</th>
#       <td>0.703343</td>
#     </tr>
#     <tr>
#       <th>passende</th>
#       <td>0.692889</td>
#     </tr>
#     <tr>
#       <th>overveldende</th>
#       <td>0.655821</td>
#     </tr>
#     <tr>
#       <th>skremmende</th>
#       <td>0.623155</td>
#     </tr>
#     <tr>
#       <th>flytende</th>
#       <td>0.607203</td>
#     </tr>
#     <tr>
#       <th>forbausende</th>
#       <td>0.514983</td>
#     </tr>
#     <tr>
#       <th>lignende</th>
#       <td>0.486179</td>
#     </tr>
#     <tr>
#       <th>overraskende</th>
#       <td>0.463066</td>
#     </tr>
#     <tr>
#       <th>avgjørende</th>
#       <td>0.422387</td>
#     </tr>
#     <tr>
#       <th>følgende</th>
#       <td>0.131432</td>
#     </tr>
#   </tbody>
# </table>

# %%
collafter = dict()
for w in COMPTOT.sort_values(ascending=False)[:150].index:
    collafter[w] = nb.urn_coll(w, korpus, before=0, after=3)

# %%
collbefore = dict()
for w in COMPTOT.sort_values(ascending=False)[:150].index:
    collbefore[w] = nb.urn_coll(w, korpus, before=3, after=0)

# %%
for x in collafter:
    nb.normalize_corpus_dataframe(collafter[x])

# %%
for x in collbefore:
    nb.normalize_corpus_dataframe(collbefore[x])

# %%
for x in collafter:
    collafter[x]['weight'] = collafter[x][0]**1.1/(TOT[0]/TOT[0].sum())

# %%
for x in collbefore:
    collbefore[x]['weight'] = collbefore[x][0]**1.1/(TOT[0]/TOT[0].sum())

# %%
nb.heatmap(collafter['strålende'].sort_values(by='weight', ascending=False)[:30])
# Out:
# <style  type="text/css" >
#     #T_f964f976_fc3a_11e9_a662_000acd2bfab2row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row1_col0 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row1_col1 {
#             background-color:  #49a849;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row2_col0 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row2_col1 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row3_col0 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row3_col1 {
#             background-color:  #7ec67e;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row4_col0 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row4_col1 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row5_col0 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row5_col1 {
#             background-color:  #abdfab;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row6_col1 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row7_col0 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row7_col1 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row8_col1 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row9_col1 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row10_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row10_col1 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row11_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row11_col1 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row12_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row12_col1 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row13_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row13_col1 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row14_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row14_col1 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row15_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row15_col1 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row16_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row16_col1 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row17_col0 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row17_col1 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row18_col0 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row18_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row19_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row19_col1 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row20_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row20_col1 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row21_col0 {
#             background-color:  #59b159;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row21_col1 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row22_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row22_col1 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row23_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row23_col1 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row24_col0 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row24_col1 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row25_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row25_col1 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row26_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row26_col1 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row27_col0 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row27_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row28_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row28_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row29_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f964f976_fc3a_11e9_a662_000acd2bfab2row29_col1 {
#             background-color:  #

# %%
import pandas as pd
import networkx as nx
import graph_networkx_louvain as gnl

# %%
def coll_array_to_df(coll, column):
    df_colls = pd.DataFrame()
    for x in coll:
        df_colls[x] = coll[x][column]
    return df_colls
    
def coll_to_graph(df_colls, limit = 1000):
    df_colls = df_colls.fillna(0)
    cross = df_colls.transpose().dot(df_colls).stack()
    edges = []
    for x in cross.index:
        if x[0] != x[1] and cross[x] > limit:
            edges.append((x[0], x[1], cross[x]))
    G = nx.Graph()
    G.add_weighted_edges_from(edges)
    return G

# %%
df_colls = coll_array_to_df(collafter,'weight')

# %%
df_colls.sort_values(by='styrtende', ascending=False).head(10)
# Out:
#        undersøkende    farende   bydende  trykkende     leende  styrtende  \
# inn        5.345528  46.887425       NaN        NaN   4.532738  45.920819
# ut         1.022478  20.993801  1.523106        NaN   4.534796  31.438963
# langs     15.091882  18.443475       NaN        NaN  19.990045  20.561925
# mot        5.374706  24.695664  2.391098        NaN        NaN  18.597286
# henne     23.680352        NaN  3.146280        NaN   2.797640  13.222323
# bort       5.733426  23.461024       NaN        NaN  16.278621   7.811503
# ham       20.818115   5.070333  1.845779   3.567737        NaN   7.756934
# igjen      2.562179   3.131185  3.816677        NaN        NaN   7.482777
# dem        3.156249   1.799441       NaN   1.977855        NaN   6.717259
# fra        0.573043   9.790802       NaN        NaN   1.627010   6.639191
#
#         truende  tiltalende    ertende  brennende  ...  angående  passende  \
# inn         NaN         NaN        NaN        NaN  ...       NaN  0.887183
# ut     2.426141    4.472482        NaN   0.786353  ...       NaN       NaN
# langs       NaN         NaN        NaN        NaN  ...       NaN       NaN
# mot    7.048961         NaN   3.368045   2.646170  ...       NaN  0.892026
# henne  2.338031    5.914467   9.499722   0.757795  ...  2.877675  2.515999
# bort        NaN         NaN  12.030141   2.057049  ...       NaN       NaN
# ham    5.441361    1.618695   5.573054   0.952944  ...       NaN  0.688588
# igjen  1.323139         NaN        NaN   1.970484  ...       NaN       NaN
# dem    3.493818         NaN   1.441325   0.528286  ...       NaN  1.753991
# fra    0.990869    0.748597        NaN   0.440707  ...       NaN  0.318451
#
#        overveldende  skremmende  flytende  forbausende  lignende  \
# inn             NaN    1.514591       NaN          NaN       NaN
# ut         1.335719    0.970045       NaN     1.044995       NaN
# langs           NaN         NaN       NaN          NaN       NaN
# mot        2.096923         NaN  4.971179          NaN  0.971568
# henne      2.759196    6.709541       NaN          NaN  1.278419
# bort            NaN         NaN       NaN          NaN       NaN
# ham        1.618695    2.519850       NaN          NaN  0.749990
# igjen           NaN    2.430790       NaN          NaN       NaN
# dem             NaN    1.396935  2.127372     3.225756  0.891230
# fra             NaN         NaN  0.827927     0.585662  0.346848
#
#        overraskende  avgjørende  følgende
# inn        1.901719         NaN       NaN
# ut              NaN         NaN       NaN
# langs           NaN         NaN       NaN
# mot             NaN         NaN       NaN
# henne           NaN         NaN       NaN
# bort            NaN         NaN       NaN
# ham        4.942266         NaN       NaN
# igjen           NaN         NaN       NaN
# dem        3.759762         NaN       NaN
# fra        0.682615         NaN  4.026028
#
# [10 rows x 67 columns]

# %%
df_colls = coll_array_to_df(collafter, 'weight')

# %%
G = coll_to_graph(df_colls)

# %%
gnl.show_graph(G)
# Out:
# D:\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
gnl.show_communities(G)
# Out:
# undersøkende-ertende :  undersøkende, ertende, beundrende, glødende, smilende, glimrende, sovende, utseende, lignende, skremmende, trykkende, stående, følgende
#
# leende-hengende :  leende, hengende, farende, løpende, styrtende, gående, liggende, tiltrekkende, tiltalende
#
# gjennomtrengende-lysende :  gjennomtrengende, lysende, spørrende, flakkende, bydende, utfordrende, bebreidende, advarende, triumferende, rasende, glitrende, flytende, brennende, nølende, oppmuntrende, rørende, beroligende, skinnende, strålende, truende, irriterende, blendende, forbausende, skrikende
#
# stikkende-flammende :  stikkende, flammende, skjelvende

# %%
df_before = coll_array_to_df(collbefore, 'weight')

# %%
Gb = coll_to_graph(df_before, limit=500)

# %%
gnl.show_graph(Gb, spread=0.6);
# Out:
# D:\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
gnl.show_communities(Gb)
# Out:
# undersøkende-sovende :  undersøkende, sovende, strålende, smilende, utfordrende, hengende, farende, overveldende, gående, skjelvende, spennende
#
# glødende-ertende :  glødende, ertende, triumferende, gjennomtrengende, stikkende, truende, lysende, advarende, tvilende, leende, flakkende, vedkommende, bydende, glitrende, bølgende, overraskende, hviskende, flammende, irriterende, styrtende, utelukkende, skrikende, skinnende, utseende, skingrende, forbausende
#
# spørrende-rasende :  spørrende, rasende, beundrende, bebreidende, stående, oppmuntrende, brennende, nølende, sittende, liggende, rørende, avgjørende
#
# sjarmerende-beroligende :  sjarmerende, beroligende, tiltrekkende, levende, skremmende
