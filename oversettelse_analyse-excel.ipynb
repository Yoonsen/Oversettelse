# %% [markdown]
# ## Preamble
#
# Run these if notebook is in a new environment, otherwise just skip to `Import modules`

# %% [markdown]
# #### Boot cell
#
# Skip if `module_update.py` is in same folder as notebook, next cell downloads this file which in turn will download other files.

# %%
# !curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %% [markdown]
# #### Get essentials
#
# Import text and graph modules for analysis, and css for display

# %%
from module_update import update, css

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# # Import modules
#
# Aktiver cellen nedenfor for å få alt til å virke.

# %%
update('nbtext', overwrite=True)
import nbtext as nb
from IPython.display import HTML
import requests
from bs4 import BeautifulSoup


def mods_digibok(urn, kind='marcxml'):
    """find information about serial number urn (or full urn) for books using NB API. 
    Parameter 'kind' is one of mods, marcxml or dublincore """
    
    if not str(urn).startswith('URN'):
        urnstr = "URN:NBN:no-nb_digibok_{urn}".format(urn=urn)
    r = requests.get("https://api.nb.no:443/catalog/v1/metadata/{ident}/{kind}".format(ident=urnstr, kind=kind))
    return r.text

def translator(urn):
    """Finds the translator for a book"""
    item = BeautifulSoup(mods_digibok(urn, kind='mods'), 'lxml')
    trans = []
    navn = item.find_all('name', {'type':'personal'})
    for i in navn:

        try:
            if i.roleterm.text == 'trl':
                trans.append(i.namepart.text)
        except:
            'nn'
    return ';'.join(trans)
# Out:
# Updated file `D:\Documents\GitHub\Oversettelse\nbtext.py`

# %% [markdown]
# ## Build corpus
#
# A corpus definition is a set of URNs. Those can be obtained in various ways and stored as text or in MS-Word file.

# %% [markdown]
# ### Define using metadata
#
# Using author name, titles, year, dewey, subject and gender. Check out [Webdewey](http://deweysearchno.pansoft.de/webdeweysearch/index.html) for more descriptions.

# %%
korpus = nb.get_urn({
                     'year':1950, 
                     'next':2,
                     'trans':'eng',
                     'limit':300})
len(korpus)
# Out:
# 300

# %%
korpus_nob = nb.get_urn({
                     'year':1950, 
                     'next':2,
                     'trans':'',
                     'limit':300})
len(korpus)
# Out:
# 300

# %% [markdown]
# # Henter bøkene med ord
#
# Her defineres korpuset som en liste over bøker, med informasjon om oversettere. Er korpuset stort (flere hundre) vil det ta noen minutter å hente alle oversetterne, så det kan være lurt å kutte ned størrelsen litt. Inntil vi får på plass en rask måte å gjøre det på, får det her duge. Det er bare å smøre seg med tålmodighet.

# %%
rammen = nb.frame(nb.metadata(korpus), ['urn', 'forfatter','år','tittel','språk','forlag', 'original' ]).sort_values(by='tittel')
rammen = rammen.set_index('urn')
rammen.index = rammen.index.astype(str)


book_counts = nb.frame(nb.book_count([x[0] for x in korpus]), ['antall_ord'])
book_counts.index = book_counts.index.astype(str)
book_counts.antall_ord = book_counts.antall_ord.astype(int)

print('Telling ferdig')

# sammenslåing
rammen = rammen.join(book_counts)
rammen = rammen[['forfatter', 'år', 'tittel', 'antall_ord', 'original']]
rammen.head()
# Out:
# Telling ferdig
#                       forfatter    år             tittel  antall_ord original
# urn
# 2011031720018                    1950   "Gud er sanndru"    106232.0      eng
# 2016060848216    Orwell, George  1950               1984    118115.0      eng
# 2012022305002  Bromfield, Louis  1952           24 timer    113596.0      eng
# 2011111108159     Barber, D. H.  1951      Afrika i kaki     37382.0      eng
# 2007012601033    Seaver, George  1950  Albert Schweitzer     71866.0      eng

# %% [markdown]
# ## Se på hele korpuset under ett som HTML

# %%
HTML(rammen.sort_values(by = 'forfatter').to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>forfatter</th>
#       <th>år</th>
#       <th>tittel</th>
#       <th>antall_ord</th>
#       <th>original</th>
#     </tr>
#     <tr>
#       <th>urn</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2011031720018</th>
#       <td></td>
#       <td>1950</td>
#       <td>"Gud er sanndru"</td>
#       <td>106232.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011110708036</th>
#       <td></td>
#       <td>1951</td>
#       <td>De tre bjørnene</td>
#       <td>811.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008042800003</th>
#       <td></td>
#       <td>1950</td>
#       <td>Verdenserklæringen om menneskerettigheter</td>
#       <td>10158.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2016110248029</th>
#       <td>Abrahams, Peter</td>
#       <td>1951</td>
#       <td>Røde hjulspor</td>
#       <td>115901.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2016062048127</th>
#       <td>Albrand, Martha</td>
#       <td>1950</td>
#       <td>andre kvinnen</td>
#       <td>107377.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2010070505015</th>
#       <td>Alcott, Louisa May</td>
#       <td>1951</td>
#       <td>Småfrøkner</td>
#       <td>43664.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008050504059</th>
#       <td>Altsheler, Joseph A.</td>
#       <td>1952</td>
#       <td>siste høvding</td>
#       <td>48468.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011112308150</th>
#       <td>Ariane</td>
#       <td>1952</td>
#       <td>Petter Harepus</td>
#       <td>1070.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2013021513004</th>
#       <td>Babcock, Dwight V.</td>
#       <td>1950</td>
#       <td>Hannas hobby</td>
#       <td>119073.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2016110248042</th>
#       <td>Babcock, Ruth</td>
#       <td>1950</td>
#       <td>Julie</td>
#       <td>133425.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2012010508050</th>
#       <td>Baird, Catherine</td>
#       <td>1952</td>
#       <td>Guds rike hører sådanne til</td>
#       <td>36609.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2012020908142</th>
#       <td>Ballantyne, R.M.</td>
#       <td>1952</td>
#       <td>Koralløya</td>
#       <td>69754.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011111108159</th>
#       <td>Barber, D. H.</td>
#       <td>1951</td>
#       <td>Afrika i kaki</td>
#       <td>37382.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2007020101088</th>
#       <td>Barea, Arturo</td>
#       <td>1950</td>
#       <td>Smia</td>
#       <td>139961.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2012052308129</th>
#       <td>Barnes, Clare</td>
#       <td>1950</td>
#       <td>På kontoret</td>
#       <td>1641.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011111108033</th>
#       <td>Barrie, J.M.</td>
#       <td>1951</td>
#       <td>Peter Pan og Wendy</td>
#       <td>24735.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008050801005</th>
#       <td>Bates, H.E.</td>
#       <td>1951</td>
#       <td>Det blodrøde sverd</td>
#       <td>79265.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011112808016</th>
#       <td>Beach, Rex</td>
#       <td>1952</td>
#       <td>Jernbanekongens sønn</td>
#       <td>92189.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011030220006</th>
#       <td>Beach, Rex</td>
#       <td>1950</td>
#       <td>Broen</td>
#       <td>91899.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008042800103</th>
#       <td>Beach, Rex</td>
#       <td>1952</td>
#       <td>Skranken</td>
#       <td>63269.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2015012708019</th>
#       <td>Beach, Rex</td>
#       <td>1952</td>
#       <td>Rivaler</td>
#       <td>83835.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008050504015</th>
#       <td>Bell, Sallie Lee</td>
#       <td>1951</td>
#       <td>Til dagen gryr</td>
#       <td>74426.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008050800079</th>
#       <td>Bennett, Arnold</td>
#       <td>1952</td>
#       <td>Levende begravet</td>
#       <td>58690.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2013042508071</th>
#       <td>Bennett, Arnold</td>
#       <td>1951</td>
#       <td>Sølvpengene</td>
#       <td>60956.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011031120028</th>
#       <td>Boardman, Anshelm</td>
#       <td>1950</td>
#       <td>Gullhunden</td>
#       <td>25743.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2007012601085</th>
#       <td>Bodley, R. V. C.</td>
#       <td>1950</td>
#       <td>Muhammed</td>
#       <td>148085.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2010111006085</th>
#       <td>Boswell, James</td>
#       <td>1951</td>
#       <td>Samuel Johnsons liv</td>
#       <td>188330.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008042400035</th>
#       <td>Bourke-White, Margaret</td>
#       <td>1951</td>
#       <td>Gjennom India</td>
#       <td>92547.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2016051148033</th>
#       <td>Bourne, Peter</td>
#       <td>1952</td>
#       <td>Høyt spill</td>
#       <td>176603.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008050801012</th>
#       <td>Brenan, Gerald</td>
#       <td>1951</td>
#       <td>Spanias ansikt</td>
#       <td>90403.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008042400045</th>
#       <td>Bridges, T. C.</td>
#       <td>1951</td>
#       <td>Dåd og djervskap</td>
#       <td>40129.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008042404035</th>
#       <td>Bristow, Gwen</td>
#       <td>1951</td>
#       <td>På spor etter lykken</td>
#       <td>274784.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2012022305002</th>
#       <td>Bromfield, Louis</td>
#       <td>1952</td>
#       <td>24 timer</td>
#       <td>113596.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011050604056</th>
#       <td>Bromfield, Louis</td>
#       <td>1952</td>
#       <td>Mr. Smith</td>
#       <td>105855.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2014020626014</th>
#       <td>Brown, Margaret Wise</td>
#       <td>1951</td>
#       <td>Malerkattene</td>
#       <td>725.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011111708178</th>
#       <td>Bruce, Dorita Fairlie</td>
#       <td>1951</td>
#       <td>Dimsie på pensjonatskole</td>
#       <td>56766.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011112808013</th>
#       <td>Buchman, Frank</td>
#       <td>1952</td>
#       <td>Slik begynte det</td>
#       <td>6901.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008042904029</th>
#       <td>Buck, Pearl S.</td>
#       <td>1952</td>
#       <td>Guds menn</td>
#       <td>192616.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2010111005023</th>
#       <td>Buck, Pearl S.</td>
#       <td>1952</td>
#       <td>Frender</td>
#       <td>172862.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2013080908129</th>
#       <td>Burroughs, Edgar R.</td>
#       <td>1951</td>
#       <td>Tarzan og den gylne løva</td>
#       <td>46125.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011121408001</th>
#       <td>Burroughs, Edgar Rice</td>
#       <td>1950</td>
#       <td>Tarzan vender tilbake</td>
#       <td>48398.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008051400064</th>
#       <td>Butterfield, Herbert</td>
#       <td>1952</td>
#       <td>Kristendommen og historien</td>
#       <td>48258.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2006110800013</th>
#       <td>Cain, James M.</td>
#       <td>1951</td>
#       <td>Postbudet ringer alltid to ganger</td>
#       <td>47278.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2008050900008</th>
#       <td>Caine, Hall</td>
#       <td>1952</td>
#       <td>Hagars sønn</td>
#       <td>108627.0</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2011032520034</th>
#       <td>Caldwell, Erskine</td>
#       <td>1950</td>
#       <td>Himmellosen</td>
#       <td>68

# %% [markdown]
# ## Search corpus for concordances

# %%
from random import sample

# %%
nb.get_urnkonk('gråtende', {'urns':sample(korpus, 50)})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032520029?searchText=gråtende' target='_blank' style='text-decoration:none'>Giftbanden som truet London, Fletcher, J.S., 1950</a>
#                 </td>
#                 <td>kvinnelige tjenere , — alle</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008050900008?searchText=gråtende' target='_blank' style='text-decoration:none'>Hagars sønn, Caine, Hall, 1952</a>
#                 </td>
#                 <td>! » sa arrestanten med</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>stemme . « Paul ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008050900008?searchText=gråtende' target='_blank' style='text-decoration:none'>Hagars sønn, Caine, Hall, 1952</a>
#                 </td>
#                 <td>var som en engel gikk</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>forbi .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008050900008?searchText=gråtende' target='_blank' style='text-decoration:none'>Hagars sønn, Caine, Hall, 1952</a>
#                 </td>
#                 <td>Greta kom ut med en</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>liten gutt på armen .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008042104049?searchText=gråtende' target='_blank' style='text-decoration:none'>Kjærlighet over alle grenser, Galsworthy, John, 1951</a>
#                 </td>
#                 <td>av seg da Betty kom</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>inn til henne . «</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008042104049?searchText=gråtende' target='_blank' style='text-decoration:none'>Kjærlighet over alle grenser, Galsworthy, John, 1951</a>
#                 </td>
#                 <td>Hvis hun tenkte på det</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>barnet , visste hun at</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011112308153?searchText=gråtende' target='_blank' style='text-decoration:none'>Natten og byen, Kersh, Gerald, 1951</a>
#                 </td>
#                 <td>som du er nå ,</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>over en fordømt flaske .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008051404091?searchText=gråtende' target='_blank' style='text-decoration:none'>tjenende ånd, Wodehouse, P.G., 1952</a>
#                 </td>
#                 <td>Å omfavne en</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>ung pike som sitter bak</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011111608113?searchText=gråtende' target='_blank' style='text-decoration:none'>Vrakgods, Valtin, Jan, 1951</a>
#                 </td>
#                 <td>tre stålklørne opp foran det</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>ansikt . Kurz loftet hendene</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011022320090?searchText=gråtende' target='_blank' style='text-decoration:none'>Arven, Croft-Cooke, Rupert, 1950</a>
#                 </td>
#                 <td>begravd ? » kom det</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>fra Maud . « Men</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012012708022?searchText=gråtende' target='_blank' style='text-decoration:none'>Lev livet uten bekymringer, Carnegie, Dale, 1950</a>
#                 </td>
#                 <td>fant en av offiserene ham</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>, og spurte hva som</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008042400035?searchText=gråtende' target='_blank' style='text-decoration:none'>Gjennom India, Bourke-White, Margaret, 1951</a>
#                 </td>
#                 <td>Vi forlot den</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>elefant og den sønneløse mahout</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011111508076?searchText=gråtende' target='_blank' style='text-decoration:none'>blanke klinge, Schoonover, Lawrence, 1951</a>
#                 </td>
#                 <td>presset dyrene ut gjennom den</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>og urolige menneskemassen .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011111508076?searchText=gråtende' target='_blank' style='text-decoration:none'>blanke klinge, Schoonover, Lawrence, 1951</a>
#                 </td>
#                 <td>, knelte ned og ba</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>ved siden av henne .</td>
#             </tr>
# </table>

# %% [markdown]
# # Definer teksten

# %% [markdown]
# Hen teksten - kan ta noe minutter. Kan lagres for senere bruk.

# %%
TEXT = nb.get_corpus_text(rammen.index)

# %%
with open ('korpus_file.csv','w',encoding="utf-8") as f:
    TEXT.to_csv(path_or_buf=f)

# %%
TEXT_NOB = nb.get_corpus_text(nb.frame(korpus_nob)[0])

# %% [markdown]
# #### convertet to md
# import pandas as pd
# with open ('korpus_file.csv','r', encoding="utf-8") as f:
#     text = pd.read_csv(f)

# %%
TEXT.sort_values(by=TEXT.columns[0], ascending=False)[:10]
# Out:
#      2011031720018  2016060848216  2012022305002  2011111108159  \
# ,           5892.0         5321.0         4845.0         1877.0
# .           2958.0         5994.0         5258.0         1490.0
# og          2681.0         3024.0         4744.0         1175.0
# :           2430.0          155.0          472.0           38.0
# som         1897.0         2104.0         1650.0          616.0
# i           1715.0         2252.0         1765.0          835.0
# er          1661.0          955.0          573.0          195.0
# det         1485.0         2603.0         1961.0          639.0
# til         1448.0         1369.0         1419.0          587.0
# «           1328.0          151.0          112.0           37.0
#
#      2007012601033  2008042804073  2011022320092  2011022320090  \
# ,           3080.0         2331.0         3169.0         3659.0
# .           2710.0         3605.0         3425.0         6143.0
# og          1623.0         2152.0         2200.0         1944.0
# :            179.0          200.0           28.0           70.0
# som         1158.0          800.0          726.0         1009.0
# i           1729.0         1235.0         1121.0         1356.0
# er           829.0          262.0          711.0         1010.0
# det         1090.0         1221.0         1495.0         2185.0
# til         1161.0         1205.0          914.0         1372.0
# «            625.0           94.0           42.0         1930.0
#
#      2013013108105  2008042804098      ...        2013092308000  \
# ,           2160.0         8553.0      ...                 16.0
# .           1667.0         9072.0      ...                 30.0
# og          1565.0         4857.0      ...                 16.0
# :             41.0          262.0      ...                  1.0
# som          414.0         2748.0      ...                  4.0
# i            738.0         3385.0      ...                  5.0
# er           251.0         5070.0      ...                  4.0
# det          680.0         4120.0      ...                  4.0
# til          512.0         3027.0      ...                  4.0
# «             27.0          335.0      ...                 19.0
#
#      2008050504059  2008051404099  2010070506039  2011102108219  \
# ,           2688.0         2750.0        11509.0         2529.0
# .           2491.0         3495.0        13372.0         2967.0
# og          1654.0         1951.0         6095.0         2065.0
# :             70.0          114.0          246.0           32.0
# som          438.0          897.0         2574.0          611.0
# i            723.0         1097.0         3914.0         1061.0
# er           252.0          424.0         1776.0          198.0
# det         1053.0         1029.0         3279.0          745.0
# til          563.0          800.0         2255.0          931.0
# «            516.0         1446.0          105.0          656.0
#
#      2008051404091  2008041804072  2008042504034  2011050420019  2007020201061
# ,           2723.0         2332.0         3851.0         1974.0          979.0
# .           5012.0         3096.0         5058.0         4366.0          954.0
# og          1433.0         1227.0         3250.0         1352.0          434.0
# :             52.0          248.0           78.0           85.0           66.0
# som          927.0          699.0          935.0          648.0          283.0
# i           1173.0          771.0         1734.0          987.0          359.0
# er           664.0          434.0          919.0          536.0          520.0
# det         1274.0          925.0         1600.0          921.0          377.0
# til          930.0          709.0         1254.0          741.0          259.0
# «           2421.0         1320.0         2219.0           22.0           91.0
#
# [10 rows x 300 columns]

# %% [markdown]
# ### Starter med listen over mulige partisipper

# %%
poss_part = list ({x for x in TEXT.index if x.endswith('ende')})

# %% [markdown]
# ### Henter ut de 100 mest frekvente

# %%
N = 100
test_words = list(TEXT.loc[poss_part].sum(axis=1).sort_values(ascending=False)[:N].index)

# %%
variants = dict()
for w in test_words:
    variants[w] = nb.word_paradigm(w)

# %%
forms = dict()
for w in test_words:
    forms[w] = nb.word_form(w)

# %%
nb.frame(variants)
# Out:
#                                                                 0  \
# stående                           [adj, [stående, stått, ståtte]]
# sende                            [adj, [sendende, sendt, sendte]]
# levende         [adj, [levd, levde, levede, levende, levet, le...
# hende                     [adj, [hendende, hendt, hendte, hende]]
# rasende                       [adj, [rasa, rasende, rast, raste]]
# ende                                [adj, [endende, endt, endte]]
# strålende                     [adj, [strålende, strålt, strålte]]
# sittende                 [adj, [sitne, sitten, sittende, sittet]]
# liggende                 [adj, [liggen, liggende, ligget, ligne]]
# vende                            [adj, [vendende, vendt, vendte]]
# følgende          [adj, [følgende, følgt, følgte, fulgt, fulgte]]
# smilende                         [adj, [smilende, smilt, smilte]]
# skinnende                       [adj, [skinnende, skint, skinte]]
# skjelvende      [adj, [skjelven, skjelvende, skjelvet, skjelvne]]
# tilsynelatende                            [adj, [tilsynelatende]]
# brennende                       [adj, [brennende, brent, brente]]
# utseende                       [adj, [utseende, utsett, utsette]]
# gående                               [adj, [gående, gått, gåtte]]
# spennende                       [adj, [spennende, spent, spente]]
# fiende               [subs, [fiende, fienden, fiendene, fiender]]
# truende         [adj, [trudd, trudde, truende, trua, truede, t...
# lignende        [adj, [ligna, lignede, lignende, lignet, ligne...
# avgjørende                 [adj, [avgjort, avgjorte, avgjørende]]
# nåværende                                      [adj, [nåværende]]
# passende        [adj, [passa, passede, passende, passet, passe...
# vedkommende     [adj, [vedkommen, vedkommende, vedkommet, vedk...
# forbausende     [adj, [forbausa, forbausede, forbausende, forb...
# hengende                         [adj, [hengende, hengt, hengte]]
# løpende                      [adj, [løpende, løpet, løpt, løpte]]
# glimrende       [adj, [glimra, glimrede, glimrende, glimret, g...
# ...                                                           ...
# tiltalende        [adj, [tiltala, tiltalende, tiltalt, tiltalte]]
# glitrende       [adj, [glitra, glitrede, glitrende, glitret, g...
# skremmende                   [adj, [skremmende, skremt, skremte]]
# bebreidende     [adj, [bebreida, bebreidede, bebreidende, bebr...
# kommende                 [adj, [kommen, kommende, kommet, komne]]
# stigende                [adj, [stegen, steget, stegne, stigende]]
# utfordrende     [adj, [utfordra, utfordrede, utfordrende, utfo...
# overbevisende     [adj, [overbevisende, overbevist, overbeviste]]
# middelaldrende                            [adj, [middelaldrende]]
# sjarmerende             [adj, [sjarmerende, sjarmert, sjarmerte]]
# styrtende       [adj, [styrta, styrtede, styrtende, styrtet, s...
# inngående                   [adj, [inngående, inngått, inngåtte]]
# undersøkende         [adj, [undersøkende, undersøkt, undersøkte]]
# trettende       [adj, [tretta, trettede, trettende, trettet, t...
# dominerende             [adj, [dominerende, dominert, dominerte]]
# blendende       [adj, [blenda, blendede, blendende, blendet, b...
# skrikende           [adj, [skreken, skreket, skrekne, skrikende]]
# sovende                     [adj, [soven, sovende, sovet, sovne]]
# farende                             [adj, [farende, fart, farte]]
# åndsfraværende                            [adj, [åndsfraværende]]
# forbløffende    [adj, [forbløffa, forbløffede, forbløffende, f...
# fortryllende    [adj, [fortrylla, fortryllede, fortryllende, f...
# foregående               [adj, [foregående, foregått, foregåtte]]
# granskende      [adj, [granska, granskede, granskende, granske...
# overbærende                                  [adj, [overbærende]]
# irriterende             [adj, [irriterende, irritert, irriterte]]
# grunnleggende       [adj, [grunnlagt, grunnlagte, grunnleggende]]
# voksende        [adj, [voksa, voksede, voksende, vokset, vokse...
# trykkende       [adj, [trykka, trykkede, trykkende, trykket, t...
# medfølende                                                   None
#
#                                                                 1  \
# stående         [verb, [sto, stod, stå, ståes, står, stås, stå...
# sende           [verb, [send, sende, sender, sendes, sendt, se...
# levende         [verb, [lev, levd, levde, leve, lever, leves, ...
# hende             [subs, [henda, hende, hendene, hender, hendet]]
# rasende                                          [adv, [rasende]]
# ende                                                [adv, [ende]]
# strålende       [verb, [strål, stråle, stråler, stråles, strål...
# sittende        [verb, [satt, sitt, sitte, sitter, sittes, sit...
# liggende        [verb, [ligg, ligge, ligger, ligges, ligget, l...
# vende             [subs, [venda, vende, venden, vendene, vender]]
# følgende        [verb, [følg, følgje, følgjer, følgjes, følgt,...
# smilende        [verb, [smil, smile, smiler, smiles, smilt, sm...
# skinnende       [verb, [skein, skinn, skinne, skinner, skinnes...
# skjelvende      [verb, [skalv, skjelv, skjelve, skjelver, skje...
# tilsynelatende                                               None
# brennende       [verb, [brenn, brenne, brenner, brennes, brent...
# utseende        [subs, [utseende, utseendene, utseender, utsee...
# gående            [verb, [gikk, gjekk, gå, gåes, går, gås, gått]]
# spennende       [verb, [spenn, spenne, spenner, spennes, spent...
# fiende                                                       None
# truende         [verb, [tru, trudd, trudde, trur, trus, trua, ...
# lignende        [verb, [lign, ligna, ligne, ligner, lignes, li...
# avgjørende      [verb, [avgjorde, avgjort, avgjør, avgjøre, av...
# nåværende                                                    None
# passende        [verb, [pass, passa, passe, passer, passes, pa...
# vedkommende                                 [subs, [vedkommende]]
# forbausende     [verb, [forbaus, forbausa, forbause, forbauser...
# hengende        [verb, [heng, henge, henger, henges, hengt, he...
# løpende            [verb, [løp, løpe, løper, løpes, løpet, løpt]]
# glimrende       [verb, [glimr, glimra, glimre, glimrer, glimre...
# ...                                                           ...
# tiltalende      [verb, [tiltal, tiltala, tiltale, tiltaler, ti...
# glitrende       [verb, [glitr, glitra, glitre, glitrer, glitre...
# skremmende      [verb, [skrem, skremme, skremmer, skremmes, sk...
# bebreidende     [verb, [bebreid, bebreida, bebreide, bebreider...
# kommende             [verb, [kom, komme, kommer, kommes, kommet]]
# stigende        [verb, [steg, steget, steig, stig, stige, stig...
# utfordrende     [verb, [utfordr, utfordra, utfordre, utfordrer...
# overbevisende   [verb, [overbevis, overbevise, overbeviser, ov...
# middelaldrende                                               None
# sjarmerende     [verb, [sjarmer, sjarmere, sjarmerer, sjarmere...
# styrtende       [verb, [styrt, styrta, styrte, styrter, styrte...
# inngående                                     [subs, [inngående]]
# undersøkende    [verb, [undersøk, undersøke, undersøker, under...
# trettende       [verb, [trett, tretta, trette, tretter, trette...
# dominerende     [verb, [dominer, dominere, dominerer, dominere...
# blendende       [verb, [blend, blenda, blende, blender, blende...
# skrikende       [verb, [skreik, skrek, skreket, skrik, skrike,...
# sovende                  [verb, [sov, sove, sover, soves, sovet]]
# farende              [verb, [far, fare, farer, fares, fart, for]]
# åndsfraværende                                               None
# forbløffende    [verb, [forbløff, forbløffa, forbløffe, forblø...
# fortryllende    [verb, [fortryll, fortrylla, fortrylle, fortry...
# foregående      [verb, [foregikk, foregjekk, foregå, foregåes,...
# granskende      [verb, [gransk, granska, granske, gransker, gr...
# overbærende                                                  None
# irriterende     [verb, [irriter, irritere, irriterer, irritere...
# grunnleggende   [verb, [grunnla, grunnlagt, grunnlegg, grunnle...
# voksende        [verb, [voks, voksa, vokse, vokser, vokses, vo...
# trykkende       [verb, [trykk, trykka, trykke, trykker, trykke...
# medfølende                                                   None
#
#                                                                 2  \
# stående                                                      None
# sende                                                        None
# levende                                                      None
# hende           [verb, [hend, hende, hender, hendes, hendt, he...
# rasende         [verb, [ras, rasa, rase, raser, rases, rast, r...
# ende                         [subs, [ende, enden, endene, ender]]
# strålende                                                    None
# sittende                                                     None
# liggende                                                     None
# vende           [verb, [vend, vende, vender, vendes, vendt, ve...
# følgende                                                     None
# smilende                                                     None
# skinnende                                                    None
# skjelvende                                                   None
# tilsynelatende                                               None
# brennende                                                    None
# utseende        [verb, [utse, utsees, utser, utses, utsett, ut...
# gående                                                       None
# spennende                                                    None
# fiende                                                       None
# truende                                                      None
# lignende                                                     None
# avgjørende                                                   None
# nåværende                                                    None
# passende                                                     None
# vedkommende     [verb, [vedkom, vedkomme, vedkommer, vedkommes...
# forbausende                                                  None
# hengende                                                     None
# løpende                                                      None
# glimrende                                                    None
# ...                                                           ...
# tiltalende                                                   None
# glitrende                                                    None
# skremmende                                                   None
# bebreidende                                                  None
# kommende                                                     None
# stigende                                                     None
# utfordrende                                                  None
# overbevisende                                                None
# middelaldrende                                               None
# sjarmerende                                                  None
# styrtende                                                    None
# inngående       [verb, [inngikk, inngjekk, inngå, inngåes, inn...
# undersøkende                                                 None
# trettende                                                    None
# dominerende                                                  None
# blendende                                                    None
# skrikende                                                    None
# sovende                                                      None
# farende                                                      None
# åndsfraværende                                               None
# forbløffende                                                 None
# fortryllende                                                 None
# foregående                                                   None
# granskende                                                   None
# overbærende                                                  None
# irriterende                                                  None
# grunnleggende                                                None
# voksende                                                     None
# trykkende                                                    None
# medfølende                                                   None
#
#                                                              3
# stående                                                   None
# sende                                                     None
# levende                                                   None
# hende                                                     None
# rasende                                                   None
# ende            [verb, [end, ende, ender, endes, endt, endte]]
# strålende                                                 None
# sittende                                                  None
# liggende                                                  None
# vende                                                     None
# følgende                                                  None
# smilende                                                  None
# skinnende                                                 None
# skjelvende                                                None
# tilsynelatende                                            None
# brennende                                                 None
# utseende                                                  None
# gående                                                    None
# spennende                                                 None
# fiende                                                    None
# truende                                                   None
# lignende                                                  None
# avgjørende                                                None
# nåværende                                                 None
# passende                                                  None
# vedkommende                                               None
# forbausende                                               None
# hengende                                                  None
# løpende                                                   None
# glimrende                                                 None
# ...                                                        ...
# tiltalende                                                None
# glitrende                                                 None
# skremmende                                                None
# bebreidende                                               None
# kommende                                                  None
# stigende                                                  None
# utfordrende                                               None
# overbevisende                                             None
# middelaldrende                                            None
# sjarmerende                                               None
# styrtende                                                 None
# inngående                                                 None
# undersøkende                                              None
# trettende                                                 None
# dominerende                                               None
# blendende                                                 None
# skrikende                                                 None
# sovende                                                   None
# farende                                                   None
# åndsfraværende                                            None
# forbløffende                                              None
# fortryllende                                              None
# foregående                                                None
# granskende                                                None
# overbærende                                               None
# irriterende                                               None
# grunnleggende                                             None
# voksende                                                  None
# trykkende                                                 None
# medfølende                                                None
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Velg former
#
# Plukk ut partisippformene, dersom formen opptrer både som adjektiv og som verb, ellers ut. Nedenfor plukkes ut de alternative verbformene som kan sammenlignes med partisippen.
#
# Her benyttes en enkelt heuristikk. Partisippformen må være oppført både som et adjektiv og et verb, i tillegg må ikke formen selv være blandt verbene.

# %%
participles = dict()
for w in variants:
    # finn POS for alle variantene
    kinds = [x[0] for x in variants[w]]
    
    # sjekk at både adj og verb er blant dem
    if 'adj' and 'verb' in kinds:
        
        # Ta ut de som har formen blant verbene (partisippet er ikke verd i NO)
        F = [k[1] for k in variants[w] if k[0] == 'verb' and not w in k[1] ]
        if F != []:
            participles[w] = F

# %% [markdown]
# ## Se på resultatet

# %%
participles
# Out:
# {'stående': [['sto', 'stod', 'stå', 'ståes', 'står', 'stås', 'stått']],
#  'levende': [['lev', 'levd', 'levde', 'leve', 'lever', 'leves', 'levet']],
#  'rasende': [['ras', 'rasa', 'rase', 'raser', 'rases', 'rast', 'raste']],
#  'strålende': [['strål', 'stråle', 'stråler', 'stråles', 'strålt', 'strålte']],
#  'sittende': [['satt', 'sitt', 'sitte', 'sitter', 'sittes', 'sittet']],
#  'liggende': [['ligg', 'ligge', 'ligger', 'ligges', 'ligget', 'lå', 'låg']],
#  'følgende': [['følg',
#    'følgje',
#    'følgjer',
#    'følgjes',
#    'følgt',
#    'følgte',
#    'fulgt',
#    'fulgte',
#    'følge',
#    'følger',
#    'følges']],
#  'smilende': [['smil', 'smile', 'smiler', 'smiles', 'smilt', 'smilte']],
#  'skinnende': [['skein',
#    'skinn',
#    'skinne',
#    'skinner',
#    'skinnes',
#    'skint',
#    'skinte']],
#  'skjelvende': [['skalv',
#    'skjelv',
#    'skjelve',
#    'skjelver',
#    'skjelves',
#    'skjelvet']],
#  'brennende': [['brenn',
#    'brenne',
#    'brenner',
#    'brennes',
#    'brent',
#    'brente',
#    'brann',
#    'brant']],
#  'utseende': [['utse', 'utsees', 'utser', 'utses', 'utsett', 'utså', 'utsåg']],
#  'gående': [['gikk', 'gjekk', 'gå', 'gåes', 'går', 'gås', 'gått']],
#  'spennende': [['spenn', 'spenne', 'spenner', 'spennes', 'spent', 'spente']],
#  'truende': [['tru',
#    'trudd',
#    'trudde',
#    'trur',
#    'trus',
#    'trua',
#    'true',
#    'truer',
#    'trues',
#    'truet']],
#  'lignende': [['lign', 'ligna', 'ligne', 'ligner', 'lignes', 'lignet']],
#  'avgjørende': [['avgjorde', 'avgjort', 'avgjør', 'avgjøre', 'avgjøres']],
#  'passende': [['pass', 'passa', 'passe', 'passer', 'passes', 'passet']],
#  'vedkommende': [['vedkom',
#    'vedkomme',
#    'vedkommer',
#    'vedkommes',
#    'vedkommet']],
#  'forbausende': [['forbaus',
#    'forbausa',
#    'forbause',
#    'forbauser',
#    'forbauses',
#    'forbauset']],
#  'hengende': [['heng',
#    'henge',
#    'henger',
#    'henges',
#    'hengt',
#    'hengte',
#    'hang']],
#  'løpende': [['løp', 'løpe', 'løper', 'løpes', 'løpet', 'løpt']],
#  'glimrende': [['glimr', 'glimra', 'glimre', 'glimrer', 'glimres', 'glimret']],
#  'utelukkende': [['utelukk',
#    'utelukka',
#    'utelukke',
#    'utelukker',
#    'utelukkes',
#    'utelukket']],
#  'spørrende': [['spurt', 'spurte', 'spør', 'spørre', 'spørres']],
#  'angående': [['angikk',
#    'angjekk',
#    'angå',
#    'angåes',
#    'angår',
#    'angås',
#    'angått']],
#  'ledende': [['led', 'leda', 'lede', 'leder', 'ledes', 'ledet']],
#  'oppmuntrende': [['oppmuntr',
#    'oppmuntra',
#    'oppmuntre',
#    'oppmuntrer',
#    'oppmuntres',
#    'oppmuntret']],
#  'beroligende': [['berolig',
#    'beroliga',
#    'berolige',
#    'beroliger',
#    'beroliges',
#    'beroliget']],
#  'glødende': [['glød',
#    'gløda',
#    'glødd',
#    'glødde',
#    'gløde',
#    'gløder',
#    'glødes',
#    'glødet']],
#  'overraskende': [['overrask',
#    'overraska',
#    'overraske',
#    'overrasker',
#    'overraskes',
#    'overrasket']],
#  'triumferende': [['triumfer',
#    'triumfere',
#    'triumferer',
#    'triumferes',
#    'triumfert',
#    'triumferte']],
#  'imponerende': [['imponer',
#    'imponere',
#    'imponerer',
#    'imponeres',
#    'imponert',
#    'imponerte']],
#  'overveldende': [['overveld',
#    'overvelda',
#    'overvelde',
#    'overvelder',
#    'overveldes',
#    'overveldet']],
#  'flytende': [['flaut',
#    'flyt',
#    'flyte',
#    'flyter',
#    'flytes',
#    'flytt',
#    'fløt',
#    'fløyt']],
#  'lysende': [['lys', 'lyse', 'lyser', 'lyses', 'lyst', 'lyste']],
#  'gjennomtrengende': [['gjennomtreng',
#    'gjennomtrenge',
#    'gjennomtrenger',
#    'gjennomtrenges',
#    'gjennomtrengt',
#    'gjennomtrengte']],
#  'tilfredsstillende': [['tilfredsstill',
#    'tilfredsstille',
#    'tilfredsstiller',
#    'tilfredsstilles',
#    'tilfredsstilt',
#    'tilfredsstilte']],
#  'anstrengende': [['anstreng',
#    'anstrenge',
#    'anstrenger',
#    'anstrenges',
#    'anstrengt',
#    'anstrengte']],
#  'skingrende': [['skingr',
#    'skingra',
#    'skingre',
#    'skingrer',
#    'skingres',
#    'skingret']],
#  'omfattende': [['omfatt',
#    'omfatta',
#    'omfatte',
#    'omfatter',
#    'omfattes',
#    'omfattet']],
#  'døende': [['dø', 'dødd', 'dødde', 'døde', 'dør', 'døs']],
#  'liknende': [['likn', 'likna', 'likne', 'likner', 'liknes', 'liknet']],
#  'flammende': [['flam', 'flamma', 'flamme', 'flammer', 'flammes', 'flammet']],
#  'ridende': [['red', 'rei', 'reid', 'rid', 'ridd', 'ride', 'rider', 'rides']],
#  'gjeldende': [['gjeld',
#    'gjelda',
#    'gjelde',
#    'gjelder',
#    'gjeldes',
#    'gjeldet',
#    'gjeldt',
#    'gjeldte',
#    'galdt',
#    'gjaldt',
#    'gjelds']],
#  'reisende': [['reis', 'reise', 'reiser', 'reises', 'reist', 'reiste']],
#  'ertende': [['ert', 'erta', 'erte', 'erter', 'ertes', 'ertet']],
#  'tilsvarende': [['tilsvar',
#    'tilsvara',
#    'tilsvare',
#    'tilsvarer',
#    'tilsvares',
#    'tilsvart',
#    'tilsvarte']],
#  'hviskende': [['hvisk', 'hviska', 'hviske', 'hvisker', 'hviskes', 'hvisket']],
#  'leende': [['le',
#    'ledd',
#    'ler',
#    'les',
#    'lo',
#    'lea',
#    'lee',
#    'leer',
#    'lees',
#    'leet']],
#  'nølende': [['nøl', 'nøle', 'nøler', 'nøles', 'nølt', 'nølte']],
#  'tiltrekkende': [['tiltrakk',
#    'tiltrekk',
#    'tiltrekke',
#    'tiltrekker',
#    'tiltrekkes',
#    'tiltrukket']],
#  'advarende': [['advar', 'advare', 'advarer', 'advares', 'advart', 'advarte']],
#  'beundrende': [['beundr',
#    'beundra',
#    'beundre',
#    'beundrer',
#    'beundres',
#    'beundret']],
#  'rørende': [['rør', 'røre', 'rører', 'røres', 'rørt', 'rørte']],
#  'tiltalende': [['tiltal',
#    'tiltala',
#    'tiltale',
#    'tiltaler',
#    'tiltales',
#    'tiltalt',
#    'tiltalte']],
#  'glitrende': [['glitr', 'glitra', 'glitre', 'glitrer', 'glitres', 'glitret']],
#  'skremmende': [['skrem',
#    'skremme',
#    'skremmer',
#    'skremmes',
#    'skremt',
#    'skremte']],
#  'bebreidende': [['bebreid',
#    'bebreida',
#    'bebreide',
#    'bebreider',
#    'bebreides',
#    'bebreidet']],
#  'kommende': [['kom', 'komme', 'kommer', 'kommes', 'kommet']],
#  'stigende': [['steg',
#    'steget',
#    'steig',
#    'stig',
#    'stige',
#    'stiger',
#    'stiges']],
#  'utfordrende': [['utfordr',
#    'utfordra',
#    'utfordre',
#    'utfordrer',
#    'utfordres',
#    'utfordret']],
#  'overbevisende': [['overbevis',
#    'overbevise',
#    'overbeviser',
#    'overbevises',
#    'overbevist',
#    'overbeviste']],
#  'sjarmerende': [['sjarmer',
#    'sjarmere',
#    'sjarmerer',
#    'sjarmeres',
#    'sjarmert',
#    'sjarmerte']],
#  'styrtende': [['styrt', 'styrta', 'styrte', 'styrter', 'styrtes', 'styrtet']],
#  'inngående': [['inngikk',
#    'inngjekk',
#    'inngå',
#    'inngåes',
#    'inngår',
#    'inngås',
#    'inngått']],
#  'undersøkende': [['undersøk',
#    'undersøke',
#    'undersøker',
#    'undersøkes',
#    'undersøkt',
#    'undersøkte']],
#  'trettende': [['trett', 'tretta', 'trette', 'tretter', 'trettes', 'trettet']],
#  'dominerende': [['dominer',
#    'dominere',
#    'dominerer',
#    'domineres',
#    'dominert',
#    'dominerte']],
#  'blendende': [['blend', 'blenda', 'blende', 'blender', 'blendes', 'blendet']],
#  'skrikende': [['skreik',
#    'skrek',
#    'skreket',
#    'skrik',
#    'skrike',
#    'skriker',
#    'skrikes']],
#  'sovende': [['sov', 'sove', 'sover', 'soves', 'sovet']],
#  'farende': [['far', 'fare', 'farer', 'fares', 'fart', 'for']],
#  'forbløffende': [['forbløff',
#    'forbløffa',
#    'forbløffe',
#    'forbløffer',
#    'forbløffes',
#    'forbløffet']],
#  'fortryllende': [['fortryll',
#    'fortrylla',
#    'fortrylle',
#    'fortryller',
#    'fortrylles',
#    'fortryllet',
#    'fortrylt',
#    'fortrylte']],
#  'foregående': [['foregikk',
#    'foregjekk',
#    'foregå',
#    'foregåes',
#    'foregår',
#    'foregås',
#    'foregått']],
#  'granskende': [['gransk',
#    'granska',
#    'granske',
#    'gransker',
#    'granskes',
#    'gransket']],
#  'irriterende': [['irriter',
#    'irritere',
#    'irriterer',
#    'irriteres',
#    'irritert',
#    'irriterte']],
#  'grunnleggende': [['grunnla',
#    'grunnlagt',
#    'grunnlegg',
#    'grunnlegge',
#    'grunnlegger',
#    'grunnlegges']],
#  'voksende': [['voks',
#    'voksa',
#    'vokse',
#    'vokser',
#    'vokses',
#    'vokset',
#    'vokst',
#    'vokste']],
#  'trykkende': [['trykk',
#    'trykka',
#    'trykke',
#    'trykker',
#    'trykkes',
#    'trykket',
#    'trykt',
#    'trykte']]}

# %% [markdown]
# Nå lager vi en ny statistikk der alle ordene telles opp fra datarammen for sammenligning

# %%
counts = dict()
for w in participles:
    counts[w] = TEXT.loc[list(set(participles[w][0]) & set(TEXT.index))].sum(axis=1).sum()

# %%
counts_nob = dict()
for w in participles:
    counts_nob[w] = TEXT_NOB.loc[list(set(participles[w][0]) & set(TEXT_NOB.index))].sum(axis=1).sum()

# %%
counts_nob
# Out:
# {'stående': 20132.0,
#  'levende': 5588.0,
#  'rasende': 402.0,
#  'strålende': 463.0,
#  'sittende': 16136.0,
#  'liggende': 14831.0,
#  'følgende': 5755.0,
#  'smilende': 3158.0,
#  'skinnende': 1080.0,
#  'skjelvende': 598.0,
#  'brennende': 1725.0,
#  'utseende': 101.0,
#  'gående': 39876.0,
#  'spennende': 882.0,
#  'truende': 3178.0,
#  'lignende': 761.0,
#  'avgjørende': 1169.0,
#  'passende': 2233.0,
#  'vedkommende': 127.0,
#  'forbausende': 312.0,
#  'hengende': 1974.0,
#  'løpende': 2614.0,
#  'glimrende': 20.0,
#  'utelukkende': 266.0,
#  'spørrende': 4315.0,
#  'angående': 440.0,
#  'ledende': 2095.0,
#  'oppmuntrende': 108.0,
#  'beroligende': 89.0,
#  'glødende': 213.0,
#  'overraskende': 176.0,
#  'triumferende': 49.0,
#  'imponerende': 103.0,
#  'overveldende': 64.0,
#  'flytende': 609.0,
#  'lysende': 5233.0,
#  'gjennomtrengende': 19.0,
#  'tilfredsstillende': 223.0,
#  'anstrengende': 139.0,
#  'skingrende': 30.0,
#  'omfattende': 1177.0,
#  'døende': 3848.0,
#  'liknende': 515.0,
#  'flammende': 296.0,
#  'ridende': 844.0,
#  'gjeldende': 7162.0,
#  'reisende': 7638.0,
#  'ertende': 656.0,
#  'tilsvarende': 70.0,
#  'hviskende': 846.0,
#  'leende': 22608.0,
#  'nølende': 90.0,
#  'tiltrekkende': 72.0,
#  'advarende': 181.0,
#  'beundrende': 263.0,
#  'rørende': 1277.0,
#  'tiltalende': 357.0,
#  'glitrende': 113.0,
#  'skremmende': 398.0,
#  'bebreidende': 149.0,
#  'kommende': 46857.0,
#  'stigende': 2981.0,
#  'utfordrende': 27.0,
#  'overbevisende': 408.0,
#  'sjarmerende': 11.0,
#  'styrtende': 721.0,
#  'inngående': 579.0,
#  'undersøkende': 900.0,
#  'trettende': 726.0,
#  'dominerende': 208.0,
#  'blendende': 88.0,
#  'skrikende': 1257.0,
#  'sovende': 1455.0,
#  'farende': 153448.0,
#  'forbløffende': 45.0,
#  'fortryllende': 6.0,
#  'foregående': 1547.0,
#  'granskende': 292.0,
#  'irriterende': 176.0,
#  'grunnleggende': 287.0,
#  'voksende': 2143.0,
#  'trykkende': 1965.0}

# %%
counts
# Out:
# {'stående': 36923.0,
#  'levende': 8255.0,
#  'rasende': 1132.0,
#  'strålende': 904.0,
#  'sittende': 35308.0,
#  'liggende': 22544.0,
#  'følgende': 11687.0,
#  'smilende': 11579.0,
#  'skinnende': 1789.0,
#  'skjelvende': 2135.0,
#  'brennende': 2949.0,
#  'utseende': 82.0,
#  'gående': 88301.0,
#  'spennende': 2025.0,
#  'truende': 1680.0,
#  'lignende': 1861.0,
#  'avgjørende': 1435.0,
#  'passende': 5642.0,
#  'vedkommende': 134.0,
#  'forbausende': 2678.0,
#  'hengende': 5147.0,
#  'løpende': 7930.0,
#  'glimrende': 21.0,
#  'utelukkende': 271.0,
#  'spørrende': 24449.0,
#  'angående': 958.0,
#  'ledende': 2996.0,
#  'oppmuntrende': 604.0,
#  'beroligende': 553.0,
#  'glødende': 567.0,
#  'overraskende': 1302.0,
#  'triumferende': 123.0,
#  'imponerende': 407.0,
#  'overveldende': 408.0,
#  'flytende': 955.0,
#  'lysende': 12891.0,
#  'gjennomtrengende': 51.0,
#  'tilfredsstillende': 422.0,
#  'anstrengende': 608.0,
#  'skingrende': 55.0,
#  'omfattende': 542.0,
#  'døende': 9231.0,
#  'liknende': 699.0,
#  'flammende': 862.0,
#  'ridende': 2955.0,
#  'gjeldende': 5746.0,
#  'reisende': 17050.0,
#  'ertende': 764.0,
#  'tilsvarende': 44.0,
#  'hviskende': 3472.0,
#  'leende': 8663.0,
#  'nølende': 798.0,
#  'tiltrekkende': 309.0,
#  'advarende': 844.0,
#  'beundrende': 1013.0,
#  'rørende': 3883.0,
#  'tiltalende': 409.0,
#  'glitrende': 361.0,
#  'skremmende': 1830.0,
#  'bebreidende': 451.0,
#  'kommende': 114309.0,
#  'stigende': 3913.0,
#  'utfordrende': 202.0,
#  'overbevisende': 1792.0,
#  'sjarmerende': 14.0,
#  'styrtende': 2241.0,
#  'inngående': 183.0,
#  'undersøkende': 2510.0,
#  'trettende': 4255.0,
#  'dominerende': 200.0,
#  'blendende': 201.0,
#  'skrikende': 4849.0,
#  'sovende': 5588.0,
#  'farende': 220205.0,
#  'forbløffende': 320.0,
#  'fortryllende': 59.0,
#  'foregående': 1814.0,
#  'granskende': 511.0,
#  'irriterende': 862.0,
#  'grunnleggende': 231.0,
#  'voksende': 2611.0,
#  'trykkende': 2585.0}

# %% [markdown]
# # Legg til opptellinger for partisippene

# %%
count_frame = dict()
for x in counts:
    count_frame[x] = {'verb_paradigm': counts[x], 'participle':TEXT.loc[x].sum()}

# %%
count_frame_nob = dict()
for x in counts_nob:
    count_frame_nob[x] = {'verb_paradigm': counts_nob[x], 'participle':TEXT_NOB.loc[x].sum()}

# %%
count_frame_nob
# Out:
# {'stående': {'verb_paradigm': 20132.0, 'participle': 1275.0},
#  'levende': {'verb_paradigm': 5588.0, 'participle': 1652.0},
#  'rasende': {'verb_paradigm': 402.0, 'participle': 357.0},
#  'strålende': {'verb_paradigm': 463.0, 'participle': 382.0},
#  'sittende': {'verb_paradigm': 16136.0, 'participle': 635.0},
#  'liggende': {'verb_paradigm': 14831.0, 'participle': 738.0},
#  'følgende': {'verb_paradigm': 5755.0, 'participle': 2581.0},
#  'smilende': {'verb_paradigm': 3158.0, 'participle': 263.0},
#  'skinnende': {'verb_paradigm': 1080.0, 'participle': 195.0},
#  'skjelvende': {'verb_paradigm': 598.0, 'participle': 137.0},
#  'brennende': {'verb_paradigm': 1725.0, 'participle': 254.0},
#  'utseende': {'verb_paradigm': 101.0, 'participle': 356.0},
#  'gående': {'verb_paradigm': 39876.0, 'participle': 360.0},
#  'spennende': {'verb_paradigm': 882.0, 'participle': 162.0},
#  'truende': {'verb_paradigm': 3178.0, 'participle': 172.0},
#  'lignende': {'verb_paradigm': 761.0, 'participle': 860.0},
#  'avgjørende': {'verb_paradigm': 1169.0, 'participle': 556.0},
#  'passende': {'verb_paradigm': 2233.0, 'participle': 413.0},
#  'vedkommende': {'verb_paradigm': 127.0, 'participle': 2978.0},
#  'forbausende': {'verb_paradigm': 312.0, 'participle': 151.0},
#  'hengende': {'verb_paradigm': 1974.0, 'participle': 179.0},
#  'løpende': {'verb_paradigm': 2614.0, 'participle': 246.0},
#  'glimrende': {'verb_paradigm': 20.0, 'participle': 178.0},
#  'utelukkende': {'verb_paradigm': 266.0, 'participle': 282.0},
#  'spørrende': {'verb_paradigm': 4315.0, 'participle': 140.0},
#  'angående': {'verb_paradigm': 440.0, 'participle': 553.0},
#  'ledende': {'verb_paradigm': 2095.0, 'participle': 424.0},
#  'oppmuntrende': {'verb_paradigm': 108.0, 'participle': 77.0},
#  'beroligende': {'verb_paradigm': 89.0, 'participle': 82.0},
#  'glødende': {'verb_paradigm': 213.0, 'participle': 145.0},
#  'overraskende': {'verb_paradigm': 176.0, 'participle': 138.0},
#  'triumferende': {'verb_paradigm': 49.0, 'participle': 64.0},
#  'imponerende': {'verb_paradigm': 103.0, 'participle': 126.0},
#  'overveldende': {'verb_paradigm': 64.0, 'participle': 115.0},
#  'flytende': {'verb_paradigm': 609.0, 'participle': 250.0},
#  'lysende': {'verb_paradigm': 5233.0, 'participle': 176.0},
#  'gjennomtrengende': {'verb_paradigm': 19.0, 'participle': 34.0},
#  'tilfredsstillende': {'verb_paradigm': 223.0, 'participle': 474.0},
#  'anstrengende': {'verb_paradigm': 139.0, 'participle': 59.0},
#  'skingrende': {'verb_paradigm': 30.0, 'participle': 35.0},
#  'omfattende': {'verb_paradigm': 1177.0, 'participle': 462.0},
#  'døende': {'verb_paradigm': 3848.0, 'participle': 103.0},
#  'liknende': {'verb_paradigm': 515.0, 'participle': 346.0},
#  'flammende': {'verb_paradigm': 296.0, 'participle': 82.0},
#  'ridende': {'verb_paradigm': 844.0, 'participle': 69.0},
#  'gjeldende': {'verb_paradigm': 7162.0, 'participle': 1156.0},
#  'reisende': {'verb_paradigm': 7638.0, 'participle': 293.0},
#  'ertende': {'verb_paradigm': 656.0, 'participle': 42.0},
#  'tilsvarende': {'verb_paradigm': 70.0, 'participle': 957.0},
#  'hviskende': {'verb_paradigm': 846.0, 'participle': 66.0},
#  'leende': {'verb_paradigm': 22608.0, 'participle': 84.0},
#  'nølende': {'verb_paradigm': 90.0, 'participle': 53.0},
#  'tiltrekkende': {'verb_paradigm': 72.0, 'participle': 27.0},
#  'advarende': {'verb_paradigm': 181.0, 'participle': 38.0},
#  'beundrende': {'verb_paradigm': 263.0, 'participle': 40.0},
#  'rørende': {'verb_paradigm': 1277.0, 'participle': 100.0},
#  'tiltalende': {'verb_paradigm': 357.0, 'participle': 96.0},
#  'glitrende': {'verb_paradigm': 113.0, 'participle': 50.0},
#  'skremmende': {'verb_paradigm': 398.0, 'participle': 47.0},
#  'bebreidende': {'verb_paradigm': 149.0, 'participle': 45.0},
#  'kommende': {'verb_paradigm': 46857.0, 'participle': 262.0},
#  'stigende': {'verb_paradigm': 2981.0, 'participle': 361.0},
#  'utfordrende': {'verb_paradigm': 27.0, 'participle': 49.0},
#  'overbevisende': {'verb_paradigm': 408.0, 'participle': 78.0},
#  'sjarmerende': {'verb_paradigm': 11.0, 'participle': 64.0},
#  'styrtende': {'verb_paradigm': 721.0, 'participle': 46.0},
#  'inngående': {'verb_paradigm': 579.0, 'participle': 271.0},
#  'undersøkende': {'verb_paradigm': 900.0, 'participle': 24.0},
#  'trettende': {'verb_paradigm': 726.0, 'participle': 32.0},
#  'dominerende': {'verb_paradigm': 208.0, 'participle': 261.0},
#  'blendende': {'verb_paradigm': 88.0, 'participle': 39.0},
#  'skrikende': {'verb_paradigm': 1257.0, 'participle': 54.0},
#  'sovende': {'verb_paradigm': 1455.0, 'participle': 79.0},
#  'farende': {'verb_paradigm': 153448.0, 'participle': 69.0},
#  'forbløffende': {'verb_paradigm': 45.0, 'participle': 60.0},
#  'fortryllende': {'verb_paradigm': 6.0, 'participle': 35.0},
#  'foregående': {'verb_paradigm': 1547.0, 'participle': 410.0},
#  'granskende': {'verb_paradigm': 292.0, 'participle': 42.0},
#  'irriterende': {'verb_paradigm': 176.0, 'participle': 56.0},
#  'grunnleggende': {'verb_paradigm': 287.0, 'participle': 140.0},
#  'voksende': {'verb_paradigm': 2143.0, 'participle': 145.0},
#  'trykkende': {'verb_paradigm': 1965.0, 'participle': 60.0}}

# %%
COUNTS = nb.frame(count_frame)

# %%
COUNTS_NOB = nb.frame(count_frame_nob)

# %% [markdown]
# Legg en ratio til

# %%
COUNTS['ratio'] = COUNTS['participle']/(COUNTS['participle']+COUNTS['verb_paradigm'])

# %%
COUNTS_NOB['ratio'] = COUNTS_NOB['participle']/(COUNTS_NOB['participle']+COUNTS_NOB['verb_paradigm'])

# %% [markdown]
# # Sortér på ratio
#
# Her ser vi klart at det kanskje ikke er ekte partisipper på topp, mer typiske ord i partisippform.
#
# De mest interessante ordene (tror jeg) er på bunnen her, som 'smilende', 'løpende', 'liggende', 'spørrende'. Og den ratioen kan sammenlignes med norsk sett.

# %%
COUNTS.sort_values(by='ratio', ascending=False)
# Out:
#                    verb_paradigm  participle     ratio
# glimrende                   21.0       550.0  0.963222
# sjarmerende                 14.0       251.0  0.947170
# utseende                    82.0       782.0  0.905093
# gjennomtrengende            51.0       366.0  0.877698
# tilsvarende                 44.0       292.0  0.869048
# skingrende                  55.0       330.0  0.857143
# vedkommende                134.0       626.0  0.823684
# fortryllende                59.0       222.0  0.790036
# triumferende               123.0       412.0  0.770093
# rasende                   1132.0      2345.0  0.674432
# strålende                  904.0      1719.0  0.655356
# utelukkende                271.0       499.0  0.648052
# inngående                  183.0       249.0  0.576389
# utfordrende                202.0       264.0  0.566524
# dominerende                200.0       240.0  0.545455
# blendende                  201.0       237.0  0.541096
# imponerende                407.0       403.0  0.497531
# overveldende               408.0       389.0  0.488080
# grunnleggende              231.0       215.0  0.482063
# tiltrekkende               309.0       286.0  0.480672
# tilfredsstillende          422.0       360.0  0.460358
# beroligende                553.0       445.0  0.445892
# glitrende                  361.0       276.0  0.433281
# glødende                   567.0       426.0  0.429003
# oppmuntrende               604.0       446.0  0.424762
# forbløffende               320.0       222.0  0.409594
# tiltalende                 409.0       279.0  0.405523
# omfattende                 542.0       330.0  0.378440
# bebreidende                451.0       272.0  0.376210
# anstrengende               608.0       341.0  0.359326
# ...                          ...         ...       ...
# overbevisende             1792.0       258.0  0.125854
# foregående                1814.0       222.0  0.109037
# styrtende                 2241.0       251.0  0.100722
# passende                  5642.0       627.0  0.100016
# hengende                  5147.0       560.0  0.098125
# følgende                 11687.0      1222.0  0.094663
# ridende                   2955.0       305.0  0.093558
# undersøkende              2510.0       245.0  0.088929
# stående                  36923.0      3357.0  0.083342
# smilende                 11579.0       999.0  0.079424
# hviskende                 3472.0       292.0  0.077577
# trykkende                 2585.0       214.0  0.076456
# voksende                  2611.0       215.0  0.076079
# rørende                   3883.0       283.0  0.067931
# løpende                   7930.0       552.0  0.065079
# stigende                  3913.0       265.0  0.063427
# liggende                 22544.0      1368.0  0.057210
# trettende                 4255.0       243.0  0.054024
# gjeldende                 5746.0       301.0  0.049777
# skrikende                 4849.0       234.0  0.046036
# sittende                 35308.0      1679.0  0.045394
# sovende                   5588.0       231.0  0.039698
# døende                    9231.0       328.0  0.034313
# leende                    8663.0       289.0  0.032283
# lysende                  12891.0       370.0  0.027901
# spørrende                24449.0       485.0  0.019451
# reisende                 17050.0       299.0  0.017234
# gående                   88301.0       778.0  0.008734
# kommende                114309.0       268.0  0.002339
# farende                 220205.0       227.0  0.001030
#
# [82 rows x 3 columns]

# %%
COUNTS_NOB.sort_values(by='ratio', ascending=False)
# Out:
#                    verb_paradigm  participle     ratio
# vedkommende                127.0      2978.0  0.959098
# tilsvarende                 70.0       957.0  0.931840
# glimrende                   20.0       178.0  0.898990
# fortryllende                 6.0        35.0  0.853659
# sjarmerende                 11.0        64.0  0.853333
# utseende                   101.0       356.0  0.778993
# tilfredsstillende          223.0       474.0  0.680057
# utfordrende                 27.0        49.0  0.644737
# overveldende                64.0       115.0  0.642458
# gjennomtrengende            19.0        34.0  0.641509
# forbløffende                45.0        60.0  0.571429
# triumferende                49.0        64.0  0.566372
# angående                   440.0       553.0  0.556898
# dominerende                208.0       261.0  0.556503
# imponerende                103.0       126.0  0.550218
# skingrende                  30.0        35.0  0.538462
# lignende                   761.0       860.0  0.530537
# utelukkende                266.0       282.0  0.514599
# beroligende                 89.0        82.0  0.479532
# rasende                    402.0       357.0  0.470356
# strålende                  463.0       382.0  0.452071
# overraskende               176.0       138.0  0.439490
# oppmuntrende               108.0        77.0  0.416216
# glødende                   213.0       145.0  0.405028
# liknende                   515.0       346.0  0.401858
# nølende                     90.0        53.0  0.370629
# grunnleggende              287.0       140.0  0.327869
# forbausende                312.0       151.0  0.326134
# avgjørende                1169.0       556.0  0.322319
# inngående                  579.0       271.0  0.318824
# ...                          ...         ...       ...
# brennende                 1725.0       254.0  0.128348
# granskende                 292.0        42.0  0.125749
# stigende                  2981.0       361.0  0.108019
# skremmende                 398.0        47.0  0.105618
# løpende                   2614.0       246.0  0.086014
# hengende                  1974.0       179.0  0.083140
# smilende                  3158.0       263.0  0.076878
# ridende                    844.0        69.0  0.075575
# rørende                   1277.0       100.0  0.072622
# hviskende                  846.0        66.0  0.072368
# voksende                  2143.0       145.0  0.063374
# ertende                    656.0        42.0  0.060172
# styrtende                  721.0        46.0  0.059974
# stående                  20132.0      1275.0  0.059560
# sovende                   1455.0        79.0  0.051499
# truende                   3178.0       172.0  0.051343
# liggende                 14831.0       738.0  0.047402
# trettende                  726.0        32.0  0.042216
# skrikende                 1257.0        54.0  0.041190
# sittende                 16136.0       635.0  0.037863
# reisende                  7638.0       293.0  0.036944
# lysende                   5233.0       176.0  0.032538
# spørrende                 4315.0       140.0  0.031425
# trykkende                 1965.0        60.0  0.029630
# døende                    3848.0       103.0  0.026069
# undersøkende               900.0        24.0  0.025974
# gående                   39876.0       360.0  0.008947
# kommende                 46857.0       262.0  0.005560
# leende                   22608.0        84.0  0.003702
# farende                 153448.0        69.0  0.000449
#
# [82 rows x 3 columns]

# %% [markdown]
# # Sammenligner ratio for oversatt mot NOB

# %%
COMP = COUNTS['ratio']/COUNTS_NOB['ratio']

# %%
HTML(nb.frame(COMP.sort_values(ascending=False)).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>leende</th>
#       <td>8.721100</td>
#     </tr>
#     <tr>
#       <th>truende</th>
#       <td>5.848702</td>
#     </tr>
#     <tr>
#       <th>ertende</th>
#       <td>4.640791</td>
#     </tr>
#     <tr>
#       <th>undersøkende</th>
#       <td>3.423775</td>
#     </tr>
#     <tr>
#       <th>trykkende</th>
#       <td>2.580386</td>
#     </tr>
#     <tr>
#       <th>granskende</th>
#       <td>2.400924</td>
#     </tr>
#     <tr>
#       <th>farende</th>
#       <td>2.291177</td>
#     </tr>
#     <tr>
#       <th>skinnende</th>
#       <td>2.275594</td>
#     </tr>
#     <tr>
#       <th>tiltalende</th>
#       <td>1.913563</td>
#     </tr>
#     <tr>
#       <th>inngående</th>
#       <td>1.807862</td>
#     </tr>
#     <tr>
#       <th>spennende</th>
#       <td>1.778731</td>
#     </tr>
#     <tr>
#       <th>tiltrekkende</th>
#       <td>1.762465</td>
#     </tr>
#     <tr>
#       <th>blendende</th>
#       <td>1.762030</td>
#     </tr>
#     <tr>
#       <th>brennende</th>
#       <td>1.708030</td>
#     </tr>
#     <tr>
#       <th>styrtende</th>
#       <td>1.679435</td>
#     </tr>
#     <tr>
#       <th>beundrende</th>
#       <td>1.658674</td>
#     </tr>
#     <tr>
#       <th>bebreidende</th>
#       <td>1.621884</td>
#     </tr>
#     <tr>
#       <th>skjelvende</th>
#       <td>1.598375</td>
#     </tr>
#     <tr>
#       <th>skingrende</th>
#       <td>1.591837</td>
#     </tr>
#     <tr>
#       <th>grunnleggende</th>
#       <td>1.470291</td>
#     </tr>
#     <tr>
#       <th>advarende</th>
#       <td>1.454827</td>
#     </tr>
#     <tr>
#       <th>strålende</th>
#       <td>1.449676</td>
#     </tr>
#     <tr>
#       <th>rasende</th>
#       <td>1.433876</td>
#     </tr>
#     <tr>
#       <th>glitrende</th>
#       <td>1.412496</td>
#     </tr>
#     <tr>
#       <th>stående</th>
#       <td>1.399289</td>
#     </tr>
#     <tr>
#       <th>gjennomtrengende</th>
#       <td>1.368176</td>
#     </tr>
#     <tr>
#       <th>triumferende</th>
#       <td>1.359696</td>
#     </tr>
#     <tr>
#       <th>omfattende</th>
#       <td>1.342562</td>
#     </tr>
#     <tr>
#       <th>døende</th>
#       <td>1.316228</td>
#     </tr>
#     <tr>
#       <th>trettende</th>
#       <td>1.279694</td>
#     </tr>
#     <tr>
#       <th>utelukkende</th>
#       <td>1.259335</td>
#     </tr>
#     <tr>
#       <th>skremmende</th>
#       <td>1.240832</td>
#     </tr>
#     <tr>
#       <th>ridende</th>
#       <td>1.237952</td>
#     </tr>
#     <tr>
#       <th>flammende</th>
#       <td>1.222194</td>
#     </tr>
#     <tr>
#       <th>liggende</th>
#       <td>1.206909</td>
#     </tr>
#     <tr>
#       <th>anstrengende</th>
#       <td>1.205872</td>
#     </tr>
#     <tr>
#       <th>voksende</th>
#       <td>1.200478</td>
#     </tr>
#     <tr>
#       <th>sittende</th>
#       <td>1.198911</td>
#     </tr>
#     <tr>
#       <th>hengende</th>
#       <td>1.180242</td>
#     </tr>
#     <tr>
#       <th>utseende</th>
#       <td>1.161874</td>
#     </tr>
#     <tr>
#       <th>skrikende</th>
#       <td>1.117647</td>
#     </tr>
#     <tr>
#       <th>sjarmerende</th>
#       <td>1.109965</td>
#     </tr>
#     <tr>
#       <th>hviskende</th>
#       <td>1.071974</td>
#     </tr>
#     <tr>
#       <th>glimrende</th>
#       <td>1.071450</td>
#     </tr>
#     <tr>
#       <th>glødende</th>
#       <td>1.059194</td>
#     </tr>
#     <tr>
#       <th>smilende</th>
#       <td>1.033121</td>
#     </tr>
#     <tr>
#       <th>oppmuntrende</th>
#       <td>1.020532</td>
#     </tr>
#     <tr>
#       <th>levende</th>
#       <td>0.981731</td>
#     </tr>
#     <tr>
#       <th>dominerende</th>
#       <td>0.980146</td>
#     </tr>
#     <tr>
#       <th>gående</th>
#       <td>0.976150</td>
#     </tr>
#     <tr>
#       <th>avgjørende</th>
#       <td>0.968235</td>
#     </tr>
#     <tr>
#       <th>flytende</th>
#       <td>0.966941</td>
#     </tr>
#     <tr>
#       <th>rørende</th>
#       <td>0.935408</td>
#     </tr>
#     <tr>
#       <th>tilsvarende</th>
#       <td>0.932614</td>
#     </tr>
#     <tr>
#       <th>beroligende</th>
#       <td>0.929847</td>
#     </tr>
#     <tr>
#       <th>fortryllende</th>
#       <td>0.925470</td>
#     </tr>
#     <tr>
#       <th>imponerende</th>
#       <td>0.904243</td>
#     </tr>
#     <tr>
#       <th>utfordrende</th>
#       <td>0.878690</td>
#     </tr>
#     <tr>
#       <th>vedkommende</th>
#       <td>0.858811</td>
#     </tr>
#     <tr>
#       <th>lysende</th>
#       <td>0.857491</td>
#     </tr>
#     <tr>
#       <th>irriterende</th>
#       <td>0.839302</td>
#     </tr>
#     <tr>
#       <th>overbevisende</th>
#       <td>0.784165</td>
#     </tr>
#     <tr>
#       <th>ledende</th>
#       <td>0.783301</td>
#     </tr>
#     <tr>
#       <th>liknende</th>
#       <td>0.776413</td>
#     </tr>
#     <tr>
#       <th>sovende</th>
#       <td>0.770836</td>
#     </tr>
#     <tr>
#       <th>overveldende</th>
#       <td>0.759708</td>
#     </tr>
#     <tr>
#       <th>løpende</th>
#       <td>0.756609</td>
#     </tr>
#     <tr>
#       <th>forbløffende</th>
#       <td>0.716790</td>
#     </tr>
#     <tr>
#       <th>nølende</th>
#       <td>0.713694</td>
#     </tr>
#     <tr>
#       <th>tilfredsstillende</th>
#       <td>0.676940</td>
#     </tr>
#     <tr>
#       <th>passende</th>
#       <td>0.640780</td>
#     </tr>
#     <tr>
#       <th>spørrende</th>
#       <td>0.618970</td>
#     </tr>
#     <tr>
#       <th>angående</th>
#       <td>0.596885</td>
#     </tr>
#     <tr>
#       <th>stigende</th>
#       <td>0.587187</td>
#     </tr>
#     <tr>
#       <th>overraskende</th>
#       <td>0.559947</td>
#     </tr>
#     <tr>
#       <th>forbausende</th>
#       <td>0.536542</td>
#     </tr>
#     <tr>
#       <th>foregående</th>
#       <td>0.520454</td>
#     </tr>
#     <tr>
#       <th>lignende</th>
#       <td>0.493464</td>
#     </tr>
#     <tr>
#       <th>reisende</th>
#       <td>0.466506</td>
#     </tr>
#     <tr>
#       <th>kommende</th>
#       <td>0.420661</td>
#     </tr>
#     <tr>
#       <th>gjeldende</th>
#       <td>0.358169</td>
#     </tr>
#     <tr>
#       <th>følgende</th>
#       <td>0.305737</td>
#     </tr>
#   </tbody>
# </table>
