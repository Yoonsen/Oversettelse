# %% [markdown]
# ## Preamble
#
# Run these if notebook is in a new environment, otherwise just skip to `Import modules`

# %% [markdown]
# #### Boot cell
#
# Skip if `module_update.py` is in same folder as notebook, next cell downloads this file which in turn will download other files.

# %%
# !curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %% [markdown]
# #### Get essentials
#
# Import text and graph modules for analysis, and css for display

# %%
from module_update import update, css

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# # Import modules
#
# Aktiver cellen nedenfor for å få alt til å virke.

# %%
update('nbtext', overwrite=True)
import nbtext as nb
from IPython.display import HTML
import requests
from bs4 import BeautifulSoup


def mods_digibok(urn, kind='marcxml'):
    """find information about serial number urn (or full urn) for books using NB API. 
    Parameter 'kind' is one of mods, marcxml or dublincore """
    
    if not str(urn).startswith('URN'):
        urnstr = "URN:NBN:no-nb_digibok_{urn}".format(urn=urn)
    r = requests.get("https://api.nb.no:443/catalog/v1/metadata/{ident}/{kind}".format(ident=urnstr, kind=kind))
    return r.text

def translator(urn):
    """Finds the translator for a book"""
    item = BeautifulSoup(mods_digibok(urn, kind='mods'), 'lxml')
    trans = []
    navn = item.find_all('name', {'type':'personal'})
    for i in navn:

        try:
            if i.roleterm.text == 'trl':
                trans.append(i.namepart.text)
        except:
            'nn'
    return ';'.join(trans)
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\Oversettelse\nbtext.py`

# %% [markdown]
# ## Build corpus
#
# A corpus definition is a set of URNs. Those can be obtained in various ways and stored as text or in MS-Word file.

# %% [markdown]
# ### Define using metadata
#
# Lag korpus manuelt, fra excel eller andre kilder. Bare lim inn definisjonen mellom de triple """ """ under

# %%
korpus = nb.pure_urn("""
 .... lim inn URNer for korpusdefinisjon her som ren tekst ....
																
																
																
			Rammeverk:													
			-          Ikke nynorsk													
			-          1945 – 1955 og etter 2000													
			-          50 bøker i hver? – spørsmål til Lars. 100 i hver? 													
																
			-          Første oversettelse skal tas med, og den skal være publisert i de gitte periodene. 													
																
			            - Bøker som inneholder flere fortellinger har blitt utelatt. Kun hele romaner													
			            - En spredning på år og forfatter er forsøkt 													
			-          Ta notater på bøker som er oversatt to ganger – bare se på forskjellige oversettere – bare for å ha en liste 													
																
																
																
																
	Urn	Forfatter	Oversetter	År	Tittel	Forlag	Fra	Ord								
	2007012601009	Priestley, J.B.	Gjesdahl, Paul	1945	Mørklagt i Gretley	Aschehoug	eng	97 342,00	Spionroman							
	2007011501001	Han, Suyin	Feydt, Odd	1945	Morgen over Kina	Aschehoug	eng	132 830,00	Fictionalized autobiography							
	2014102708025	Beach, Rex	Grieg-Müller, John.	1945	Hevnerne	Nasjonalforl.	eng	73 671,00	Fiction							
	2012041308131	Norris, Frank	Skjønhaug, Arne.	1945	På eventyr i Stillehavet	Ekko	eng	49 039,00	Eventyrfiksjon							
	2016051148041	Lippincott, Joseph Wharton	Telnæs, Audun H.	1945	Villmarkens champion	Brann	eng	75553	Fiksjon, Ungdom							
	2007013101011	Williams, Valentine	Hopp, Egil Meidell	1945	Som kurér til Marrakesh	Bergendalh	eng	109 496,00	Fiksjon							
								537 931,00								
	2015042008014	Green, F.L.	Hav, Harald	1946	Siste mann ut	Bergendahl	             eng	115 082,00	Mysteriefortelling							
	2012101105071	Shute, Nevil	Toklum, Leif	1946	Livet og leken		eng	110 923,00	Fiksjon							
	2007040201028	Douglas, Lloyd C.	Frodesen, Leiv	1954	Grønt lys	Nasjonalforl.	eng	132 742,00								
	2013042908150	MacDonald, John D.	Gunnufsen, H. Chr.	1954	Syndens sold	Bladkompaniet	eng	69 418,00								
	2014031808130	Bradbury, Ray	Hauge, Eivind	1954	Kom hjem! Kom hjem!	Eide	eng	91 274,00								
								430 478,00								
	2007022701037	Hanley, Gerald	Amlie, Axel	1955	Det store løveåret	Gyldendal	eng	117 455,00								
	2007022301048	Costain, Thomas B.	Gammelgaard, Arthur W.	1955	hellige ild		eng	238 666,00								
	2007020501008	Franken, Rose	Schjelderup, Daisy	1955	Ja til livet		eng	118 036,00								
	2013112708060	Popkin, Zelda	Bommen, Anton	1955	Døden spanderer	Bergendahl	eng	93 337,00								
	2011070710022	Fleming, Ian	Dalen, Erling.	1955	Å leve og la dø	Nasjonalforlaget	eng	76 018,00								
	2013042338078	Frazee, Steve	Faye-Lund, Hans	1955	Kvinnelist	Bladkompaniet	eng	63 363,00								
	2013050208018	Heckelmann, Charles N.	Gleditsch, Ulf	1955	Hevnens legion	Bladkompaniet	eng	63 849,00								
								770 724,00								
																
	Sum							7 670 022,00								

""")
len(korpus)
# Out:
# 70

# %%
korpus_nob = nb.get_urn({
                     'year':1950, 
                     'next':2,
                     'trans':'',
                     'limit':300})
len(korpus)
# Out:
# 70

# %% [markdown]
# # Henter bøkene med ord
#
# Her defineres korpuset som en liste over bøker, med informasjon om oversettere. Er korpuset stort (flere hundre) vil det ta noen minutter å hente alle oversetterne, så det kan være lurt å kutte ned størrelsen litt. Inntil vi får på plass en rask måte å gjøre det på, får det her duge. Det er bare å smøre seg med tålmodighet.

# %% [markdown]
# ## Search corpus for concordances

# %%
from random import sample

# %%
nb.get_urnkonk('gråtende', {'urns':sample(korpus, 50)})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007022701074?searchText=gråtende' target='_blank' style='text-decoration:none'>Til ærens tinde, Spring, Howard, 1950</a>
#                 </td>
#                 <td>Darkie ( Dneap takket nam</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>, « ' lom ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007022701074?searchText=gråtende' target='_blank' style='text-decoration:none'>Til ærens tinde, Spring, Howard, 1950</a>
#                 </td>
#                 <td>og liadde dj ^ dd</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007022701074?searchText=gråtende' target='_blank' style='text-decoration:none'>Til ærens tinde, Spring, Howard, 1950</a>
#                 </td>
#                 <td>lanto liadde d ^ dd</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>med armene om l ^</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010102506020?searchText=gråtende' target='_blank' style='text-decoration:none'>Mrs. Murphy, Scott, Natalie Anderson, 1949</a>
#                 </td>
#                 <td>kom fort . Hun falt</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>inn mot ham .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010102506020?searchText=gråtende' target='_blank' style='text-decoration:none'>Mrs. Murphy, Scott, Natalie Anderson, 1949</a>
#                 </td>
#                 <td>miste ham . Hun nikket</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010102506020?searchText=gråtende' target='_blank' style='text-decoration:none'>Mrs. Murphy, Scott, Natalie Anderson, 1949</a>
#                 </td>
#                 <td>av nå , forklarte han</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>. Det eneste han trengte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012020908035?searchText=gråtende' target='_blank' style='text-decoration:none'>Mittie, Rooke, Daphne, 1953</a>
#                 </td>
#                 <td>fant en stakkars farget pike</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>i solen og for første</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012101105071?searchText=gråtende' target='_blank' style='text-decoration:none'>Livet og leken, Shute, Nevil, 1946</a>
#                 </td>
#                 <td>kontrollrommet . Og hun sa</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>: « Nei , jeg</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008051500097?searchText=gråtende' target='_blank' style='text-decoration:none'>Ralph Ray, Caine, Hall, 1953</a>
#                 </td>
#                 <td>første de møtte var noen</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>unger og en del mødre</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008051500097?searchText=gråtende' target='_blank' style='text-decoration:none'>Ralph Ray, Caine, Hall, 1953</a>
#                 </td>
#                 <td>hadde visst ingen medlidenhet med</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>kvinner og harn .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008042404035?searchText=gråtende' target='_blank' style='text-decoration:none'>På spor etter lykken, Bristow, Gwen, 1951</a>
#                 </td>
#                 <td>skal jeg forvandle meg til</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>enke . » Hun byttet</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061505152?searchText=gråtende' target='_blank' style='text-decoration:none'>Yngste sønn, Sinclair, Jo, 1948</a>
#                 </td>
#                 <td>følte det som han krøp</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>på gulvet foran henne .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061505152?searchText=gråtende' target='_blank' style='text-decoration:none'>Yngste sønn, Sinclair, Jo, 1948</a>
#                 </td>
#                 <td>av løpende , skrikende ,</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>mennesker. Og over det hele</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061505152?searchText=gråtende' target='_blank' style='text-decoration:none'>Yngste sønn, Sinclair, Jo, 1948</a>
#                 </td>
#                 <td>en slik far og løp</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>ut av huset ; da</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011071406026?searchText=gråtende' target='_blank' style='text-decoration:none'>Løytnant Hornblower, Forester, C.S., 1952</a>
#                 </td>
#                 <td>som kaptein ennå . Det</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>vesenet som lå i lugaren</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012111406019?searchText=gråtende' target='_blank' style='text-decoration:none'>Klokkene ringer for deg, Hemingway, Ernest, 1946</a>
#                 </td>
#                 <td>Hun reiste seg langsomt ,</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>, og med hengende hode</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016051048180?searchText=gråtende' target='_blank' style='text-decoration:none'>Portrett av kunstneren som ung mann, Joyce, James, 1948</a>
#                 </td>
#                 <td>mens hans venner ennå sto</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>ved dødsleiet, ble synderens sjel</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016051048180?searchText=gråtende' target='_blank' style='text-decoration:none'>Portrett av kunstneren som ung mann, Joyce, James, 1948</a>
#                 </td>
#                 <td>i brødefulle tårer fra hans</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>sjel — den var betent</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013082708199?searchText=gråtende' target='_blank' style='text-decoration:none'>Skjebner i drift, Reymond, Dalton S., 1948</a>
#                 </td>
#                 <td>slapp henne , sank hun</td>
#                 <td>gråtende</td>
#                 <td style='text-align:left'>ned i en stol .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016051148001?s

# %% [markdown]
# # Definer teksten

# %% [markdown]
# Hen teksten - kan ta noe minutter. Kan lagres for senere bruk.

# %%
TEXT = nb.get_corpus_text(nb.frame(korpus)[0])

# %%
with open ('korpus_file.csv','w',encoding="utf-8") as f:
    TEXT.to_csv(path_or_buf=f)

# %%
TEXT_NOB = nb.get_corpus_text(nb.frame(korpus_nob)[0])

# %%
with open ('korpus_file_nob.csv','w',encoding="utf-8") as f:
    TEXT_NOB.to_csv(path_or_buf=f)

# %% [markdown]
# #### convertet to md
# import pandas as pd
# with open ('korpus_file.csv','r', encoding="utf-8") as f:
#     text = pd.read_csv(f)

# %%
TEXT.sort_values(by=TEXT.columns[0], ascending=False)[:10]
# Out:
#      2007012601009  2007011501001  2014102708025  2012041308131  \
# .           5119.0         6330.0         4262.0         2732.0
# ,           3527.0         5232.0         3146.0         1855.0
# «           2013.0          370.0         1909.0          117.0
# »           1953.0          581.0         1885.0          119.0
# og          1683.0         3876.0         1844.0         1540.0
# jeg         1657.0          705.0          840.0          266.0
# en          1574.0         2161.0          950.0          689.0
# i           1541.0         2557.0         1131.0          985.0
# 6           1516.0         2273.0            2.0            2.0
# ^           1514.0         1182.0            4.0            2.0
#
#      2016051148041  2007013101011  2015042008014  2012101105071  \
# .           3218.0         6288.0         6811.0         7284.0
# ,           2741.0         3777.0         5739.0         3907.0
# «            372.0          242.0           16.0         2824.0
# »            377.0          158.0           15.0         2798.0
# og          2625.0         1680.0         3392.0         3122.0
# jeg          115.0         1361.0          460.0          789.0
# en           926.0         1744.0         1386.0         1536.0
# i           1294.0         2235.0         2244.0         1805.0
# 6              3.0          604.0            2.0            1.0
# ^             12.0          939.0            1.0            1.0
#
#      2012111406019  2007020101046      ...        2007040201028  \
# .          13751.0         1313.0      ...               5692.0
# ,           7524.0         1269.0      ...               4970.0
# «            513.0          248.0      ...               2202.0
# »            496.0          236.0      ...               2143.0
# og          7468.0          773.0      ...               2592.0
# jeg         1692.0          157.0      ...                553.0
# en          2228.0          575.0      ...               2074.0
# i           3114.0          624.0      ...               2091.0
# 6              3.0           52.0      ...               1054.0
# ^              NaN           74.0      ...               1829.0
#
#      2013042908150  2014031808130  2007022701037  2007022301048  \
# .           4223.0         5729.0         6111.0        10654.0
# ,           4268.0         4904.0         4984.0         9318.0
# «             38.0         2322.0          433.0         4502.0
# »             31.0         2309.0          483.0         4201.0
# og          2133.0         3194.0         3066.0         5199.0
# jeg         1551.0          565.0          547.0         1576.0
# en          1049.0         1195.0         1928.0         3274.0
# i           1030.0         1681.0         1863.0         3966.0
# 6              1.0            4.0         1325.0         1941.0
# ^              1.0            2.0          848.0         4363.0
#
#      2007020501008  2013112708060  2011070710022  2013042338078  2013050208018
# .           6327.0         7132.0         4732.0         4091.0         3498.0
# ,           5005.0         3500.0         2801.0         2476.0         2182.0
# «           4164.0         2517.0         1080.0         1442.0           26.0
# »           3948.0         2487.0         1037.0         1413.0           24.0
# og          1842.0         1800.0         2442.0         1521.0         1818.0
# jeg          819.0          703.0          307.0          286.0          312.0
# en          1184.0         1282.0         1188.0          955.0          911.0
# i           1568.0         1449.0         1535.0          986.0         1291.0
# 6           1108.0            2.0            3.0            4.0            1.0
# ^           1998.0            NaN            1.0            4.0           14.0
#
# [10 rows x 70 columns]

# %% [markdown]
# ### Starter med listen over mulige partisipper

# %%
poss_part = list ({x for x in TEXT.index if x.endswith('ende')})

# %% [markdown]
# ### Henter ut de 100 mest frekvente

# %%
N = 100
test_words = list(TEXT.loc[poss_part].sum(axis=1).sort_values(ascending=False)[:N].index)

# %%
variants = dict()
for w in test_words:
    variants[w] = nb.word_paradigm(w)

# %%
forms = dict()
for w in test_words:
    forms[w] = nb.word_form(w)

# %%
nb.frame(variants)
# Out:
#                                                                    0  \
# stående                              [adj, [stående, stått, ståtte]]
# hende                        [adj, [hendende, hendt, hendte, hende]]
# levende            [adj, [levd, levde, levede, levende, levet, le...
# sende                               [adj, [sendende, sendt, sendte]]
# rasende                          [adj, [rasa, rasende, rast, raste]]
# sittende                    [adj, [sitne, sitten, sittende, sittet]]
# stående            [verb, [sto, stod, stå, ståes, står, stås, stå...
# hende                [subs, [henda, hende, hendene, hender, hendet]]
# levende            [verb, [lev, levd, levde, leve, lever, leves, ...
# sende              [verb, [send, sende, sender, sendes, sendt, se...
# rasende                                             [adv, [rasende]]
# sittende           [verb, [satt, sitt, sitte, sitter, sittes, sit...
# ende                                                   [adv, [ende]]
# strålende          [verb, [strål, stråle, stråler, stråles, strål...
# liggende           [verb, [ligg, ligge, ligger, ligges, ligget, l...
# smilende           [verb, [smil, smile, smiler, smiles, smilt, sm...
# vende                [subs, [venda, vende, venden, vendene, vender]]
# skjelvende         [verb, [skalv, skjelv, skjelve, skjelver, skje...
# skinnende          [verb, [skein, skinn, skinne, skinner, skinnes...
# brennende          [verb, [brenn, brenne, brenner, brennes, brent...
# spennende          [verb, [spenn, spenne, spenner, spennes, spent...
# utseende           [subs, [utseende, utseendene, utseender, utsee...
# gående               [verb, [gikk, gjekk, gå, gåes, går, gås, gått]]
# hengende           [verb, [heng, henge, henger, henges, hengt, he...
# truende            [verb, [tru, trudd, trudde, trur, trus, trua, ...
# løpende               [verb, [løp, løpe, løper, løpes, løpet, løpt]]
# passende           [verb, [pass, passa, passe, passer, passes, pa...
# tilsynelatende                                                  None
# lignende           [verb, [lign, ligna, ligne, ligner, lignes, li...
# triumferende       [verb, [triumfer, triumfere, triumferer, trium...
# glimrende          [verb, [glimr, glimra, glimre, glimrer, glimre...
# spørrende             [verb, [spurt, spurte, spør, spørre, spørres]]
# glødende           [verb, [glød, gløda, glødd, glødde, gløde, glø...
# inntrengende                                                    None
# vedkommende                                    [subs, [vedkommende]]
# beroligende        [verb, [berolig, beroliga, berolige, beroliger...
# ...                                                              ...
# stikkende          [verb, [stakk, stikk, stikke, stikker, stikkes...
# flytende           [verb, [flaut, flyt, flyte, flyter, flytes, fl...
# middelaldrende                                                  None
# hviskende          [verb, [hvisk, hviska, hviske, hvisker, hviske...
# påfallende                                                      None
# bydende            [verb, [baud, budt, byd, bydd, bydde, byde, by...
# flakkende          [verb, [flakk, flakka, flakke, flakker, flakke...
# kvelende           [verb, [kvalt, kvalte, kvel, kvele, kveler, kv...
# anstrengende       [verb, [anstreng, anstrenge, anstrenger, anstr...
# tvilende           [verb, [tvil, tvile, tviler, tviles, tvilt, tv...
# attende                                            [prep, [attende]]
# motstrebende                                                    None
# sjarmerende        [verb, [sjarmer, sjarmere, sjarmerer, sjarmere...
# fristende          [verb, [frist, frista, friste, frister, friste...
# unnskyldende       [verb, [unnskyld, unnskylde, unnskylder, unnsk...
# slepende           [verb, [slep, slepe, sleper, slepes, slept, sl...
# granskende         [verb, [gransk, granska, granske, gransker, gr...
# ridende            [verb, [red, rei, reid, rid, ridd, ride, rider...
# larmende           [verb, [larm, larma, larme, larmer, larmes, la...
# drømmende          [verb, [drøm, drømme, drømmer, drømmes, drømt,...
# dirrende           [verb, [dirr, dirra, dirre, dirrer, dirres, di...
# døende                     [verb, [dø, dødd, dødde, døde, dør, døs]]
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Velg former
#
# Plukk ut partisippformene, dersom formen opptrer både som adjektiv og som verb, ellers ut. Nedenfor plukkes ut de alternative verbformene som kan sammenlignes med partisippen.
#
# Her benyttes en enkelt heuristikk. Partisippformen må være oppført både som et adjektiv og et verb, i tillegg må ikke formen selv være blandt verbene.

# %%
participles = dict()
for w in variants:
    # finn POS for alle variantene
    kinds = [x[0] for x in variants[w]]
    
    # sjekk at både adj og verb er blant dem
    if 'adj' and 'verb' in kinds:
        
        # Ta ut de som har formen blant verbene (partisippet er ikke verd i NO)
        F = [k[1] for k in variants[w] if k[0] == 'verb' and not w in k[1] ]
        if F != []:
            participles[w] = F

# %% [markdown]
# ## Se på resultatet

# %%
participles
# Out:
# {'stående': [['sto', 'stod', 'stå', 'ståes', 'står', 'stås', 'stått']],
#  'levende': [['lev', 'levd', 'levde', 'leve', 'lever', 'leves', 'levet']],
#  'rasende': [['ras', 'rasa', 'rase', 'raser', 'rases', 'rast', 'raste']],
#  'sittende': [['satt', 'sitt', 'sitte', 'sitter', 'sittes', 'sittet']],
#  'strålende': [['strål', 'stråle', 'stråler', 'stråles', 'strålt', 'strålte']],
#  'liggende': [['ligg', 'ligge', 'ligger', 'ligges', 'ligget', 'lå', 'låg']],
#  'smilende': [['smil', 'smile', 'smiler', 'smiles', 'smilt', 'smilte']],
#  'skjelvende': [['skalv',
#    'skjelv',
#    'skjelve',
#    'skjelver',
#    'skjelves',
#    'skjelvet']],
#  'skinnende': [['skein',
#    'skinn',
#    'skinne',
#    'skinner',
#    'skinnes',
#    'skint',
#    'skinte']],
#  'brennende': [['brenn',
#    'brenne',
#    'brenner',
#    'brennes',
#    'brent',
#    'brente',
#    'brann',
#    'brant']],
#  'spennende': [['spenn', 'spenne', 'spenner', 'spennes', 'spent', 'spente']],
#  'utseende': [['utse', 'utsees', 'utser', 'utses', 'utsett', 'utså', 'utsåg']],
#  'gående': [['gikk', 'gjekk', 'gå', 'gåes', 'går', 'gås', 'gått']],
#  'hengende': [['heng',
#    'henge',
#    'henger',
#    'henges',
#    'hengt',
#    'hengte',
#    'hang']],
#  'truende': [['tru',
#    'trudd',
#    'trudde',
#    'trur',
#    'trus',
#    'trua',
#    'true',
#    'truer',
#    'trues',
#    'truet']],
#  'løpende': [['løp', 'løpe', 'løper', 'løpes', 'løpet', 'løpt']],
#  'passende': [['pass', 'passa', 'passe', 'passer', 'passes', 'passet']],
#  'lignende': [['lign', 'ligna', 'ligne', 'ligner', 'lignes', 'lignet']],
#  'triumferende': [['triumfer',
#    'triumfere',
#    'triumferer',
#    'triumferes',
#    'triumfert',
#    'triumferte']],
#  'glimrende': [['glimr', 'glimra', 'glimre', 'glimrer', 'glimres', 'glimret']],
#  'spørrende': [['spurt', 'spurte', 'spør', 'spørre', 'spørres']],
#  'glødende': [['glød',
#    'gløda',
#    'glødd',
#    'glødde',
#    'gløde',
#    'gløder',
#    'glødes',
#    'glødet']],
#  'vedkommende': [['vedkom',
#    'vedkomme',
#    'vedkommer',
#    'vedkommes',
#    'vedkommet']],
#  'beroligende': [['berolig',
#    'beroliga',
#    'berolige',
#    'beroliger',
#    'beroliges',
#    'beroliget']],
#  'lysende': [['lys', 'lyse', 'lyser', 'lyses', 'lyst', 'lyste']],
#  'skremmende': [['skrem',
#    'skremme',
#    'skremmer',
#    'skremmes',
#    'skremt',
#    'skremte']],
#  'gjennomtrengende': [['gjennomtreng',
#    'gjennomtrenge',
#    'gjennomtrenger',
#    'gjennomtrenges',
#    'gjennomtrengt',
#    'gjennomtrengte']],
#  'følgende': [['følg',
#    'følgje',
#    'følgjer',
#    'følgjes',
#    'følgt',
#    'følgte',
#    'fulgt',
#    'fulgte',
#    'følge',
#    'følger',
#    'følges']],
#  'imponerende': [['imponer',
#    'imponere',
#    'imponerer',
#    'imponeres',
#    'imponert',
#    'imponerte']],
#  'ertende': [['ert', 'erta', 'erte', 'erter', 'ertes', 'ertet']],
#  'undersøkende': [['undersøk',
#    'undersøke',
#    'undersøker',
#    'undersøkes',
#    'undersøkt',
#    'undersøkte']],
#  'oppmuntrende': [['oppmuntr',
#    'oppmuntra',
#    'oppmuntre',
#    'oppmuntrer',
#    'oppmuntres',
#    'oppmuntret']],
#  'bebreidende': [['bebreid',
#    'bebreida',
#    'bebreide',
#    'bebreider',
#    'bebreides',
#    'bebreidet']],
#  'forbausende': [['forbaus',
#    'forbausa',
#    'forbause',
#    'forbauser',
#    'forbauses',
#    'forbauset']],
#  'glitrende': [['glitr', 'glitra', 'glitre', 'glitrer', 'glitres', 'glitret']],
#  'nølende': [['nøl', 'nøle', 'nøler', 'nøles', 'nølt', 'nølte']],
#  'skrikende': [['skreik',
#    'skrek',
#    'skreket',
#    'skrik',
#    'skrike',
#    'skriker',
#    'skrikes']],
#  'utelukkende': [['utelukk',
#    'utelukka',
#    'utelukke',
#    'utelukker',
#    'utelukkes',
#    'utelukket']],
#  'utfordrende': [['utfordr',
#    'utfordra',
#    'utfordre',
#    'utfordrer',
#    'utfordres',
#    'utfordret']],
#  'rørende': [['rør', 'røre', 'rører', 'røres', 'rørt', 'rørte']],
#  'flammende': [['flam', 'flamma', 'flamme', 'flammer', 'flammes', 'flammet']],
#  'skingrende': [['skingr',
#    'skingra',
#    'skingre',
#    'skingrer',
#    'skingres',
#    'skingret']],
#  'overraskende': [['overrask',
#    'overraska',
#    'overraske',
#    'overrasker',
#    'overraskes',
#    'overrasket']],
#  'blendende': [['blend', 'blenda', 'blende', 'blender', 'blendes', 'blendet']],
#  'beundrende': [['beundr',
#    'beundra',
#    'beundre',
#    'beundrer',
#    'beundres',
#    'beundret']],
#  'farende': [['far', 'fare', 'farer', 'fares', 'fart', 'for']],
#  'irriterende': [['irriter',
#    'irritere',
#    'irriterer',
#    'irriteres',
#    'irritert',
#    'irriterte']],
#  'advarende': [['advar', 'advare', 'advarer', 'advares', 'advart', 'advarte']],
#  'overveldende': [['overveld',
#    'overvelda',
#    'overvelde',
#    'overvelder',
#    'overveldes',
#    'overveldet']],
#  'sovende': [['sov', 'sove', 'sover', 'soves', 'sovet']],
#  'avgjørende': [['avgjorde', 'avgjort', 'avgjør', 'avgjøre', 'avgjøres']],
#  'tiltalende': [['tiltal',
#    'tiltala',
#    'tiltale',
#    'tiltaler',
#    'tiltales',
#    'tiltalt',
#    'tiltalte']],
#  'leende': [['le',
#    'ledd',
#    'ler',
#    'les',
#    'lo',
#    'lea',
#    'lee',
#    'leer',
#    'lees',
#    'leet']],
#  'bølgende': [['bølg', 'bølga', 'bølge', 'bølger', 'bølges', 'bølget']],
#  'tiltrekkende': [['tiltrakk',
#    'tiltrekk',
#    'tiltrekke',
#    'tiltrekker',
#    'tiltrekkes',
#    'tiltrukket']],
#  'trykkende': [['trykk',
#    'trykka',
#    'trykke',
#    'trykker',
#    'trykkes',
#    'trykket',
#    'trykt',
#    'trykte']],
#  'styrtende': [['styrt', 'styrta', 'styrte', 'styrter', 'styrtes', 'styrtet']],
#  'angående': [['angikk',
#    'angjekk',
#    'angå',
#    'angåes',
#    'angår',
#    'angås',
#    'angått']],
#  'stikkende': [['stakk', 'stikk', 'stikke', 'stikker', 'stikkes', 'stukket']],
#  'flytende': [['flaut',
#    'flyt',
#    'flyte',
#    'flyter',
#    'flytes',
#    'flytt',
#    'fløt',
#    'fløyt']],
#  'hviskende': [['hvisk', 'hviska', 'hviske', 'hvisker', 'hviskes', 'hvisket']],
#  'bydende': [['baud',
#    'budt',
#    'byd',
#    'bydd',
#    'bydde',
#    'byde',
#    'byder',
#    'bydes',
#    'bød']],
#  'flakkende': [['flakk', 'flakka', 'flakke', 'flakker', 'flakkes', 'flakket']],
#  'kvelende': [['kvalt',
#    'kvalte',
#    'kvel',
#    'kvele',
#    'kveler',
#    'kveles',
#    'kvelt',
#    'kvelte']],
#  'anstrengende': [['anstreng',
#    'anstrenge',
#    'anstrenger',
#    'anstrenges',
#    'anstrengt',
#    'anstrengte']],
#  'tvilende': [['tvil', 'tvile', 'tviler', 'tviles', 'tvilt', 'tvilte']],
#  'sjarmerende': [['sjarmer',
#    'sjarmere',
#    'sjarmerer',
#    'sjarmeres',
#    'sjarmert',
#    'sjarmerte']],
#  'fristende': [['frist', 'frista', 'friste', 'frister', 'fristes', 'fristet']],
#  'unnskyldende': [['unnskyld',
#    'unnskylde',
#    'unnskylder',
#    'unnskyldes',
#    'unnskyldt',
#    'unnskyldte']],
#  'slepende': [['slep', 'slepe', 'sleper', 'slepes', 'slept', 'slepte']],
#  'granskende': [['gransk',
#    'granska',
#    'granske',
#    'gransker',
#    'granskes',
#    'gransket']],
#  'ridende': [['red', 'rei', 'reid', 'rid', 'ridd', 'ride', 'rider', 'rides']],
#  'larmende': [['larm', 'larma', 'larme', 'larmer', 'larmes', 'larmet']],
#  'drømmende': [['drøm', 'drømme', 'drømmer', 'drømmes', 'drømt', 'drømte']],
#  'dirrende': [['dirr', 'dirra', 'dirre', 'dirrer', 'dirres', 'dirret']],
#  'døende': [['dø', 'dødd', 'dødde', 'døde', 'dør', 'døs']],
#  'tilfredsstillende': [['tilfredsstill',
#    'tilfredsstille',
#    'tilfredsstiller',
#    'tilfredsstilles',
#    'tilfredsstilt',
#    'tilfredsstilte']],
#  'blomstrende': [['blomstr',
#    'blomstra',
#    'blomstre',
#    'blomstrer',
#    'blomstres',
#    'blomstret']],
#  'liknende': [['likn', 'likna', 'likne', 'likner', 'liknes', 'liknet']],
#  'springende': [['sprang',
#    'spring',
#    'springe',
#    'springer',
#    'springes',
#    'sprunget']],
#  'trøstende': [['trøst', 'trøsta', 'trøste', 'trøster', 'trøstes', 'trøstet']],
#  'fortryllende': [['fortryll',
#    'fortrylla',
#    'fortrylle',
#    'fortryller',
#    'fortrylles',
#    'fortryllet',
#    'fortrylt',
#    'fortrylte']]}

# %% [markdown]
# Nå lager vi en ny statistikk der alle ordene telles opp fra datarammen for sammenligning

# %%
counts = dict()
for w in participles:
    counts[w] = TEXT.loc[list(set(participles[w][0]) & set(TEXT.index))].sum(axis=1).sum()

# %%
counts_nob = dict()
for w in participles:
    counts_nob[w] = TEXT_NOB.loc[list(set(participles[w][0]) & set(TEXT_NOB.index))].sum(axis=1).sum()

# %%
counts_nob
# Out:
# {'stående': 17193.0,
#  'levende': 3700.0,
#  'rasende': 331.0,
#  'sittende': 14901.0,
#  'strålende': 357.0,
#  'liggende': 11661.0,
#  'smilende': 2520.0,
#  'skjelvende': 488.0,
#  'skinnende': 675.0,
#  'brennende': 1672.0,
#  'spennende': 829.0,
#  'utseende': 74.0,
#  'gående': 36444.0,
#  'hengende': 2088.0,
#  'truende': 2578.0,
#  'løpende': 2664.0,
#  'passende': 2546.0,
#  'lignende': 596.0,
#  'triumferende': 45.0,
#  'glimrende': 8.0,
#  'spørrende': 4807.0,
#  'glødende': 180.0,
#  'vedkommende': 123.0,
#  'beroligende': 124.0,
#  'lysende': 4584.0,
#  'skremmende': 402.0,
#  'gjennomtrengende': 6.0,
#  'følgende': 5473.0,
#  'imponerende': 114.0,
#  'ertende': 415.0,
#  'undersøkende': 991.0,
#  'oppmuntrende': 114.0,
#  'bebreidende': 140.0,
#  'forbausende': 381.0,
#  'glitrende': 97.0,
#  'nølende': 109.0,
#  'skrikende': 1165.0,
#  'utelukkende': 218.0,
#  'utfordrende': 38.0,
#  'rørende': 1192.0,
#  'flammende': 293.0,
#  'skingrende': 20.0,
#  'overraskende': 213.0,
#  'blendende': 51.0,
#  'beundrende': 260.0,
#  'farende': 139554.0,
#  'irriterende': 213.0,
#  'advarende': 153.0,
#  'overveldende': 57.0,
#  'sovende': 1289.0,
#  'avgjørende': 1160.0,
#  'tiltalende': 695.0,
#  'leende': 7942.0,
#  'bølgende': 276.0,
#  'tiltrekkende': 81.0,
#  'trykkende': 1720.0,
#  'styrtende': 513.0,
#  'angående': 448.0,
#  'stikkende': 1554.0,
#  'flytende': 464.0,
#  'hviskende': 756.0,
#  'bydende': 559.0,
#  'flakkende': 72.0,
#  'kvelende': 133.0,
#  'anstrengende': 129.0,
#  'tvilende': 1334.0,
#  'sjarmerende': 2.0,
#  'fristende': 422.0,
#  'unnskyldende': 195.0,
#  'slepende': 291.0,
#  'granskende': 247.0,
#  'ridende': 749.0,
#  'larmende': 102.0,
#  'drømmende': 975.0,
#  'dirrende': 152.0,
#  'døende': 3474.0,
#  'tilfredsstillende': 223.0,
#  'blomstrende': 142.0,
#  'liknende': 233.0,
#  'springende': 1348.0,
#  'trøstende': 434.0,
#  'fortryllende': 16.0}

# %%
counts
# Out:
# {'stående': 10851.0,
#  'levende': 2227.0,
#  'rasende': 302.0,
#  'sittende': 11015.0,
#  'strålende': 248.0,
#  'liggende': 6238.0,
#  'smilende': 3862.0,
#  'skjelvende': 802.0,
#  'skinnende': 580.0,
#  'brennende': 788.0,
#  'spennende': 574.0,
#  'utseende': 18.0,
#  'gående': 27203.0,
#  'hengende': 1613.0,
#  'truende': 543.0,
#  'løpende': 2311.0,
#  'passende': 1659.0,
#  'lignende': 549.0,
#  'triumferende': 36.0,
#  'glimrende': 11.0,
#  'spørrende': 7751.0,
#  'glødende': 166.0,
#  'vedkommende': 32.0,
#  'beroligende': 161.0,
#  'lysende': 4092.0,
#  'skremmende': 521.0,
#  'gjennomtrengende': 9.0,
#  'følgende': 2955.0,
#  'imponerende': 114.0,
#  'ertende': 335.0,
#  'undersøkende': 582.0,
#  'oppmuntrende': 150.0,
#  'bebreidende': 162.0,
#  'forbausende': 673.0,
#  'glitrende': 111.0,
#  'nølende': 320.0,
#  'skrikende': 1485.0,
#  'utelukkende': 59.0,
#  'utfordrende': 40.0,
#  'rørende': 1234.0,
#  'flammende': 350.0,
#  'skingrende': 28.0,
#  'overraskende': 426.0,
#  'blendende': 66.0,
#  'beundrende': 275.0,
#  'farende': 55037.0,
#  'irriterende': 287.0,
#  'advarende': 234.0,
#  'overveldende': 114.0,
#  'sovende': 1576.0,
#  'avgjørende': 337.0,
#  'tiltalende': 100.0,
#  'leende': 3117.0,
#  'bølgende': 291.0,
#  'tiltrekkende': 101.0,
#  'trykkende': 808.0,
#  'styrtende': 539.0,
#  'angående': 267.0,
#  'stikkende': 2225.0,
#  'flytende': 281.0,
#  'hviskende': 1178.0,
#  'bydende': 190.0,
#  'flakkende': 110.0,
#  'kvelende': 238.0,
#  'anstrengende': 206.0,
#  'tvilende': 936.0,
#  'sjarmerende': 4.0,
#  'fristende': 121.0,
#  'unnskyldende': 242.0,
#  'slepende': 215.0,
#  'granskende': 141.0,
#  'ridende': 774.0,
#  'larmende': 86.0,
#  'drømmende': 798.0,
#  'dirrende': 177.0,
#  'døende': 2379.0,
#  'tilfredsstillende': 103.0,
#  'blomstrende': 76.0,
#  'liknende': 257.0,
#  'springende': 1037.0,
#  'trøstende': 360.0,
#  'fortryllende': 23.0}

# %% [markdown]
# # Legg til opptellinger for partisippene

# %%
count_frame = {x: {'verb_paradigm': counts[x], 'participle': TEXT.loc[x].sum()} for x in counts}

# %%
count_frame_nob = {x: {'verb_paradigm': counts_nob[x], 'participle': TEXT_NOB.loc[x].sum()} for x in counts_nob}

# %%
count_frame
# Out:
# {'stående': {'verb_paradigm': 10851.0, 'participle': 1122.0},
#  'levende': {'verb_paradigm': 2227.0, 'participle': 599.0},
#  'rasende': {'verb_paradigm': 302.0, 'participle': 572.0},
#  'sittende': {'verb_paradigm': 11015.0, 'participle': 561.0},
#  'strålende': {'verb_paradigm': 248.0, 'participle': 508.0},
#  'liggende': {'verb_paradigm': 6238.0, 'participle': 388.0},
#  'smilende': {'verb_paradigm': 3862.0, 'participle': 362.0},
#  'skjelvende': {'verb_paradigm': 802.0, 'participle': 312.0},
#  'skinnende': {'verb_paradigm': 580.0, 'participle': 304.0},
#  'brennende': {'verb_paradigm': 788.0, 'participle': 259.0},
#  'spennende': {'verb_paradigm': 574.0, 'participle': 246.0},
#  'utseende': {'verb_paradigm': 18.0, 'participle': 246.0},
#  'gående': {'verb_paradigm': 27203.0, 'participle': 236.0},
#  'hengende': {'verb_paradigm': 1613.0, 'participle': 211.0},
#  'truende': {'verb_paradigm': 543.0, 'participle': 186.0},
#  'løpende': {'verb_paradigm': 2311.0, 'participle': 183.0},
#  'passende': {'verb_paradigm': 1659.0, 'participle': 174.0},
#  'lignende': {'verb_paradigm': 549.0, 'participle': 161.0},
#  'triumferende': {'verb_paradigm': 36.0, 'participle': 155.0},
#  'glimrende': {'verb_paradigm': 11.0, 'participle': 149.0},
#  'spørrende': {'verb_paradigm': 7751.0, 'participle': 149.0},
#  'glødende': {'verb_paradigm': 166.0, 'participle': 148.0},
#  'vedkommende': {'verb_paradigm': 32.0, 'participle': 135.0},
#  'beroligende': {'verb_paradigm': 161.0, 'participle': 135.0},
#  'lysende': {'verb_paradigm': 4092.0, 'participle': 122.0},
#  'skremmende': {'verb_paradigm': 521.0, 'participle': 107.0},
#  'gjennomtrengende': {'verb_paradigm': 9.0, 'participle': 106.0},
#  'følgende': {'verb_paradigm': 2955.0, 'participle': 104.0},
#  'imponerende': {'verb_paradigm': 114.0, 'participle': 104.0},
#  'ertende': {'verb_paradigm': 335.0, 'participle': 104.0},
#  'undersøkende': {'verb_paradigm': 582.0, 'participle': 102.0},
#  'oppmuntrende': {'verb_paradigm': 150.0, 'participle': 102.0},
#  'bebreidende': {'verb_paradigm': 162.0, 'participle': 101.0},
#  'forbausende': {'verb_paradigm': 673.0, 'participle': 100.0},
#  'glitrende': {'verb_paradigm': 111.0, 'participle': 99.0},
#  'nølende': {'verb_paradigm': 320.0, 'participle': 97.0},
#  'skrikende': {'verb_paradigm': 1485.0, 'participle': 93.0},
#  'utelukkende': {'verb_paradigm': 59.0, 'participle': 93.0},
#  'utfordrende': {'verb_paradigm': 40.0, 'participle': 92.0},
#  'rørende': {'verb_paradigm': 1234.0, 'participle': 89.0},
#  'flammende': {'verb_paradigm': 350.0, 'participle': 89.0},
#  'skingrende': {'verb_paradigm': 28.0, 'participle': 88.0},
#  'overraskende': {'verb_paradigm': 426.0, 'participle': 87.0},
#  'blendende': {'verb_paradigm': 66.0, 'participle': 87.0},
#  'beundrende': {'verb_paradigm': 275.0, 'participle': 85.0},
#  'farende': {'verb_paradigm': 55037.0, 'participle': 85.0},
#  'irriterende': {'verb_paradigm': 287.0, 'participle': 82.0},
#  'advarende': {'verb_paradigm': 234.0, 'participle': 82.0},
#  'overveldende': {'verb_paradigm': 114.0, 'participle': 80.0},
#  'sovende': {'verb_paradigm': 1576.0, 'participle': 80.0},
#  'avgjørende': {'verb_paradigm': 337.0, 'participle': 80.0},
#  'tiltalende': {'verb_paradigm': 100.0, 'participle': 80.0},
#  'leende': {'verb_paradigm': 3117.0, 'participle': 79.0},
#  'bølgende': {'verb_paradigm': 291.0, 'participle': 78.0},
#  'tiltrekkende': {'verb_paradigm': 101.0, 'participle': 78.0},
#  'trykkende': {'verb_paradigm': 808.0, 'participle': 78.0},
#  'styrtende': {'verb_paradigm': 539.0, 'participle': 77.0},
#  'angående': {'verb_paradigm': 267.0, 'participle': 77.0},
#  'stikkende': {'verb_paradigm': 2225.0, 'participle': 75.0},
#  'flytende': {'verb_paradigm': 281.0, 'participle': 73.0},
#  'hviskende': {'verb_paradigm': 1178.0, 'participle': 72.0},
#  'bydende': {'verb_paradigm': 190.0, 'participle': 71.0},
#  'flakkende': {'verb_paradigm': 110.0, 'participle': 70.0},
#  'kvelende': {'verb_paradigm': 238.0, 'participle': 69.0},
#  'anstrengende': {'verb_paradigm': 206.0, 'participle': 68.0},
#  'tvilende': {'verb_paradigm': 936.0, 'participle': 68.0},
#  'sjarmerende': {'verb_paradigm': 4.0, 'participle': 67.0},
#  'fristende': {'verb_paradigm': 121.0, 'participle': 65.0},
#  'unnskyldende': {'verb_paradigm': 242.0, 'participle': 64.0},
#  'slepende': {'verb_paradigm': 215.0, 'participle': 63.0},
#  'granskende': {'verb_paradigm': 141.0, 'participle': 62.0},
#  'ridende': {'verb_paradigm': 774.0, 'participle': 62.0},
#  'larmende': {'verb_paradigm': 86.0, 'participle': 62.0},
#  'drømmende': {'verb_paradigm': 798.0, 'participle': 62.0},
#  'dirrende': {'verb_paradigm': 177.0, 'participle': 61.0},
#  'døende': {'verb_paradigm': 2379.0, 'participle': 61.0},
#  'tilfredsstillende': {'verb_paradigm': 103.0, 'participle': 60.0},
#  'blomstrende': {'verb_paradigm': 76.0, 'participle': 60.0},
#  'liknende': {'verb_paradigm': 257.0, 'participle': 60.0},
#  'springende': {'verb_paradigm': 1037.0, 'participle': 60.0},
#  'trøstende': {'verb_paradigm': 360.0, 'participle': 59.0},
#  'fortryllende': {'verb_paradigm': 23.0, 'participle': 58.0}}

# %%
COUNTS = nb.frame(count_frame)

# %%
COUNTS_NOB = nb.frame(count_frame_nob)

# %%
TOT = nb.totals(40000)

# %%
TOT = nb.frame(TOT)

# %% [markdown]
# Legg en ratio til

# %%
COUNTS['ratio'] = COUNTS['participle']/(COUNTS['participle']+COUNTS['verb_paradigm'])

# %%
COUNTS_NOB['ratio'] = COUNTS_NOB['participle']/(COUNTS_NOB['participle']+COUNTS_NOB['verb_paradigm'])

# %% [markdown]
# # Sortér på ratio
#
# Her ser vi klart at det kanskje ikke er ekte partisipper på topp, mer typiske ord i partisippform.
#
# De mest interessante ordene (tror jeg) er på bunnen her, som 'smilende', 'løpende', 'liggende', 'spørrende'. Og den ratioen kan sammenlignes med norsk sett.

# %%
COUNTS.sort_values(by='ratio', ascending=False)
# Out:
#                    verb_paradigm  participle     ratio
# sjarmerende                  4.0        67.0  0.943662
# utseende                    18.0       246.0  0.931818
# glimrende                   11.0       149.0  0.931250
# gjennomtrengende             9.0       106.0  0.921739
# triumferende                36.0       155.0  0.811518
# vedkommende                 32.0       135.0  0.808383
# skingrende                  28.0        88.0  0.758621
# fortryllende                23.0        58.0  0.716049
# utfordrende                 40.0        92.0  0.696970
# strålende                  248.0       508.0  0.671958
# rasende                    302.0       572.0  0.654462
# utelukkende                 59.0        93.0  0.611842
# blendende                   66.0        87.0  0.568627
# imponerende                114.0       104.0  0.477064
# glitrende                  111.0        99.0  0.471429
# glødende                   166.0       148.0  0.471338
# beroligende                161.0       135.0  0.456081
# tiltalende                 100.0        80.0  0.444444
# blomstrende                 76.0        60.0  0.441176
# tiltrekkende               101.0        78.0  0.435754
# larmende                    86.0        62.0  0.418919
# overveldende               114.0        80.0  0.412371
# oppmuntrende               150.0       102.0  0.404762
# flakkende                  110.0        70.0  0.388889
# bebreidende                162.0       101.0  0.384030
# tilfredsstillende          103.0        60.0  0.368098
# fristende                  121.0        65.0  0.349462
# skinnende                  580.0       304.0  0.343891
# granskende                 141.0        62.0  0.305419
# spennende                  574.0       246.0  0.300000
# ...                          ...         ...       ...
# skremmende                 521.0       107.0  0.170382
# overraskende               426.0        87.0  0.169591
# undersøkende               582.0       102.0  0.149123
# trøstende                  360.0        59.0  0.140811
# forbausende                673.0       100.0  0.129366
# styrtende                  539.0        77.0  0.125000
# hengende                  1613.0       211.0  0.115680
# passende                  1659.0       174.0  0.094926
# stående                  10851.0      1122.0  0.093711
# trykkende                  808.0        78.0  0.088036
# smilende                  3862.0       362.0  0.085701
# ridende                    774.0        62.0  0.074163
# løpende                   2311.0       183.0  0.073376
# drømmende                  798.0        62.0  0.072093
# tvilende                   936.0        68.0  0.067729
# rørende                   1234.0        89.0  0.067271
# skrikende                 1485.0        93.0  0.058935
# liggende                  6238.0       388.0  0.058557
# hviskende                 1178.0        72.0  0.057600
# springende                1037.0        60.0  0.054695
# sittende                 11015.0       561.0  0.048462
# sovende                   1576.0        80.0  0.048309
# følgende                  2955.0       104.0  0.033998
# stikkende                 2225.0        75.0  0.032609
# lysende                   4092.0       122.0  0.028951
# døende                    2379.0        61.0  0.025000
# leende                    3117.0        79.0  0.024718
# spørrende                 7751.0       149.0  0.018861
# gående                   27203.0       236.0  0.008601
# farende                  55037.0        85.0  0.001542
#
# [82 rows x 3 columns]

# %%
COUNTS_NOB.sort_values(by='ratio', ascending=False)
# Out:
#                    verb_paradigm  participle     ratio
# glimrende                    8.0       175.0  0.956284
# vedkommende                123.0      2168.0  0.946312
# sjarmerende                  2.0        29.0  0.935484
# gjennomtrengende             6.0        36.0  0.857143
# utseende                    74.0       236.0  0.761290
# skingrende                  20.0        42.0  0.677419
# tilfredsstillende          223.0       388.0  0.635025
# overveldende                57.0        99.0  0.634615
# triumferende                45.0        69.0  0.605263
# lignende                   596.0       882.0  0.596752
# fortryllende                16.0        23.0  0.589744
# utelukkende                218.0       282.0  0.564000
# utfordrende                 38.0        49.0  0.563218
# liknende                   233.0       278.0  0.544031
# strålende                  357.0       386.0  0.519515
# imponerende                114.0       113.0  0.497797
# rasende                    331.0       327.0  0.496960
# blendende                   51.0        41.0  0.445652
# oppmuntrende               114.0        84.0  0.424242
# angående                   448.0       300.0  0.401070
# beroligende                124.0        82.0  0.398058
# nølende                    109.0        72.0  0.397790
# glødende                   180.0       118.0  0.395973
# overraskende               213.0       135.0  0.387931
# glitrende                   97.0        58.0  0.374194
# tiltrekkende                81.0        40.0  0.330579
# dirrende                   152.0        75.0  0.330396
# følgende                  5473.0      2578.0  0.320209
# avgjørende                1160.0       501.0  0.301626
# blomstrende                142.0        61.0  0.300493
# ...                          ...         ...       ...
# brennende                 1672.0       228.0  0.120000
# beundrende                 260.0        35.0  0.118644
# hviskende                  756.0        81.0  0.096774
# slepende                   291.0        31.0  0.096273
# smilende                  2520.0       252.0  0.090909
# trøstende                  434.0        33.0  0.070664
# styrtende                  513.0        37.0  0.067273
# hengende                  2088.0       143.0  0.064097
# stående                  17193.0      1149.0  0.062643
# rørende                   1192.0        78.0  0.061417
# løpende                   2664.0       165.0  0.058324
# ridende                    749.0        46.0  0.057862
# liggende                 11661.0       633.0  0.051489
# drømmende                  975.0        50.0  0.048780
# truende                   2578.0       130.0  0.048006
# skrikende                 1165.0        57.0  0.046645
# sovende                   1289.0        52.0  0.038777
# springende                1348.0        53.0  0.037830
# trykkende                 1720.0        66.0  0.036954
# sittende                 14901.0       545.0  0.035284
# lysende                   4584.0       153.0  0.032299
# tvilende                  1334.0        43.0  0.031227
# bydende                    559.0        18.0  0.031196
# stikkende                 1554.0        45.0  0.028143
# spørrende                 4807.0       114.0  0.023166
# undersøkende               991.0        20.0  0.019782
# døende                    3474.0        46.0  0.013068
# leende                    7942.0        93.0  0.011574
# gående                   36444.0       305.0  0.008300
# farende                 139554.0        63.0  0.000451
#
# [82 rows x 3 columns]

# %% [markdown]
# # Sammenligner ratio for oversatt mot NOB

# %%
COMP = COUNTS['ratio']/COUNTS_NOB['ratio']

# %%
HTML(nb.frame(COMP.sort_values(ascending=False)).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>bydende</th>
#       <td>8.720094</td>
#     </tr>
#     <tr>
#       <th>undersøkende</th>
#       <td>7.538158</td>
#     </tr>
#     <tr>
#       <th>truende</th>
#       <td>5.314846</td>
#     </tr>
#     <tr>
#       <th>farende</th>
#       <td>3.417368</td>
#     </tr>
#     <tr>
#       <th>tiltalende</th>
#       <td>3.227227</td>
#     </tr>
#     <tr>
#       <th>larmende</th>
#       <td>3.089527</td>
#     </tr>
#     <tr>
#       <th>trykkende</th>
#       <td>2.382311</td>
#     </tr>
#     <tr>
#       <th>slepende</th>
#       <td>2.353910</td>
#     </tr>
#     <tr>
#       <th>granskende</th>
#       <td>2.191379</td>
#     </tr>
#     <tr>
#       <th>tvilende</th>
#       <td>2.168906</td>
#     </tr>
#     <tr>
#       <th>leende</th>
#       <td>2.135616</td>
#     </tr>
#     <tr>
#       <th>brennende</th>
#       <td>2.061445</td>
#     </tr>
#     <tr>
#       <th>trøstende</th>
#       <td>1.992695</td>
#     </tr>
#     <tr>
#       <th>beundrende</th>
#       <td>1.990079</td>
#     </tr>
#     <tr>
#       <th>ertende</th>
#       <td>1.961715</td>
#     </tr>
#     <tr>
#       <th>fristende</th>
#       <td>1.935195</td>
#     </tr>
#     <tr>
#       <th>døende</th>
#       <td>1.913043</td>
#     </tr>
#     <tr>
#       <th>styrtende</th>
#       <td>1.858108</td>
#     </tr>
#     <tr>
#       <th>hengende</th>
#       <td>1.804767</td>
#     </tr>
#     <tr>
#       <th>bebreidende</th>
#       <td>1.798879</td>
#     </tr>
#     <tr>
#       <th>flakkende</th>
#       <td>1.661616</td>
#     </tr>
#     <tr>
#       <th>advarende</th>
#       <td>1.540220</td>
#     </tr>
#     <tr>
#       <th>stående</th>
#       <td>1.495948</td>
#     </tr>
#     <tr>
#       <th>skinnende</th>
#       <td>1.493033</td>
#     </tr>
#     <tr>
#       <th>drømmende</th>
#       <td>1.477907</td>
#     </tr>
#     <tr>
#       <th>blomstrende</th>
#       <td>1.468177</td>
#     </tr>
#     <tr>
#       <th>springende</th>
#       <td>1.445796</td>
#     </tr>
#     <tr>
#       <th>bølgende</th>
#       <td>1.426829</td>
#     </tr>
#     <tr>
#       <th>spennende</th>
#       <td>1.395595</td>
#     </tr>
#     <tr>
#       <th>sittende</th>
#       <td>1.373485</td>
#     </tr>
#     <tr>
#       <th>triumferende</th>
#       <td>1.340769</td>
#     </tr>
#     <tr>
#       <th>tiltrekkende</th>
#       <td>1.318156</td>
#     </tr>
#     <tr>
#       <th>rasende</th>
#       <td>1.316930</td>
#     </tr>
#     <tr>
#       <th>strålende</th>
#       <td>1.293431</td>
#     </tr>
#     <tr>
#       <th>skjelvende</th>
#       <td>1.292480</td>
#     </tr>
#     <tr>
#       <th>flammende</th>
#       <td>1.282750</td>
#     </tr>
#     <tr>
#       <th>ridende</th>
#       <td>1.281725</td>
#     </tr>
#     <tr>
#       <th>blendende</th>
#       <td>1.275945</td>
#     </tr>
#     <tr>
#       <th>skrikende</th>
#       <td>1.263491</td>
#     </tr>
#     <tr>
#       <th>glitrende</th>
#       <td>1.259852</td>
#     </tr>
#     <tr>
#       <th>løpende</th>
#       <td>1.258067</td>
#     </tr>
#     <tr>
#       <th>sovende</th>
#       <td>1.245819</td>
#     </tr>
#     <tr>
#       <th>skremmende</th>
#       <td>1.240595</td>
#     </tr>
#     <tr>
#       <th>utfordrende</th>
#       <td>1.237477</td>
#     </tr>
#     <tr>
#       <th>utseende</th>
#       <td>1.223998</td>
#     </tr>
#     <tr>
#       <th>fortryllende</th>
#       <td>1.214171</td>
#     </tr>
#     <tr>
#       <th>glødende</th>
#       <td>1.190327</td>
#     </tr>
#     <tr>
#       <th>stikkende</th>
#       <td>1.158696</td>
#     </tr>
#     <tr>
#       <th>beroligende</th>
#       <td>1.145765</td>
#     </tr>
#     <tr>
#       <th>liggende</th>
#       <td>1.137286</td>
#     </tr>
#     <tr>
#       <th>skingrende</th>
#       <td>1.119869</td>
#     </tr>
#     <tr>
#       <th>unnskyldende</th>
#       <td>1.095766</td>
#     </tr>
#     <tr>
#       <th>rørende</th>
#       <td>1.095316</td>
#     </tr>
#     <tr>
#       <th>utelukkende</th>
#       <td>1.084826</td>
#     </tr>
#     <tr>
#       <th>gjennomtrengende</th>
#       <td>1.075362</td>
#     </tr>
#     <tr>
#       <th>gående</th>
#       <td>1.036309</td>
#     </tr>
#     <tr>
#       <th>levende</th>
#       <td>1.016323</td>
#     </tr>
#     <tr>
#       <th>sjarmerende</th>
#       <td>1.008742</td>
#     </tr>
#     <tr>
#       <th>irriterende</th>
#       <td>0.998179</td>
#     </tr>
#     <tr>
#       <th>glimrende</th>
#       <td>0.973821</td>
#     </tr>
#     <tr>
#       <th>imponerende</th>
#       <td>0.958350</td>
#     </tr>
#     <tr>
#       <th>oppmuntrende</th>
#       <td>0.954082</td>
#     </tr>
#     <tr>
#       <th>smilende</th>
#       <td>0.942708</td>
#     </tr>
#     <tr>
#       <th>lysende</th>
#       <td>0.896349</td>
#     </tr>
#     <tr>
#       <th>anstrengende</th>
#       <td>0.863841</td>
#     </tr>
#     <tr>
#       <th>vedkommende</th>
#       <td>0.854246</td>
#     </tr>
#     <tr>
#       <th>kvelende</th>
#       <td>0.847516</td>
#     </tr>
#     <tr>
#       <th>spørrende</th>
#       <td>0.814156</td>
#     </tr>
#     <tr>
#       <th>dirrende</th>
#       <td>0.775742</td>
#     </tr>
#     <tr>
#       <th>forbausende</th>
#       <td>0.753271</td>
#     </tr>
#     <tr>
#       <th>flytende</th>
#       <td>0.749872</td>
#     </tr>
#     <tr>
#       <th>overveldende</th>
#       <td>0.649797</td>
#     </tr>
#     <tr>
#       <th>avgjørende</th>
#       <td>0.636042</td>
#     </tr>
#     <tr>
#       <th>passende</th>
#       <td>0.622617</td>
#     </tr>
#     <tr>
#       <th>hviskende</th>
#       <td>0.595200</td>
#     </tr>
#     <tr>
#       <th>nølende</th>
#       <td>0.584766</td>
#     </tr>
#     <tr>
#       <th>tilfredsstillende</th>
#       <td>0.579660</td>
#     </tr>
#     <tr>
#       <th>angående</th>
#       <td>0.558101</td>
#     </tr>
#     <tr>
#       <th>overraskende</th>
#       <td>0.437167</td>
#     </tr>
#     <tr>
#       <th>lignende</th>
#       <td>0.379991</td>
#     </tr>
#     <tr>
#       <th>liknende</th>
#       <td>0.347911</td>
#     </tr>
#     <tr>
#       <th>følgende</th>
#       <td>0.106175</td>
#     </tr>
#   </tbody>
# </table>
