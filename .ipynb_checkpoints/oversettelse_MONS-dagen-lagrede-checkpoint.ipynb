# %% [markdown]
# ## Preamble
#
# Run these if notebook is in a new environment, otherwise just skip to `Import modules`

# %% [markdown]
# 1. partisipp + konjugert verb: kan vi se mønstre i hva som kan stå som konjugert verb?  Jeg ha noen vage resultater - at det er større variasjon i hva som opptrer i det konjugert elementet i oversatt tekst - men jeg er ikke sikker.
#
# 1. Har vi eksempler fra NB-korpusene på bli+partisipp, hvor partisippet ikke er et av de vanlige posisjonsverbene (jf ble lesende/ble drikkende  vs ble sittende og lese/drikke) - altså hele variasjonsbredden i denne strukturen.
# 1. - oppfølgingsspørsmål etter b) er det forskjell i variasjonsbredden i original vs oversatt norsk?
#
# 1. kunne tenkt meg å se hvilke partisipper som opptrer med 'fant ham/henne/dem + partisipp - tilsvarende 'så ham/henne/dem/deg + partisipp) (objektspredikativer) (Typisk: jeg fant ham + posisjonsverb (fant ham liggende/stående/sittende i grøfta - men ikke typisk:  fant ham gråtende/drikkende/etc
#
# 1. Partisipper i begynnelsen av setninger (frie predikativer):  Sittende med hodet i hendene fikk han endelig en ide....../Sittende på trappen med boken foran seg lignet han en filosof  - hvilke andre verb opptrer i slike partisipper?

# %% [markdown]
# #### Boot cell
#
# Skip if `module_update.py` is in same folder as notebook, next cell downloads this file which in turn will download other files.

# %%
import dhlab.module_update as mu

# %%
from dhlab.module_update import update, css

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
update('collocations')
# Out:
# Updated file `D:\Documents\GitHub\Oversettelse\collocations.py`

# %%
from collocations import dist_coll_urn

# %% [markdown]
# # Import modules
#
# Aktiver cellen nedenfor for å få alt til å virke.

# %%
import dhlab.nbtext as nb
from IPython.display import HTML
import requests
from bs4 import BeautifulSoup
import pandas as pd

def mods_digibok(urn, kind='marcxml'):
    """find information about serial number urn (or full urn) for books using NB API. 
    Parameter 'kind' is one of mods, marcxml or dublincore """
    
    if not str(urn).startswith('URN'):
        urnstr = "URN:NBN:no-nb_digibok_{urn}".format(urn=urn)
    r = requests.get("https://api.nb.no:443/catalog/v1/metadata/{ident}/{kind}".format(ident=urnstr, kind=kind))
    return r.text

def translator(urn):
    """Finds the translator for a book"""
    item = BeautifulSoup(mods_digibok(urn, kind='mods'), 'lxml')
    trans = []
    navn = item.find_all('name', {'type':'personal'})
    for i in navn:

        try:
            if i.roleterm.text == 'trl':
                trans.append(i.namepart.text)
        except:
            'nn'
    return ';'.join(trans)

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'prep' in fs:
        res = 'prep'
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def sort_word_forms(words):
    res = {select_form(w):w for w in words}
    return res

def mdprint(forskjell, cutoff=5):
    categories = categorize(forskjell[forskjell > cutoff].dropna().index)
    forms = {w:select_form(w) for w in categories['other']}
    Grouping = {cat:[word for word in forms if forms[word] == cat] for cat in forms.values()}
    navn = "## Egennavn \n"
    navn += ', '.join(categories['propr'])
    pos = ""
    for cat in Grouping:
        pos += "## " + cat + "\n"
        pos += ', '.join(Grouping[cat]) + "\n"
    mu.printmd(navn)
    mu.printmd(pos)
    return

def velg_form(word):
    former = list({x.split()[0] for x in nb.word_form(word)})
    if 'prep' in former:
        res = 'prep'
    elif 'det' in former:
        res = 'det'
    elif 'pron' in former:
        res = 'pron'
    elif 'verb' in former:
        res = 'verb'
    elif 'subst' in former:
        res = 'subst'
    elif 'adj' in former:
        res = 'adj'
    else:
        try:
            res = former[0]
        except:
            res = 'ukjent'
    return res

def klassifikasjon(df, num = 60, column = 0, up=False):
    gruppering = list(map(lambda w: (w, velg_form(w)), df.sort_values(by=column, ascending=up).head(num).index))
    grupper = dict(gruppering)
    grupperinger = {cat:[w for w in grupper if grupper[w] == cat] for cat in grupper.values()}
    return nb.frame(grupperinger).transpose().fillna('')

# %%
def wordbags(words, urns):
    url = 'https://api.nb.no/ngram/wordbags'
    if isinstance(words, str):
        return
    if isinstance(words, list):
        words = {w:[w] for w in words}
    r = requests.post(url, json={'wordbags':words, 'urns':urns})
    return r.json()

# %%
def word_frequencies(words):
    url = 'https://api.nb.no/ngram/word_frequencies'
    if isinstance(words, str):
        words = words.split()
    r = requests.post(url, json={'words':words})
    return r.json()

# %%
from random import sample

import inspect
def urn_concordance(urns = None, word = None, size = 5, before = None, after = None, html=False):
    """ Find a concordance within a corpus as list of URNs. This is a wrapper for get_urnkonk """
    
    # exit if list of urns is empty
    if urns is None or word is None:
        return []
    
    # The URNs may be presented in different ways. 
    urns = nb.pure_urn(urns)
    
    # find values and feed everything to get_urnkonk
    frame = inspect.currentframe()
    args, _, _, values = inspect.getargvalues(frame)
    query = {i:values[i] for i in args if values[i] != None and i != 'word'}
    return nb.get_urnkonk(word, query, html=html)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})

# %%
nb.word_paradigm('spisende')
# Out:
# [['adj', ['spisende', 'spist', 'spiste']],
#  ['verb', ['spis', 'spise', 'spiser', 'spises', 'spist', 'spiste']]]

# %% [markdown]
# ## Build corpus
#
# A corpus definition is a set of URNs. Those can be obtained in various ways and stored as text or in MS-Word file.

# %% [markdown]
# ### Define using metadata
#
# Lag korpus manuelt, fra excel eller andre kilder. Bare lim inn definisjonen mellom de triple """ """ under

# %%
korpus = pd.read_csv('korpus_urns_1980.csv', index_col = 0)

# %%
korpus_nob = pd.read_csv('korpus_urns_nob_1980', index_col = 0)

# %%
korpus_nob
# Out:
#                urn                     author  \
# 0    2011041308067               Omre, Arthur
# 1    2013043007014                        NaN
# 2    2015082448047             Roestad, Bente
# 3    2013042206017              Wilsberg, Jan
# 4    2012112306021            Kloster, Gunvor
# 5    2012112305061           Stokke, Bernhard
# 6    2013120205014        Lillegaard, Leif B.
# 7    2006111001010           Sandsdalen, Guro
# 8    2013092407034               Midtbø, Tore
# 9    2015021808385              Bjerke, André
# 10   2010101220012          Cartland, Barbara
# 11   2013102407318                Dalby, Gene
# 12   2013061308240               Lyngås, Arne
# 13   2009051104114             Halstvedt, Tor
# 14   2006110700068             Larsen, Petter
# 15   2013112606039                        NaN
# 16   2015111907538                        NaN
# 17   2012062706055                Dalby, Gene
# 18   2012092606080                 Manus, Max
# 19   2012092506009            Rud, Nils Johan
# 20   2013040807050              Skram, Amalie
# 21   2012121007133                  Ege, John
# 22   2012062106073                 Moen, John
# 23   2014013106084               Arnesen, Gro
# 24   2011070406046  Michaelsen, Aslaug Groven
# 25   2012092108088               Saus, Anders
# 26   2012092106012           Stryken, Øystein
# 27   2014100608077           Norland, Andreas
# 28   2012121105039               Bronken, Per
# 29   2014062307003             Ulstad, Gunnar
# ..             ...                        ...
# 270  2012011908119                        NaN
# 271  2012121105109               Flock, Willy
# 272  2007072600026             Hestenes, Arne
# 273  2009051200015               Prøysen, Alf
# 274  2012120705030         Johansen, Margaret
# 275  2013061708151           Furuhatt, Trygve
# 276  2013042305078           Lid, Dagny Tande
# 277  2013061408162             Messel, Gunnar
# 278  2012031908115    Hagen, Ingeborg Refling
# 279  2012080808236                        NaN
# 280  2012092108132            Pettersen, Knut
# 281  2007072300031           Thams, Elisabeth
# 282  2007080104051                        NaN
# 283  2007092401081              Bloch, Robert
# 284  2014072206091            Osmundsen, Mari
# 285  2015041408079            Halle, Barthold
# 286  2012120505056             Kullerud, Erik
# 287  2013061108093             Messel, Gunnar
# 288  2014030707088      Gulbransen, Reidar I.
# 289  2009071001058               Ringen, Tone
# 290  2007080200110           Lier, Svein Rolf
# 291  2013040807065                        NaN
# 292  2014071007101               Hagen, Inger
# 293  2011060706052                        NaN
# 294  2012100106171         Tønseth, Jan Jakob
# 295  2016112948508             Elvestad, Sven
# 296  2016040508077                        NaN
# 297  2010110320014           Stenersen, Helge
# 298  2007070904079   Christensen, Lars Saabye
# 299  2013061408149          Otgard, Ragnar W.
#
#                                                  title  year
# 0                                             Smuglere  1971
# 1                                  - som det var i går  1974
# 2                                 Blekkulf og Armianne  1990
# 3                                         Sort oktober  1974
# 4                                        Karens bilder  1979
# 5                                     ensomme vaktpost  1978
# 6                                          Fangeskipet  1974
# 7                                           Saras rike  1977
# 8                                 Fenomenet "Flåklypa"  1979
# 9                                       Fremmede toner  1978
# 10                         Drømmen som ble virkelighet  1990
# 11                                           Neon/furu  1983
# 12                                        Sildrebekken  1979
# 13                                                Elva  1990
# 14                                                Holt  1975
# 15             Søkelys på Knut Hamsuns 90-års diktning  1979
# 16                                      Bjørnson i dag  1983
# 17                                         Frostknuter  1982
# 18                                            Stigmata  1979
# 19                                   Jakten og kvinnen  1978
# 20                                  Bønn og anfektelse  1975
# 21                                        Bjørnedansen  1985
# 22                                   usynlige bagasjen  1981
# 23                                           Kjære mor  1986
# 24                             "av mangel på seg selv"  1985
# 25                              Brødrene på Hundholmen  1977
# 26                     Ingela, ditt smertefylte ansikt  1982
# 27                                   Mord i Stortinget  1979
# 28                                   Knapt tilmålt tid  1987
# 29                                            Sirianna  1980
# ..                                                 ...   ...
# 270                            Flores og Blancheflor =  1985
# 271                            Daniel Meyers nye dager  1987
# 272                                          Galleri 2  1970
# 273                           Teskjekjerringa og elgen  1990
# 274                                        Tidsfordriv  1988
# 275                                   Vertshusholderen  1978
# 276                                 Brikker i et spill  1981
# 277                                    Felle i Funchal  1985
# 278                                        Guds tuntre  1972
# 279                   Streiftog i Dostojevskijs verden  1982
# 280                                           Patenten  1982
# 281                                        Tre kvinner  1970
# 282                           Rim, regler og barnevers  1987
# 283                                               Lori  1990
# 284                                    Gode gjerninger  1984
# 285  Tordenshow, eller Den musikalske beretning om ...  1986
# 286                                      Martes mandag  1984
# 287                                  S.O.S. Fort Omida  1977
# 288                                        Nebb og klo  1980
# 289                                        Hekseskogen  1990
# 290                                        Barnemordet  1985
# 291             Strukturalisme i litteraturvitenskapen  1978
# 292            Brannmenn gjør mer enn å slokke branner  1978
# 293                                            Poetikk  1986
# 294                                    Lengsel og lede  1987
# 295  Skjebergmysteriet, eller Severin Mellebyes sid...  1990
# 296                              Vår egen lille verden  1976
# 297                            I den midterste skuffen  1990
# 298                                            Paraply  1982
# 299                                 Drep Henry Rinnan!  1977
#
# [300 rows x 4 columns]

# %% [markdown]
# # Henter bøkene med ord
#
# Her defineres korpuset som en liste over bøker, med informasjon om oversettere. Er korpuset stort (flere hundre) vil det ta noen minutter å hente alle oversetterne, så det kan være lurt å kutte ned størrelsen litt. Inntil vi får på plass en rask måte å gjøre det på, får det her duge. Det er bare å smøre seg med tålmodighet.

# %% [markdown]
# ## Search corpus for concordances

# %%
from random import sample

# %%
nb.urn_concordance(word='leende', urns= sample(nb.pure_urn(korpus), 50))
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012011706052?searchText=leende' target='_blank' style='text-decoration:none'>Chatterton, Ackroyd, Peter, 1989</a>
#                 </td>
#                 <td>forsiktig over ham og løp</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>til døren . Edward holdt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012011706052?searchText=leende' target='_blank' style='text-decoration:none'>Chatterton, Ackroyd, Peter, 1989</a>
#                 </td>
#                 <td>om Charles plutselig hadde hoppet</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>ut bak en av disse</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012011706052?searchText=leende' target='_blank' style='text-decoration:none'>Chatterton, Ackroyd, Peter, 1989</a>
#                 </td>
#                 <td>de går sin vei ,</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012062806124?searchText=leende' target='_blank' style='text-decoration:none'>Amys øyne, Kennedy, Richard, 1989</a>
#                 </td>
#                 <td>ut av utkikkstønna og gikk</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>bortover en rå .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014103008108?searchText=leende' target='_blank' style='text-decoration:none'>Bueskytteren, Scott, Walter, 1987</a>
#                 </td>
#                 <td>gode mann , utbrøt Crevecoeur</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>. Nå føler jeg meg</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014103008108?searchText=leende' target='_blank' style='text-decoration:none'>Bueskytteren, Scott, Walter, 1987</a>
#                 </td>
#                 <td>i heraldikk , svarte kongen</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>, han skal lære hva</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010081103003?searchText=leende' target='_blank' style='text-decoration:none'>Far vel, lev vel, Jones, Toeckey, 1990</a>
#                 </td>
#                 <td>Becky nevnte i forbifarten og</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>oversatte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010081103003?searchText=leende' target='_blank' style='text-decoration:none'>Far vel, lev vel, Jones, Toeckey, 1990</a>
#                 </td>
#                 <td>hun kunne , til han</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>ropte at hun måtte stanse</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010081103003?searchText=leende' target='_blank' style='text-decoration:none'>Far vel, lev vel, Jones, Toeckey, 1990</a>
#                 </td>
#                 <td>til dem , rygget de</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>unna og løp sin vei</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014012338013?searchText=leende' target='_blank' style='text-decoration:none'>Gjøkereiret, Kesey, Ken, 1976</a>
#                 </td>
#                 <td>fiskenes slag i vannet ,</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>, nakne barn på bredden</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014012338013?searchText=leende' target='_blank' style='text-decoration:none'>Gjøkereiret, Kesey, Ken, 1976</a>
#                 </td>
#                 <td>bort mot hovedveien med oss</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>bak seg . Nå og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014012338013?searchText=leende' target='_blank' style='text-decoration:none'>Gjøkereiret, Kesey, Ken, 1976</a>
#                 </td>
#                 <td>hørte jeg en høy</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>snadring , først svak ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014012338013?searchText=leende' target='_blank' style='text-decoration:none'>Gjøkereiret, Kesey, Ken, 1976</a>
#                 </td>
#                 <td>Han vandret</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>ned mellom sengeradene i retning</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014012338013?searchText=leende' target='_blank' style='text-decoration:none'>Gjøkereiret, Kesey, Ken, 1976</a>
#                 </td>
#                 <td>var to , slepte ham</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>og hylende ut av soveværelset</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007021601014?searchText=leende' target='_blank' style='text-decoration:none'>Ulysses, MacLean, Alistair, 1978</a>
#                 </td>
#                 <td>None</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>nikkelen lor ai2rmklokken . 2</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007021601014?searchText=leende' target='_blank' style='text-decoration:none'>Ulysses, MacLean, Alistair, 1978</a>
#                 </td>
#                 <td>en ung mann med en</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>pike ved armen . Så</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016062048007?searchText=leende' target='_blank' style='text-decoration:none'>Hårreisende historier, , 1982</a>
#                 </td>
#                 <td>noe ? » gispet hun</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>. Men jeg klarte aldri</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013080508024?searchText=leende' target='_blank' style='text-decoration:none'>Mowgli, Bringsværd, Tor Åge, 1984</a>
#                 </td>
#                 <td>og går , kaster seg</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>inn i dansen ) mowgli</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016061508100?searchText=leende' target='_blank' style='text-decoration:none'>hvite løgnen, Fleming, Thomas J., 1980</a>
#                 </td>
#                 <td>den hele veien inn ,</td>
#                 <td>leende</td>
#                 <td style='text-align:left'>og skrålende som et par</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016061508100?searchText=leende' target='_blank' style='text-decoration:none'>hvite løgnen, Fleming, Thomas J., 1980</a>
#                 </td>
#                 <td>nesten av veien i en</td>

# %% [markdown]
# # Definer teksten

# %% [markdown]
# Lager mindre versjon av TEXT og TEXT_NOB for Github

# %%
TEXT = pd.read_csv('korpus_file_f5_1980.csv', index_col = 0)
TEXT_NOB = pd.read_csv('korpus_file_nob_f5_1980.csv', index_col = 0)

# %% [markdown]
# #### convertet to md
# import pandas as pd
# with open ('korpus_file.csv','r', encoding="utf-8") as f:
#     text = pd.read_csv(f)

# %%
TEXT.sort_values(by=TEXT.columns[0], ascending=False)[:10]
# Out:
#      2013031206018  2013040507021  2011012105050  2015082548139  \
# ,           1717.0         3488.0          556.0         4515.0
# .           1713.0         9025.0          914.0         8095.0
# «           1000.0           24.0          655.0          200.0
# »            971.0           23.0          634.0          183.0
# det          829.0         2265.0          242.0         1925.0
# og           788.0         2863.0          283.0         2822.0
# er           584.0         1181.0          254.0         1319.0
# å            507.0         1718.0          152.0         1003.0
# som          432.0         1140.0           82.0         1131.0
# en           415.0         1351.0          155.0         1484.0
#
#      2012071806015  2012022908075  2016030907022  2012062806124  \
# ,             46.0         3314.0         2644.0         6094.0
# .             61.0         5714.0         3384.0         7673.0
# «              1.0         1325.0           73.0         1745.0
# »              6.0         1380.0           72.0         1720.0
# det            9.0         1552.0         1237.0         2531.0
# og            16.0         1646.0         1709.0         4119.0
# er             7.0          433.0          518.0         1510.0
# å              2.0         1162.0          844.0         1571.0
# som            4.0         1234.0          537.0         1674.0
# en             4.0         1174.0          715.0         2014.0
#
#      2009092900105  2013012907209  ...  2015072108291  2012012008059  \
# ,           1519.0         3022.0  ...         4557.0           77.0
# .           2577.0         4247.0  ...         4059.0          241.0
# «           1402.0            7.0  ...         1277.0            NaN
# »           1373.0            7.0  ...         1262.0            NaN
# det          530.0          838.0  ...         1518.0           33.0
# og           747.0         1633.0  ...         2508.0           47.0
# er           399.0          385.0  ...          759.0           12.0
# å            624.0          717.0  ...          992.0           17.0
# som          277.0          678.0  ...         1028.0           16.0
# en           320.0          835.0  ...         1168.0            NaN
#
#      2011110208183  2010101208095  2011022320087  2014032406004  \
# ,             12.0           90.0         1744.0         3826.0
# .             30.0          247.0         2640.0         4929.0
# «              2.0           46.0            4.0          122.0
# »              1.0           56.0           21.0          119.0
# det            2.0           40.0          615.0         1390.0
# og             3.0           73.0          690.0         2268.0
# er             4.0            5.0          419.0          529.0
# å              NaN           28.0          415.0         1252.0
# som            2.0           28.0          281.0         1094.0
# en             4.0           31.0          456.0         1330.0
#
#      2015102308102  2016062748040  2014103008108  2013060708127
# ,           6422.0         3996.0         3368.0         4342.0
# .           7894.0         5459.0         2423.0         5566.0
# «            184.0         2124.0           55.0         1740.0
# »            170.0         2089.0           54.0         1718.0
# det         1531.0         1908.0          742.0         1957.0
# og          5462.0         3180.0         1436.0         2435.0
# er           738.0         1056.0          441.0         1094.0
# å           1684.0         1222.0          870.0         1464.0
# som         2150.0         1189.0          967.0          916.0
# en          1609.0         1205.0          787.0         1144.0
#
# [10 rows x 300 columns]

# %% [markdown]
# ### Starter med listen over mulige partisipper

# %%
TEXT.index = TEXT.index.map(str)

# %%
poss_part = list ({x for x in TEXT.index if x.endswith('ende')})

# %%
TEXT.index
# Out:
# Index([',', '.', '«', '»', 'det', 'og', 'er', 'å', 'som', 'en',
#        ...
#        '„', '•', '€', '™', '□', '►', '▼', '★', '♦', '✓'],
#       dtype='object', length=73246)

# %% [markdown]
# ### Henter ut de 100 mest frekvente

# %%
N = 200
test_words = list(TEXT.loc[TEXT.index.str.contains(".*ende$")].sum(axis=1).sort_values(ascending=False)[:N].index)

# %%
variants = dict()
for w in test_words:
    variants[w] = nb.word_paradigm(w)

# %%
forms = dict()
for w in test_words:
    forms[w] = nb.word_form(w)

# %%
var = nb.frame(variants)

# %%
var.loc[['levende', 'vende']]
# Out:
#                                                          0  \
# levende  [adj, [levd, levde, levede, levende, levet, le...
# vende                     [adj, [vendende, vendt, vendte]]
#
#                                                          1  \
# levende  [verb, [lev, levd, levde, leve, lever, leves, ...
# vende      [subs, [venda, vende, venden, vendene, vender]]
#
#                                                          2     3
# levende                                               None  None
# vende    [verb, [vend, vende, vender, vendes, vendt, ve...  None

# %% [markdown]
# ## Velg former
#
# Plukk ut partisippformene, dersom formen opptrer både som adjektiv og som verb, ellers ut. Nedenfor plukkes ut de alternative verbformene som kan sammenlignes med partisippen.
#
# Her benyttes en enkelt heuristikk. Partisippformen må være oppført både som et adjektiv og et verb, i tillegg må ikke formen selv være blandt verbene.

# %%
participles = dict()
for w in variants:
    # finn POS for alle variantene
    kinds = [x[0] for x in variants[w]]
    
    # sjekk at både adj og verb er blant dem
    if 'adj' and 'verb' in kinds:
        
        # Ta ut de som har formen blant verbene (partisippet er ikke verd i NO)
        F = [k[1] for k in variants[w] if k[0] == 'verb' and not w in k[1] ]
        if F != []:
            participles[w] = F

# %% [markdown]
# ## Se på resultatet

# %%
participles
# Out:
# {'stående': [['sto', 'stod', 'stå', 'ståes', 'står', 'stås', 'stått']],
#  'rasende': [['ras', 'rasa', 'rase', 'raser', 'rases', 'rast', 'raste']],
#  'sittende': [['satt', 'sitt', 'sitte', 'sitter', 'sittes', 'sittet']],
#  'levende': [['lev', 'levd', 'levde', 'leve', 'lever', 'leves', 'levet']],
#  'liggende': [['ligg', 'ligge', 'ligger', 'ligges', 'ligget', 'lå', 'låg']],
#  'strålende': [['strål', 'stråle', 'stråler', 'stråles', 'strålt', 'strålte']],
#  'skinnende': [['skein',
#    'skinn',
#    'skinne',
#    'skinner',
#    'skinnes',
#    'skint',
#    'skinte']],
#  'smilende': [['smil', 'smile', 'smiler', 'smiles', 'smilt', 'smilte']],
#  'skjelvende': [['skalv',
#    'skjelv',
#    'skjelve',
#    'skjelver',
#    'skjelves',
#    'skjelvet']],
#  'spennende': [['spenn', 'spenne', 'spenner', 'spennes', 'spent', 'spente']],
#  'utseende': [['utse', 'utsees', 'utser', 'utses', 'utsett', 'utså', 'utsåg']],
#  'hengende': [['heng',
#    'henge',
#    'henger',
#    'henges',
#    'hengt',
#    'hengte',
#    'hang']],
#  'gående': [['gikk', 'gjekk', 'gå', 'gåes', 'går', 'gås', 'gått']],
#  'truende': [['tru',
#    'trudd',
#    'trudde',
#    'trur',
#    'trus',
#    'trua',
#    'true',
#    'truer',
#    'trues',
#    'truet']],
#  'skremmende': [['skrem',
#    'skremme',
#    'skremmer',
#    'skremmes',
#    'skremt',
#    'skremte']],
#  'løpende': [['løp', 'løpe', 'løper', 'løpes', 'løpet', 'løpt']],
#  'passende': [['pass', 'passa', 'passe', 'passer', 'passes', 'passet']],
#  'lignende': [['lign', 'ligna', 'ligne', 'ligner', 'lignes', 'lignet']],
#  'beroligende': [['berolig',
#    'beroliga',
#    'berolige',
#    'beroliger',
#    'beroliges',
#    'beroliget']],
#  'brennende': [['brenn',
#    'brenne',
#    'brenner',
#    'brennes',
#    'brent',
#    'brente',
#    'brann',
#    'brant']],
#  'spørrende': [['spurt', 'spurte', 'spør', 'spørre', 'spørres']],
#  'vedkommende': [['vedkom',
#    'vedkomme',
#    'vedkommer',
#    'vedkommes',
#    'vedkommet']],
#  'flytende': [['flaut',
#    'flyt',
#    'flyte',
#    'flyter',
#    'flytes',
#    'flytt',
#    'fløt',
#    'fløyt']],
#  'tiltrekkende': [['tiltrakk',
#    'tiltrekk',
#    'tiltrekke',
#    'tiltrekker',
#    'tiltrekkes',
#    'tiltrukket']],
#  'triumferende': [['triumfer',
#    'triumfere',
#    'triumferer',
#    'triumferes',
#    'triumfert',
#    'triumferte']],
#  'glitrende': [['glitr', 'glitra', 'glitre', 'glitrer', 'glitres', 'glitret']],
#  'følgende': [['følg',
#    'følgje',
#    'følgjer',
#    'følgjes',
#    'følgt',
#    'følgte',
#    'fulgt',
#    'fulgte',
#    'følge',
#    'følger',
#    'følges']],
#  'overraskende': [['overrask',
#    'overraska',
#    'overraske',
#    'overrasker',
#    'overraskes',
#    'overrasket']],
#  'nølende': [['nøl', 'nøle', 'nøler', 'nøles', 'nølt', 'nølte']],
#  'imponerende': [['imponer',
#    'imponere',
#    'imponerer',
#    'imponeres',
#    'imponert',
#    'imponerte']],
#  'sjarmerende': [['sjarmer',
#    'sjarmere',
#    'sjarmerer',
#    'sjarmeres',
#    'sjarmert',
#    'sjarmerte']],
#  'lysende': [['lys', 'lyse', 'lyser', 'lyses', 'lyst', 'lyste']],
#  'utelukkende': [['utelukk',
#    'utelukka',
#    'utelukke',
#    'utelukker',
#    'utelukkes',
#    'utelukket']],
#  'oppmuntrende': [['oppmuntr',
#    'oppmuntra',
#    'oppmuntre',
#    'oppmuntrer',
#    'oppmuntres',
#    'oppmuntret']],
#  'glødende': [['glød',
#    'gløda',
#    'glødd',
#    'glødde',
#    'gløde',
#    'gløder',
#    'glødes',
#    'glødet']],
#  'døende': [['dø', 'dødd', 'dødde', 'døde', 'dør', 'døs']],
#  'forbausende': [['forbaus',
#    'forbausa',
#    'forbause',
#    'forbauser',
#    'forbauses',
#    'forbauset']],
#  'avgjørende': [['avgjorde', 'avgjort', 'avgjør', 'avgjøre', 'avgjøres']],
#  'besøkende': [['besøk', 'besøke', 'besøker', 'besøkes', 'besøkt', 'besøkte']],
#  'forbløffende': [['forbløff',
#    'forbløffa',
#    'forbløffe',
#    'forbløffer',
#    'forbløffes',
#    'forbløffet']],
#  'overbevisende': [['overbevis',
#    'overbevise',
#    'overbeviser',
#    'overbevises',
#    'overbevist',
#    'overbeviste']],
#  'overveldende': [['overveld',
#    'overvelda',
#    'overvelde',
#    'overvelder',
#    'overveldes',
#    'overveldet']],
#  'skingrende': [['skingr',
#    'skingra',
#    'skingre',
#    'skingrer',
#    'skingres',
#    'skingret']],
#  'glimrende': [['glimr', 'glimra', 'glimre', 'glimrer', 'glimres', 'glimret']],
#  'overlevende': [['overlev',
#    'overlevd',
#    'overlevde',
#    'overleve',
#    'overlever',
#    'overleves']],
#  'omgående': [['omgikk',
#    'omgjekk',
#    'omgå',
#    'omgåes',
#    'omgår',
#    'omgås',
#    'omgått']],
#  'utfordrende': [['utfordr',
#    'utfordra',
#    'utfordre',
#    'utfordrer',
#    'utfordres',
#    'utfordret']],
#  'ertende': [['ert', 'erta', 'erte', 'erter', 'ertes', 'ertet']],
#  'beundrende': [['beundr',
#    'beundra',
#    'beundre',
#    'beundrer',
#    'beundres',
#    'beundret']],
#  'tilfredsstillende': [['tilfredsstill',
#    'tilfredsstille',
#    'tilfredsstiller',
#    'tilfredsstilles',
#    'tilfredsstilt',
#    'tilfredsstilte']],
#  'angående': [['angikk',
#    'angjekk',
#    'angå',
#    'angåes',
#    'angår',
#    'angås',
#    'angått']],
#  'unnskyldende': [['unnskyld',
#    'unnskylde',
#    'unnskylder',
#    'unnskyldes',
#    'unnskyldt',
#    'unnskyldte']],
#  'advarende': [['advar', 'advare', 'advarer', 'advares', 'advart', 'advarte']],
#  'flammende': [['flam', 'flamma', 'flamme', 'flammer', 'flammes', 'flammet']],
#  'sovende': [['sov', 'sove', 'sover', 'soves', 'sovet']],
#  'blendende': [['blend', 'blenda', 'blende', 'blender', 'blendes', 'blendet']],
#  'manglende': [['mangl', 'mangla', 'mangle', 'mangler', 'mangles', 'manglet']],
#  'bebreidende': [['bebreid',
#    'bebreida',
#    'bebreide',
#    'bebreider',
#    'bebreides',
#    'bebreidet']],
#  'granskende': [['gransk',
#    'granska',
#    'granske',
#    'gransker',
#    'granskes',
#    'gransket']],
#  'skrikende': [['skreik',
#    'skrek',
#    'skreket',
#    'skrik',
#    'skrike',
#    'skriker',
#    'skrikes']],
#  'undrende': [['undr', 'undra', 'undre', 'undrer', 'undres', 'undret']],
#  'bølgende': [['bølg', 'bølga', 'bølge', 'bølger', 'bølges', 'bølget']],
#  'forvirrende': [['forvirr',
#    'forvirra',
#    'forvirre',
#    'forvirrer',
#    'forvirres',
#    'forvirret']],
#  'hviskende': [['hvisk', 'hviska', 'hviske', 'hvisker', 'hviskes', 'hvisket']],
#  'tiltalende': [['tiltal',
#    'tiltala',
#    'tiltale',
#    'tiltaler',
#    'tiltales',
#    'tiltalt',
#    'tiltalte']],
#  'inngående': [['inngikk',
#    'inngjekk',
#    'inngå',
#    'inngåes',
#    'inngår',
#    'inngås',
#    'inngått']],
#  'irriterende': [['irriter',
#    'irritere',
#    'irriterer',
#    'irriteres',
#    'irritert',
#    'irriterte']],
#  'bitende': [['beit', 'bet', 'bit', 'bite', 'biter', 'bites', 'bitt']],
#  'tvilende': [['tvil', 'tvile', 'tviler', 'tviles', 'tvilt', 'tvilte']],
#  'leende': [['le',
#    'ledd',
#    'ler',
#    'les',
#    'lo',
#    'lea',
#    'lee',
#    'leer',
#    'lees',
#    'leet']],
#  'beskyttende': [['beskytt',
#    'beskytta',
#    'beskytte',
#    'beskytter',
#    'beskyttes',
#    'beskyttet']],
#  'drivende': [['dreiv',
#    'drev',
#    'drevet',
#    'driv',
#    'drive',
#    'driver',
#    'drives']],
#  'drømmende': [['drøm', 'drømme', 'drømmer', 'drømmes', 'drømt', 'drømte']],
#  'gjennomtrengende': [['gjennomtreng',
#    'gjennomtrenge',
#    'gjennomtrenger',
#    'gjennomtrenges',
#    'gjennomtrengt',
#    'gjennomtrengte']],
#  'fristende': [['frist', 'frista', 'friste', 'frister', 'fristes', 'fristet']],
#  'omfattende': [['omfatt',
#    'omfatta',
#    'omfatte',
#    'omfatter',
#    'omfattes',
#    'omfattet']],
#  'stinkende': [['stink', 'stinka', 'stinke', 'stinker', 'stinkes', 'stinket']],
#  'farende': [['far', 'fare', 'farer', 'fares', 'fart', 'for']],
#  'skjærende': [['skar', 'skjær', 'skjære', 'skjærer', 'skjæres', 'skåret']],
#  'tilsvarende': [['tilsvar',
#    'tilsvara',
#    'tilsvare',
#    'tilsvarer',
#    'tilsvares',
#    'tilsvart',
#    'tilsvarte']],
#  'stigende': [['steg',
#    'steget',
#    'steig',
#    'stig',
#    'stige',
#    'stiger',
#    'stiges']],
#  'hylende': [['hyl', 'hyle', 'hyler', 'hyles', 'hylt', 'hylte']],
#  'dirrende': [['dirr', 'dirra', 'dirre', 'dirrer', 'dirres', 'dirret']],
#  'stirrende': [['stirr', 'stirra', 'stirre', 'stirrer', 'stirres', 'stirret']],
#  'trykkende': [['trykk',
#    'trykka',
#    'trykke',
#    'trykker',
#    'trykkes',
#    'trykket',
#    'trykt',
#    'trykte']],
#  'stikkende': [['stakk', 'stikk', 'stikke', 'stikker', 'stikkes', 'stukket']],
#  'vitende': [['veit', 'vet', 'visst', 'visste', 'vit', 'vite', 'vites']],
#  'bønnfallende': [['bønnfall',
#    'bønnfalle',
#    'bønnfaller',
#    'bønnfalles',
#    'bønnfalt']],
#  'kjørende': [['kjør', 'kjøre', 'kjører', 'kjøres', 'kjørt', 'kjørte']],
#  'stormende': [['storm', 'storma', 'storme', 'stormer', 'stormes', 'stormet']],
#  'foruroligende': [['forurolig',
#    'foruroliga',
#    'forurolige',
#    'foruroliger',
#    'foruroliges',
#    'foruroliget']],
#  'trøstende': [['trøst', 'trøsta', 'trøste', 'trøster', 'trøstes', 'trøstet']],
#  'klagende': [['klag',
#    'klaga',
#    'klagd',
#    'klagde',
#    'klage',
#    'klager',
#    'klages',
#    'klaget']],
#  'flakkende': [['flakk', 'flakka', 'flakke', 'flakker', 'flakkes', 'flakket']],
#  'glinsende': [['glins', 'glinsa', 'glinse', 'glinser', 'glinses', 'glinset']],
#  'svulmende': [['svulm', 'svulma', 'svulme', 'svulmer', 'svulmes', 'svulmet']],
#  'fascinerende': [['fasciner',
#    'fascinere',
#    'fascinerer',
#    'fascineres',
#    'fascinert',
#    'fascinerte']],
#  'styrtende': [['styrt', 'styrta', 'styrte', 'styrter', 'styrtes', 'styrtet']],
#  'dampende': [['damp', 'dampa', 'dampe', 'damper', 'dampes', 'dampet']],
#  'ledende': [['led', 'leda', 'lede', 'leder', 'ledes', 'ledet']],
#  'værende': [['vær',
#    'væra',
#    'være',
#    'værer',
#    'væres',
#    'været',
#    'er',
#    'var',
#    'vært']],
#  'støyende': [['støy',
#    'støya',
#    'støyd',
#    'støyde',
#    'støye',
#    'støyer',
#    'støyes',
#    'støyet']],
#  'undersøkende': [['undersøk',
#    'undersøke',
#    'undersøker',
#    'undersøkes',
#    'undersøkt',
#    'undersøkte']],
#  'dryppende': [['drypp',
#    'dryppa',
#    'dryppe',
#    'drypper',
#    'dryppes',
#    'dryppet',
#    'drypt',
#    'drypte']],
#  'prøvende': [['prøv', 'prøvd', 'prøvde', 'prøve', 'prøver', 'prøves']],
#  'dinglende': [['dingl', 'dingla', 'dingle', 'dingler', 'dingles', 'dinglet']],
#  'lovende': [['lov',
#    'lova',
#    'love',
#    'lover',
#    'loves',
#    'lovet',
#    'lovd',
#    'lovde',
#    'lovt',
#    'lovte']],
#  'dansende': [['dans', 'dansa', 'danse', 'danser', 'danses', 'danset']],
#  'kommende': [['kom', 'komme', 'kommer', 'kommes', 'kommet']],
#  'rørende': [['rør', 'røre', 'rører', 'røres', 'rørt', 'rørte']],
#  'anstrengende': [['anstreng',
#    'anstrenge',
#    'anstrenger',
#    'anstrenges',
#    'anstrengt',
#    'anstrengte']],
#  'nedlatende': [['nedlat',
#    'nedlate',
#    'nedlater',
#    'nedlates',
#    'nedlatt',
#    'nedlot']],
#  'forestående': [['foresto',
#    'forestod',
#    'forestå',
#    'foreståes',
#    'forestår',
#    'forestås',
#    'forestått']],
#  'misbilligende': [['misbillig',
#    'misbilliga',
#    'misbillige',
#    'misbilliger',
#    'misbilliges',
#    'misbilliget']],
#  'kvelende': [['kvalt',
#    'kvalte',
#    'kvel',
#    'kvele',
#    'kveler',
#    'kveles',
#    'kvelt',
#    'kvelte']],
#  'anerkjennende': [['anerkjenn',
#    'anerkjenne',
#    'anerkjenner',
#    'anerkjennes',
#    'anerkjent',
#    'anerkjente']],
#  'strømmende': [['strøm',
#    'strømma',
#    'strømme',
#    'strømmer',
#    'strømmes',
#    'strømmet',
#    'strømt',
#    'strømte']],
#  'trettende': [['trett', 'tretta', 'trette', 'tretter', 'trettes', 'trettet']],
#  'gapende': [['gap', 'gapa', 'gape', 'gaper', 'gapes', 'gapt', 'gapte']],
#  'bedende': [['ba', 'bad', 'bed', 'bede', 'beder', 'bedes', 'bedt']],
#  'fortryllende': [['fortryll',
#    'fortrylla',
#    'fortrylle',
#    'fortryller',
#    'fortrylles',
#    'fortryllet',
#    'fortrylt',
#    'fortrylte']],
#  'blomstrende': [['blomstr',
#    'blomstra',
#    'blomstre',
#    'blomstrer',
#    'blomstres',
#    'blomstret']],
#  'reisende': [['reis', 'reise', 'reiser', 'reises', 'reist', 'reiste']],
#  'gråtende': [['gret', 'gråt', 'gråte', 'gråter', 'gråtes', 'grått']],
#  'fremstående': [['fremsto',
#    'fremstod',
#    'fremstå',
#    'fremståes',
#    'fremstår',
#    'fremstås',
#    'fremstått']],
#  'svingende': [['sving',
#    'svinga',
#    'svinge',
#    'svinger',
#    'svinges',
#    'svinget',
#    'svingt',
#    'svingte',
#    'svang',
#    'svunget']],
#  'skurrende': [['skurr', 'skurra', 'skurre', 'skurrer', 'skurres', 'skurret']],
#  'gjeldende': [['gjeld',
#    'gjelda',
#    'gjelde',
#    'gjelder',
#    'gjeldes',
#    'gjeldet',
#    'gjeldt',
#    'gjeldte',
#    'galdt',
#    'gjaldt',
#    'gjelds']],
#  'svevende': [['svev',
#    'sveva',
#    'svevd',
#    'svevde',
#    'sveve',
#    'svever',
#    'sveves',
#    'svevet']],
#  'brølende': [['brøl', 'brøle', 'brøler', 'brøles', 'brølt', 'brølte']],
#  'pågående': [['pågikk',
#    'pågjekk',
#    'pågå',
#    'pågåes',
#    'pågår',
#    'pågås',
#    'pågått']],
#  'voksende': [['voks',
#    'voksa',
#    'vokse',
#    'vokser',
#    'vokses',
#    'vokset',
#    'vokst',
#    'vokste']],
#  'verkende': [['verk',
#    'verka',
#    'verke',
#    'verker',
#    'verkes',
#    'verket',
#    'verkt',
#    'verkte']],
#  'rykende': [['rauk',
#    'ryk',
#    'ryke',
#    'ryker',
#    'rykes',
#    'røk',
#    'røket',
#    'røyk']],
#  'vaklende': [['vakl', 'vakla', 'vakle', 'vakler', 'vakles', 'vaklet']],
#  'rullende': [['rull', 'rulla', 'rulle', 'ruller', 'rulles', 'rullet']],
#  'flagrende': [['flagr', 'flagra', 'flagre', 'flagrer', 'flagres', 'flagret']],
#  'ventende': [['vent', 'venta', 'vente', 'venter', 'ventes', 'ventet']],
#  'krevende': [['krev',
#    'kreva',
#    'krevd',
#    'krevde',
#    'kreve',
#    'krever',
#    'kreves',
#    'krevet']],
#  'anklagende': [['anklag',
#    'anklaga',
#    'anklagd',
#    'anklagde',
#    'anklage',
#    'anklager',
#    'anklages',
#    'anklaget']],
#  'bydende': [['baud',
#    'budt',
#    'byd',
#    'bydd',
#    'bydde',
#    'byde',
#    'byder',
#    'bydes',
#    'bød']],
#  'krypende': [['kraup',
#    'kryp',
#    'krype',
#    'kryper',
#    'krypes',
#    'krøp',
#    'krøpet',
#    'krøyp']],
#  'troende': [['tro', 'trodd', 'trodde', 'tror', 'tros']],
#  'fremtredende': [['fremtre',
#    'fremtrer',
#    'fremtres',
#    'fremtrådt',
#    'fremtrådte']],
#  'grunnleggende': [['grunnla',
#    'grunnlagt',
#    'grunnlegg',
#    'grunnlegge',
#    'grunnlegger',
#    'grunnlegges']],
#  'boende': [['bo', 'bodd', 'bodde', 'bor', 'bos']],
#  'unnvikende': [['unnveik',
#    'unnvek',
#    'unnveket',
#    'unnvik',
#    'unnvike',
#    'unnviker',
#    'unnvikes']],
#  'susende': [['sus', 'suse', 'suser', 'suses', 'sust', 'suste']],
#  'frastøtende': [['frastøt',
#    'frastøte',
#    'frastøter',
#    'frastøtes',
#    'frastøtt',
#    'frastøtte']],
#  'blussende': [['bluss', 'blussa', 'blusse', 'blusser', 'blusses', 'blusset']],
#  'elskende': [['elsk', 'elska', 'elske', 'elsker', 'elskes', 'elsket']],
#  'drepende': [['drap',
#    'drep',
#    'drepe',
#    'dreper',
#    'drepes',
#    'drept',
#    'drepte']],
#  'tiende': [['tagd',
#    'tagde',
#    'ti',
#    'tia',
#    'tidd',
#    'tidde',
#    'tie',
#    'tier',
#    'ties',
#    'tiet']],
#  'sviende': [['sved',
#    'svei',
#    'svi',
#    'svidd',
#    'svidde',
#    'svir',
#    'svis',
#    'sveid']],
#  'slepende': [['slep', 'slepe', 'sleper', 'slepes', 'slept', 'slepte']],
#  'økende': [['øk', 'øka', 'øke', 'øker', 'økes', 'øket', 'økt', 'økte']],
#  'hvilende': [['hvil', 'hvile', 'hviler', 'hviles', 'hvilt', 'hvilte']],
#  'aldrende': [['aldr', 'aldra', 'aldre', 'aldrer', 'aldres', 'aldret']],
#  'tordnende': [['tordn', 'tordna', 'tordne', 'tordner', 'tordnes', 'tordnet']],
#  'knusende': [['knus', 'knuse', 'knuser', 'knuses', 'knust', 'knuste']],
#  'feiende': [['fei',
#    'feia',
#    'feid',
#    'feide',
#    'feie',
#    'feier',
#    'feies',
#    'feiet']]}

# %% [markdown]
# Nå lager vi en ny statistikk der alle ordene telles opp fra datarammen for sammenligning

# %%
counts = dict()
for w in participles:
    counts[w] = max(1, TEXT.loc[list(set(participles[w][0]) & set(TEXT.index))].sum(axis=1).sum())

# %%
counts_nob = dict()
for w in participles:
    counts_nob[w] = max(1, TEXT_NOB.loc[list(set(participles[w][0]) & set(TEXT_NOB.index))].sum(axis=1).sum())

# %%
for x in Counter(counts_nob).most_common()[:10]:
    print(x[0], x[1])
# Out:
# værende 397236.0
# farende 126584.0
# kommende 61380.0
# gående 53923.0
# vitende 30871.0
# sittende 29748.0
# stående 28259.0
# liggende 17147.0
# troende 14285.0
# spørrende 11392.0

# %%
for x in Counter(counts).most_common()[:10]:
    print(x[0], x[1])
# Out:
# værende 606753.0
# farende 191928.0
# kommende 99214.0
# gående 81579.0
# vitende 53558.0
# sittende 34494.0
# stående 31682.0
# troende 30292.0
# spørrende 22886.0
# liggende 18761.0

# %% [markdown]
# # Legg til opptellinger for partisippene

# %%
count_frame = {x: {'verb_paradigm': counts[x], 'participle': TEXT.loc[x].sum()} for x in counts}

# %%
count_frame_nob = {x: {'verb_paradigm': counts_nob[x], 'participle': TEXT_NOB.loc[x].sum()} for x in counts_nob}

# %%
count_frame
# Out:
# {'stående': {'verb_paradigm': 31682.0, 'participle': 3063.0},
#  'rasende': {'verb_paradigm': 1237.0, 'participle': 1973.0},
#  'sittende': {'verb_paradigm': 34494.0, 'participle': 1823.0},
#  'levende': {'verb_paradigm': 5363.0, 'participle': 1599.0},
#  'liggende': {'verb_paradigm': 18761.0, 'participle': 1259.0},
#  'strålende': {'verb_paradigm': 576.0, 'participle': 1080.0},
#  'skinnende': {'verb_paradigm': 1607.0, 'participle': 839.0},
#  'smilende': {'verb_paradigm': 12655.0, 'participle': 809.0},
#  'skjelvende': {'verb_paradigm': 2257.0, 'participle': 804.0},
#  'spennende': {'verb_paradigm': 1320.0, 'participle': 799.0},
#  'utseende': {'verb_paradigm': 36.0, 'participle': 751.0},
#  'hengende': {'verb_paradigm': 4935.0, 'participle': 707.0},
#  'gående': {'verb_paradigm': 81579.0, 'participle': 693.0},
#  'truende': {'verb_paradigm': 1365.0, 'participle': 608.0},
#  'skremmende': {'verb_paradigm': 2021.0, 'participle': 607.0},
#  'løpende': {'verb_paradigm': 9133.0, 'participle': 600.0},
#  'passende': {'verb_paradigm': 4864.0, 'participle': 593.0},
#  'lignende': {'verb_paradigm': 1768.0, 'participle': 572.0},
#  'beroligende': {'verb_paradigm': 466.0, 'participle': 554.0},
#  'brennende': {'verb_paradigm': 2348.0, 'participle': 532.0},
#  'spørrende': {'verb_paradigm': 22886.0, 'participle': 513.0},
#  'vedkommende': {'verb_paradigm': 86.0, 'participle': 441.0},
#  'flytende': {'verb_paradigm': 939.0, 'participle': 427.0},
#  'tiltrekkende': {'verb_paradigm': 378.0, 'participle': 401.0},
#  'triumferende': {'verb_paradigm': 69.0, 'participle': 398.0},
#  'glitrende': {'verb_paradigm': 439.0, 'participle': 397.0},
#  'følgende': {'verb_paradigm': 10603.0, 'participle': 395.0},
#  'overraskende': {'verb_paradigm': 1621.0, 'participle': 390.0},
#  'nølende': {'verb_paradigm': 1693.0, 'participle': 387.0},
#  'imponerende': {'verb_paradigm': 529.0, 'participle': 377.0},
#  'sjarmerende': {'verb_paradigm': 49.0, 'participle': 375.0},
#  'lysende': {'verb_paradigm': 10810.0, 'participle': 367.0},
#  'utelukkende': {'verb_paradigm': 188.0, 'participle': 336.0},
#  'oppmuntrende': {'verb_paradigm': 410.0, 'participle': 335.0},
#  'glødende': {'verb_paradigm': 606.0, 'participle': 332.0},
#  'døende': {'verb_paradigm': 8881.0, 'participle': 324.0},
#  'forbausende': {'verb_paradigm': 1854.0, 'participle': 320.0},
#  'avgjørende': {'verb_paradigm': 1150.0, 'participle': 307.0},
#  'besøkende': {'verb_paradigm': 3182.0, 'participle': 305.0},
#  'forbløffende': {'verb_paradigm': 684.0, 'participle': 305.0},
#  'overbevisende': {'verb_paradigm': 1837.0, 'participle': 293.0},
#  'overveldende': {'verb_paradigm': 331.0, 'participle': 292.0},
#  'skingrende': {'verb_paradigm': 69.0, 'participle': 289.0},
#  'glimrende': {'verb_paradigm': 13.0, 'participle': 288.0},
#  'overlevende': {'verb_paradigm': 880.0, 'participle': 274.0},
#  'omgående': {'verb_paradigm': 245.0, 'participle': 272.0},
#  'utfordrende': {'verb_paradigm': 182.0, 'participle': 254.0},
#  'ertende': {'verb_paradigm': 585.0, 'participle': 253.0},
#  'beundrende': {'verb_paradigm': 824.0, 'participle': 251.0},
#  'tilfredsstillende': {'verb_paradigm': 245.0, 'participle': 242.0},
#  'angående': {'verb_paradigm': 678.0, 'participle': 241.0},
#  'unnskyldende': {'verb_paradigm': 765.0, 'participle': 241.0},
#  'advarende': {'verb_paradigm': 866.0, 'participle': 239.0},
#  'flammende': {'verb_paradigm': 660.0, 'participle': 233.0},
#  'sovende': {'verb_paradigm': 4543.0, 'participle': 233.0},
#  'blendende': {'verb_paradigm': 183.0, 'participle': 232.0},
#  'manglende': {'verb_paradigm': 1056.0, 'participle': 230.0},
#  'bebreidende': {'verb_paradigm': 383.0, 'participle': 219.0},
#  'granskende': {'verb_paradigm': 715.0, 'participle': 217.0},
#  'skrikende': {'verb_paradigm': 4568.0, 'participle': 214.0},
#  'undrende': {'verb_paradigm': 1540.0, 'participle': 211.0},
#  'bølgende': {'verb_paradigm': 878.0, 'participle': 211.0},
#  'forvirrende': {'verb_paradigm': 1562.0, 'participle': 210.0},
#  'hviskende': {'verb_paradigm': 3039.0, 'participle': 209.0},
#  'tiltalende': {'verb_paradigm': 411.0, 'participle': 206.0},
#  'inngående': {'verb_paradigm': 250.0, 'participle': 203.0},
#  'irriterende': {'verb_paradigm': 1300.0, 'participle': 203.0},
#  'bitende': {'verb_paradigm': 2139.0, 'participle': 200.0},
#  'tvilende': {'verb_paradigm': 3065.0, 'participle': 199.0},
#  'leende': {'verb_paradigm': 6542.0, 'participle': 199.0},
#  'beskyttende': {'verb_paradigm': 1299.0, 'participle': 198.0},
#  'drivende': {'verb_paradigm': 5140.0, 'participle': 198.0},
#  'drømmende': {'verb_paradigm': 2603.0, 'participle': 198.0},
#  'gjennomtrengende': {'verb_paradigm': 9.0, 'participle': 195.0},
#  'fristende': {'verb_paradigm': 430.0, 'participle': 194.0},
#  'omfattende': {'verb_paradigm': 200.0, 'participle': 190.0},
#  'stinkende': {'verb_paradigm': 216.0, 'participle': 190.0},
#  'farende': {'verb_paradigm': 191928.0, 'participle': 189.0},
#  'skjærende': {'verb_paradigm': 2318.0, 'participle': 188.0},
#  'tilsvarende': {'verb_paradigm': 50.0, 'participle': 188.0},
#  'stigende': {'verb_paradigm': 2878.0, 'participle': 187.0},
#  'hylende': {'verb_paradigm': 1158.0, 'participle': 180.0},
#  'dirrende': {'verb_paradigm': 408.0, 'participle': 178.0},
#  'stirrende': {'verb_paradigm': 9268.0, 'participle': 176.0},
#  'trykkende': {'verb_paradigm': 2680.0, 'participle': 176.0},
#  'stikkende': {'verb_paradigm': 6894.0, 'participle': 175.0},
#  'vitende': {'verb_paradigm': 53558.0, 'participle': 174.0},
#  'bønnfallende': {'verb_paradigm': 202.0, 'participle': 173.0},
#  'kjørende': {'verb_paradigm': 8698.0, 'participle': 172.0},
#  'stormende': {'verb_paradigm': 1039.0, 'participle': 167.0},
#  'foruroligende': {'verb_paradigm': 41.0, 'participle': 164.0},
#  'trøstende': {'verb_paradigm': 1120.0, 'participle': 162.0},
#  'klagende': {'verb_paradigm': 990.0, 'participle': 162.0},
#  'flakkende': {'verb_paradigm': 247.0, 'participle': 160.0},
#  'glinsende': {'verb_paradigm': 126.0, 'participle': 159.0},
#  'svulmende': {'verb_paradigm': 196.0, 'participle': 158.0},
#  'fascinerende': {'verb_paradigm': 274.0, 'participle': 158.0},
#  'styrtende': {'verb_paradigm': 1651.0, 'participle': 158.0},
#  'dampende': {'verb_paradigm': 353.0, 'participle': 157.0},
#  'ledende': {'verb_paradigm': 1828.0, 'participle': 157.0},
#  'værende': {'verb_paradigm': 606753.0, 'participle': 157.0},
#  'støyende': {'verb_paradigm': 160.0, 'participle': 156.0},
#  'undersøkende': {'verb_paradigm': 2108.0, 'participle': 154.0},
#  'dryppende': {'verb_paradigm': 328.0, 'participle': 154.0},
#  'prøvende': {'verb_paradigm': 10200.0, 'participle': 154.0},
#  'dinglende': {'verb_paradigm': 322.0, 'participle': 152.0},
#  'lovende': {'verb_paradigm': 4964.0, 'participle': 151.0},
#  'dansende': {'verb_paradigm': 1850.0, 'participle': 151.0},
#  'kommende': {'verb_paradigm': 99214.0, 'participle': 149.0},
#  'rørende': {'verb_paradigm': 3573.0, 'participle': 147.0},
#  'anstrengende': {'verb_paradigm': 645.0, 'participle': 147.0},
#  'nedlatende': {'verb_paradigm': 73.0, 'participle': 146.0},
#  'forestående': {'verb_paradigm': 50.0, 'participle': 145.0},
#  'misbilligende': {'verb_paradigm': 19.0, 'participle': 144.0},
#  'kvelende': {'verb_paradigm': 681.0, 'participle': 144.0},
#  'anerkjennende': {'verb_paradigm': 139.0, 'participle': 143.0},
#  'strømmende': {'verb_paradigm': 1595.0, 'participle': 142.0},
#  'trettende': {'verb_paradigm': 2940.0, 'participle': 142.0},
#  'gapende': {'verb_paradigm': 284.0, 'participle': 141.0},
#  'bedende': {'verb_paradigm': 5990.0, 'participle': 141.0},
#  'fortryllende': {'verb_paradigm': 35.0, 'participle': 141.0},
#  'blomstrende': {'verb_paradigm': 236.0, 'participle': 141.0},
#  'reisende': {'verb_paradigm': 12801.0, 'participle': 140.0},
#  'gråtende': {'verb_paradigm': 3562.0, 'participle': 138.0},
#  'fremstående': {'verb_paradigm': 50.0, 'participle': 137.0},
#  'svingende': {'verb_paradigm': 3333.0, 'participle': 137.0},
#  'skurrende': {'verb_paradigm': 45.0, 'participle': 136.0},
#  'gjeldende': {'verb_paradigm': 4245.0, 'participle': 133.0},
#  'svevende': {'verb_paradigm': 439.0, 'participle': 133.0},
#  'brølende': {'verb_paradigm': 1686.0, 'participle': 133.0},
#  'pågående': {'verb_paradigm': 160.0, 'participle': 132.0},
#  'voksende': {'verb_paradigm': 2231.0, 'participle': 132.0},
#  'verkende': {'verb_paradigm': 925.0, 'participle': 131.0},
#  'rykende': {'verb_paradigm': 1111.0, 'participle': 131.0},
#  'vaklende': {'verb_paradigm': 552.0, 'participle': 130.0},
#  'rullende': {'verb_paradigm': 1988.0, 'participle': 130.0},
#  'flagrende': {'verb_paradigm': 235.0, 'participle': 129.0},
#  'ventende': {'verb_paradigm': 16077.0, 'participle': 129.0},
#  'krevende': {'verb_paradigm': 1055.0, 'participle': 128.0},
#  'anklagende': {'verb_paradigm': 508.0, 'participle': 128.0},
#  'bydende': {'verb_paradigm': 549.0, 'participle': 128.0},
#  'krypende': {'verb_paradigm': 1674.0, 'participle': 127.0},
#  'troende': {'verb_paradigm': 30292.0, 'participle': 127.0},
#  'fremtredende': {'verb_paradigm': 1, 'participle': 127.0},
#  'grunnleggende': {'verb_paradigm': 107.0, 'participle': 126.0},
#  'boende': {'verb_paradigm': 5511.0, 'participle': 126.0},
#  'unnvikende': {'verb_paradigm': 23.0, 'participle': 122.0},
#  'susende': {'verb_paradigm': 464.0, 'participle': 121.0},
#  'frastøtende': {'verb_paradigm': 40.0, 'participle': 120.0},
#  'blussende': {'verb_paradigm': 189.0, 'participle': 119.0},
#  'elskende': {'verb_paradigm': 4995.0, 'participle': 118.0},
#  'drepende': {'verb_paradigm': 5667.0, 'participle': 117.0},
#  'tiende': {'verb_paradigm': 5912.0, 'participle': 116.0},
#  'sviende': {'verb_paradigm': 572.0, 'participle': 116.0},
#  'slepende': {'verb_paradigm': 736.0, 'participle': 115.0},
#  'økende': {'verb_paradigm': 843.0, 'participle': 114.0},
#  'hvilende': {'verb_paradigm': 1909.0, 'participle': 114.0},
#  'aldrende': {'verb_paradigm': 23.0, 'participle': 114.0},
#  'tordnende': {'verb_paradigm': 222.0, 'participle': 114.0},
#  'knusende': {'verb_paradigm': 1794.0, 'participle': 113.0},
#  'feiende': {'verb_paradigm': 857.0, 'participle': 113.0}}

# %%
COUNTS = nb.frame(count_frame)

# %%
COUNTS.sort_values(by='participle', ascending=False).head(10).participle
# Out:
# stående       3063.0
# rasende       1973.0
# sittende      1823.0
# levende       1599.0
# liggende      1259.0
# strålende     1080.0
# skinnende      839.0
# smilende       809.0
# skjelvende     804.0
# spennende      799.0
# Name: participle, dtype: float64

# %%
COUNTS_NOB = nb.frame(count_frame_nob)

# %%
pd.concat([
    nb.frame(COUNTS.sort_values(by='participle', ascending=False).head(50).participle.values, 'oversatt'),
    nb.frame(COUNTS_NOB.sort_values(by='participle', ascending=False).head(50).participle.values,'bokmål')
], sort=False).plot(lw=10, alpha = .8, figsize=(15,10))

# %%
len([x for x in COUNTS.sort_values(by='participle', ascending=False)[:50].index if x in COUNTS_NOB.sort_values(by='participle', ascending=False)[:50].index])
# Out:
# 38

# %%
TEXT_NOB.loc[[x for x in COUNTS.index if x not in COUNTS_NOB.index]].sum(axis=1)
# Out:
# aldrende          99.0
# blussende         88.0
# boende           132.0
# drepende          67.0
# elskende         116.0
# feiende           45.0
# frastøtende       61.0
# grunnleggende    169.0
# hvilende          87.0
# knusende          57.0
# slepende          70.0
# susende          143.0
# sviende          144.0
# tiende            74.0
# tordnende         45.0
# unnvikende        66.0
# økende           107.0
# dtype: float64

# %%
nb.urn_concordance(word='følgende', urns=korpus_nob)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013043007014?searchText=følgende' target='_blank' style='text-decoration:none'>- som det var i går, , 1974</a>
#                 </td>
#                 <td>23 år ) fikk jeg</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>telegram fra søstrene på medisinsk</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013043007014?searchText=følgende' target='_blank' style='text-decoration:none'>- som det var i går, , 1974</a>
#                 </td>
#                 <td>blev sparket av opsynsmanden i</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>ordelag :</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120205014?searchText=følgende' target='_blank' style='text-decoration:none'>Fangeskipet, Lillegaard, Leif B., 1974</a>
#                 </td>
#                 <td>bakhand . Den består av</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>: Hvis vi nu viser</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013092407034?searchText=følgende' target='_blank' style='text-decoration:none'>Fenomenet "Flåklypa", Midtbø, Tore, 1979</a>
#                 </td>
#                 <td>vesentlig hendinger som har med</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>emner å gjøre : teknologi</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013092407034?searchText=følgende' target='_blank' style='text-decoration:none'>Fenomenet "Flåklypa", Midtbø, Tore, 1979</a>
#                 </td>
#                 <td>« valgmaskin med nominasjonschoker» med</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>tekniske data : « Modifisert</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013092407034?searchText=følgende' target='_blank' style='text-decoration:none'>Fenomenet "Flåklypa", Midtbø, Tore, 1979</a>
#                 </td>
#                 <td>Også i den</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>teksten oppstår det en komisk</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013092407034?searchText=følgende' target='_blank' style='text-decoration:none'>Fenomenet "Flåklypa", Midtbø, Tore, 1979</a>
#                 </td>
#                 <td>Flåklypas kulturliv . I det</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>sitatet , som avisa angivelig</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013092407034?searchText=følgende' target='_blank' style='text-decoration:none'>Fenomenet "Flåklypa", Midtbø, Tore, 1979</a>
#                 </td>
#                 <td>Hallstein Bronskimlet kan vi lese</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>:</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015021808385?searchText=følgende' target='_blank' style='text-decoration:none'>Fremmede toner, Bjerke, André, 1978</a>
#                 </td>
#                 <td>i Chicago , hadde offentliggjort</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>: « Jeg så en</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015021808385?searchText=følgende' target='_blank' style='text-decoration:none'>Fremmede toner, Bjerke, André, 1978</a>
#                 </td>
#                 <td>og senat , har utsendt</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>diktat til alle klasser som</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010101220012?searchText=følgende' target='_blank' style='text-decoration:none'>Drømmen som ble virkelighet, Cartland, Barbara, 1990</a>
#                 </td>
#                 <td>Den</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>morgenen , etter en søvnløs</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006110700068?searchText=følgende' target='_blank' style='text-decoration:none'>Holt, Larsen, Petter, 1975</a>
#                 </td>
#                 <td>Tasmanien , har vi mottaf</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>telegram :  Hobarf 7.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013112606039?searchText=følgende' target='_blank' style='text-decoration:none'>Søkelys på Knut Hamsuns 90-års diktning, , 1979</a>
#                 </td>
#                 <td>med en gang at f.eks.</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>iakttakelse fra en norsk litteraturhistorie</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013112606039?searchText=følgende' target='_blank' style='text-decoration:none'>Søkelys på Knut Hamsuns 90-års diktning, , 1979</a>
#                 </td>
#                 <td>den helt borte ? Les</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>scene :</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013112606039?searchText=følgende' target='_blank' style='text-decoration:none'>Søkelys på Knut Hamsuns 90-års diktning, , 1979</a>
#                 </td>
#                 <td>I de</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>tre Dager var Nagel fraværende</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013112606039?searchText=følgende' target='_blank' style='text-decoration:none'>Søkelys på Knut Hamsuns 90-års diktning, , 1979</a>
#                 </td>
#                 <td>kap. II ) bemerker Glahn</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>om Edvardas far :</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013112606039?searchText=følgende' target='_blank' style='text-decoration:none'>Søkelys på Knut Hamsuns 90-års diktning, , 1979</a>
#                 </td>
#                 <td>Vi vil i det</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>søke å analysere forholdet mellom</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015111907538?searchText=følgende' target='_blank' style='text-decoration:none'>Bjørnson i dag, , 1983</a>
#                 </td>
#                 <td>Studenteme » . I de</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>artiklene mener imidlertid Bjørnson å</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015111907538?searchText=følgende' target='_blank' style='text-decoration:none'>Bjørnson i dag, , 1983</a>
#                 </td>
#                 <td>1 det</td>
#                 <td>følgende</td>
#                 <td style='text-align:left'>skal vi se nærmere på</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://w

# %%
TOT = nb.totals(50000)

# %%
TOT = nb.frame(TOT)

# %% [markdown]
# Legg til en kolonne med ratioen melllom de to første.

# %%
COUNTS['ratio'] = COUNTS['participle']/(COUNTS['participle']+COUNTS['verb_paradigm'])

# %%
COUNTS_NOB['ratio'] = COUNTS_NOB['participle']/(COUNTS_NOB['participle']+COUNTS_NOB['verb_paradigm'])

# %% [markdown]
# # Sortér på ratio
#
# Her ser vi klart at det kanskje ikke er ekte partisipper på topp, mer typiske ord i partisippform.
#
# De mest interessante ordene (tror jeg) er på bunnen her, som 'smilende', 'løpende', 'liggende', 'spørrende'. Og den ratioen kan sammenlignes med norsk sett.

# %%
def check_frames(column, number):
    return len([x for x in COUNTS.sort_values(by=column, ascending=False)[:number].index 
                if x in COUNTS_NOB.sort_values(by=column, ascending=False)[:number].index])

# %%
check_frames('participle', 50)
# Out:
# 38

# %%
COUNTS.sort_values(by='ratio', ascending=False)
# Out:
#                   verb_paradigm  participle     ratio
# fremtredende                1.0       127.0  0.992188
# glimrende                  13.0       288.0  0.956811
# gjennomtrengende            9.0       195.0  0.955882
# utseende                   36.0       751.0  0.954257
# sjarmerende                49.0       375.0  0.884434
# misbilligende              19.0       144.0  0.883436
# triumferende               69.0       398.0  0.852248
# unnvikende                 23.0       122.0  0.841379
# vedkommende                86.0       441.0  0.836812
# aldrende                   23.0       114.0  0.832117
# skingrende                 69.0       289.0  0.807263
# fortryllende               35.0       141.0  0.801136
# foruroligende              41.0       164.0  0.800000
# tilsvarende                50.0       188.0  0.789916
# skurrende                  45.0       136.0  0.751381
# frastøtende                40.0       120.0  0.750000
# forestående                50.0       145.0  0.743590
# fremstående                50.0       137.0  0.732620
# nedlatende                 73.0       146.0  0.666667
# strålende                 576.0      1080.0  0.652174
# utelukkende               188.0       336.0  0.641221
# rasende                  1237.0      1973.0  0.614642
# utfordrende               182.0       254.0  0.582569
# blendende                 183.0       232.0  0.559036
# glinsende                 126.0       159.0  0.557895
# beroligende               466.0       554.0  0.543137
# grunnleggende             107.0       126.0  0.540773
# omgående                  245.0       272.0  0.526112
# tiltrekkende              378.0       401.0  0.514763
# anerkjennende             139.0       143.0  0.507092
# ...                         ...         ...       ...
# trettende                2940.0       142.0  0.046074
# skrikende                4568.0       214.0  0.044751
# rørende                  3573.0       147.0  0.039516
# svingende                3333.0       137.0  0.039481
# gråtende                 3562.0       138.0  0.037297
# drivende                 5140.0       198.0  0.037093
# følgende                10603.0       395.0  0.035916
# døende                   8881.0       324.0  0.035198
# lysende                 10810.0       367.0  0.032835
# gjeldende                4245.0       133.0  0.030379
# lovende                  4964.0       151.0  0.029521
# leende                   6542.0       199.0  0.029521
# stikkende                6894.0       175.0  0.024756
# elskende                 4995.0       118.0  0.023078
# bedende                  5990.0       141.0  0.022998
# boende                   5511.0       126.0  0.022352
# spørrende               22886.0       513.0  0.021924
# drepende                 5667.0       117.0  0.020228
# kjørende                 8698.0       172.0  0.019391
# tiende                   5912.0       116.0  0.019244
# stirrende                9268.0       176.0  0.018636
# prøvende                10200.0       154.0  0.014873
# reisende                12801.0       140.0  0.010818
# gående                  81579.0       693.0  0.008423
# ventende                16077.0       129.0  0.007960
# troende                 30292.0       127.0  0.004175
# vitende                 53558.0       174.0  0.003238
# kommende                99214.0       149.0  0.001500
# farende                191928.0       189.0  0.000984
# værende                606753.0       157.0  0.000259
#
# [161 rows x 3 columns]

# %%
COUNTS_NOB.sort_values(by='ratio', ascending=False)[:20]
# Out:
#                   verb_paradigm  participle     ratio
# misbilligende               1.0        36.0  0.972973
# utseende                   14.0       254.0  0.947761
# glimrende                  18.0       106.0  0.854839
# sjarmerende                14.0        81.0  0.852632
# vedkommende                76.0       275.0  0.783476
# foruroligende              18.0        63.0  0.777778
# nedlatende                 22.0        75.0  0.773196
# skingrende                 52.0       159.0  0.753555
# fortryllende               19.0        58.0  0.753247
# tilsvarende                67.0       200.0  0.749064
# gjennomtrengende           35.0        95.0  0.730769
# triumferende               63.0       164.0  0.722467
# fremtredende               42.0        83.0  0.664000
# forestående                46.0        81.0  0.637795
# glinsende                  85.0       140.0  0.622222
# utelukkende               126.0       202.0  0.615854
# utfordrende               103.0       148.0  0.589641
# oppmuntrende              121.0       160.0  0.569395
# stinkende                  89.0       111.0  0.555000
# overveldende              153.0       187.0  0.550000

# %%
', '.join([x for x in COUNTS_NOB.sort_values(by='ratio', ascending=False)[:20].index])
# Out:
# 'misbilligende, utseende, glimrende, sjarmerende, vedkommende, foruroligende, nedlatende, skingrende, fortryllende, tilsvarende, gjennomtrengende, triumferende, fremtredende, forestående, glinsende, utelukkende, utfordrende, oppmuntrende, stinkende, overveldende'

# %%
hi_bm = [x for x in COUNTS_NOB.sort_values(by='ratio', ascending=False)[:20].index]
hi_ov = [x for x in COUNTS.sort_values(by='ratio', ascending=False)[:20].index]
lo_ov = [x for x in COUNTS.sort_values(by='ratio', ascending=True)[:20].index]
lo_bm = [x for x in COUNTS_NOB.sort_values(by='ratio', ascending=True)[:20].index]

# %%
hi_ov
# Out:
# ['fremtredende',
#  'glimrende',
#  'gjennomtrengende',
#  'utseende',
#  'sjarmerende',
#  'misbilligende',
#  'triumferende',
#  'unnvikende',
#  'vedkommende',
#  'aldrende',
#  'skingrende',
#  'fortryllende',
#  'foruroligende',
#  'tilsvarende',
#  'skurrende',
#  'frastøtende',
#  'forestående',
#  'fremstående',
#  'nedlatende',
#  'strålende']

# %% [markdown]
# # Sammenligner ratio for oversatt mot NOB

# %%
COMP = COUNTS['ratio']/COUNTS_NOB['ratio']

# %%
HTML(nb.frame(COMP.sort_values(ascending=False)).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>fremstående</th>
#       <td>3.970329</td>
#     </tr>
#     <tr>
#       <th>verkende</th>
#       <td>3.559227</td>
#     </tr>
#     <tr>
#       <th>bydende</th>
#       <td>2.464312</td>
#     </tr>
#     <tr>
#       <th>overlevende</th>
#       <td>2.458442</td>
#     </tr>
#     <tr>
#       <th>besøkende</th>
#       <td>2.071236</td>
#     </tr>
#     <tr>
#       <th>flytende</th>
#       <td>1.909213</td>
#     </tr>
#     <tr>
#       <th>tiltalende</th>
#       <td>1.886774</td>
#     </tr>
#     <tr>
#       <th>gapende</th>
#       <td>1.861569</td>
#     </tr>
#     <tr>
#       <th>truende</th>
#       <td>1.857032</td>
#     </tr>
#     <tr>
#       <th>lovende</th>
#       <td>1.832177</td>
#     </tr>
#     <tr>
#       <th>dryppende</th>
#       <td>1.730636</td>
#     </tr>
#     <tr>
#       <th>skurrende</th>
#       <td>1.697565</td>
#     </tr>
#     <tr>
#       <th>drømmende</th>
#       <td>1.657210</td>
#     </tr>
#     <tr>
#       <th>angående</th>
#       <td>1.636030</td>
#     </tr>
#     <tr>
#       <th>bitende</th>
#       <td>1.592690</td>
#     </tr>
#     <tr>
#       <th>anerkjennende</th>
#       <td>1.574344</td>
#     </tr>
#     <tr>
#       <th>fristende</th>
#       <td>1.538485</td>
#     </tr>
#     <tr>
#       <th>fremtredende</th>
#       <td>1.494258</td>
#     </tr>
#     <tr>
#       <th>omgående</th>
#       <td>1.480908</td>
#     </tr>
#     <tr>
#       <th>voksende</th>
#       <td>1.470792</td>
#     </tr>
#     <tr>
#       <th>inngående</th>
#       <td>1.448069</td>
#     </tr>
#     <tr>
#       <th>ertende</th>
#       <td>1.443808</td>
#     </tr>
#     <tr>
#       <th>krypende</th>
#       <td>1.434773</td>
#     </tr>
#     <tr>
#       <th>trøstende</th>
#       <td>1.427550</td>
#     </tr>
#     <tr>
#       <th>flammende</th>
#       <td>1.423008</td>
#     </tr>
#     <tr>
#       <th>passende</th>
#       <td>1.413527</td>
#     </tr>
#     <tr>
#       <th>dansende</th>
#       <td>1.378584</td>
#     </tr>
#     <tr>
#       <th>værende</th>
#       <td>1.370392</td>
#     </tr>
#     <tr>
#       <th>strålende</th>
#       <td>1.365130</td>
#     </tr>
#     <tr>
#       <th>trettende</th>
#       <td>1.348550</td>
#     </tr>
#     <tr>
#       <th>hengende</th>
#       <td>1.340187</td>
#     </tr>
#     <tr>
#       <th>blomstrende</th>
#       <td>1.310590</td>
#     </tr>
#     <tr>
#       <th>skinnende</th>
#       <td>1.308850</td>
#     </tr>
#     <tr>
#       <th>gjennomtrengende</th>
#       <td>1.308050</td>
#     </tr>
#     <tr>
#       <th>tiltrekkende</th>
#       <td>1.289560</td>
#     </tr>
#     <tr>
#       <th>hylende</th>
#       <td>1.274719</td>
#     </tr>
#     <tr>
#       <th>flakkende</th>
#       <td>1.262610</td>
#     </tr>
#     <tr>
#       <th>krevende</th>
#       <td>1.252196</td>
#     </tr>
#     <tr>
#       <th>skjærende</th>
#       <td>1.244862</td>
#     </tr>
#     <tr>
#       <th>stående</th>
#       <td>1.243637</td>
#     </tr>
#     <tr>
#       <th>beundrende</th>
#       <td>1.239712</td>
#     </tr>
#     <tr>
#       <th>sittende</th>
#       <td>1.236263</td>
#     </tr>
#     <tr>
#       <th>dampende</th>
#       <td>1.231373</td>
#     </tr>
#     <tr>
#       <th>styrtende</th>
#       <td>1.222775</td>
#     </tr>
#     <tr>
#       <th>tilfredsstillende</th>
#       <td>1.204491</td>
#     </tr>
#     <tr>
#       <th>bønnfallende</th>
#       <td>1.201612</td>
#     </tr>
#     <tr>
#       <th>strømmende</th>
#       <td>1.195320</td>
#     </tr>
#     <tr>
#       <th>trykkende</th>
#       <td>1.192779</td>
#     </tr>
#     <tr>
#       <th>glitrende</th>
#       <td>1.182452</td>
#     </tr>
#     <tr>
#       <th>rasende</th>
#       <td>1.181469</td>
#     </tr>
#     <tr>
#       <th>triumferende</th>
#       <td>1.179636</td>
#     </tr>
#     <tr>
#       <th>skremmende</th>
#       <td>1.174180</td>
#     </tr>
#     <tr>
#       <th>forestående</th>
#       <td>1.165875</td>
#     </tr>
#     <tr>
#       <th>svulmende</th>
#       <td>1.149166</td>
#     </tr>
#     <tr>
#       <th>døende</th>
#       <td>1.142898</td>
#     </tr>
#     <tr>
#       <th>klagende</th>
#       <td>1.141927</td>
#     </tr>
#     <tr>
#       <th>svevende</th>
#       <td>1.141256</td>
#     </tr>
#     <tr>
#       <th>manglende</th>
#       <td>1.138045</td>
#     </tr>
#     <tr>
#       <th>skrikende</th>
#       <td>1.134669</td>
#     </tr>
#     <tr>
#       <th>lignende</th>
#       <td>1.132465</td>
#     </tr>
#     <tr>
#       <th>blendende</th>
#       <td>1.131819</td>
#     </tr>
#     <tr>
#       <th>brennende</th>
#       <td>1.123907</td>
#     </tr>
#     <tr>
#       <th>glimrende</th>
#       <td>1.119288</td>
#     </tr>
#     <tr>
#       <th>dinglende</th>
#       <td>1.112931</td>
#     </tr>
#     <tr>
#       <th>anklagende</th>
#       <td>1.112214</td>
#     </tr>
#     <tr>
#       <th>stigende</th>
#       <td>1.111170</td>
#     </tr>
#     <tr>
#       <th>bølgende</th>
#       <td>1.103251</td>
#     </tr>
#     <tr>
#       <th>omfattende</th>
#       <td>1.100556</td>
#     </tr>
#     <tr>
#       <th>løpende</th>
#       <td>1.074990</td>
#     </tr>
#     <tr>
#       <th>skingrende</th>
#       <td>1.071273</td>
#     </tr>
#     <tr>
#       <th>vedkommende</th>
#       <td>1.068077</td>
#     </tr>
#     <tr>
#       <th>fortryllende</th>
#       <td>1.063578</td>
#     </tr>
#     <tr>
#       <th>liggende</th>
#       <td>1.057652</td>
#     </tr>
#     <tr>
#       <th>hviskende</th>
#       <td>1.057332</td>
#     </tr>
#     <tr>
#       <th>tilsvarende</th>
#       <td>1.054538</td>
#     </tr>
#     <tr>
#       <th>ledende</th>
#       <td>1.041273</td>
#     </tr>
#     <tr>
#       <th>utelukkende</th>
#       <td>1.041191</td>
#     </tr>
#     <tr>
#       <th>sjarmerende</th>
#       <td>1.037299</td>
#     </tr>
#     <tr>
#       <th>forvirrende</th>
#       <td>1.032731</td>
#     </tr>
#     <tr>
#       <th>foruroligende</th>
#       <td>1.028571</td>
#     </tr>
#     <tr>
#       <th>flagrende</th>
#       <td>1.021080</td>
#     </tr>
#     <tr>
#       <th>kvelende</th>
#       <td>1.018182</td>
#     </tr>
#     <tr>
#       <th>vitende</th>
#       <td>1.013030</td>
#     </tr>
#     <tr>
#       <th>sovende</th>
#       <td>1.009706</td>
#     </tr>
#     <tr>
#       <th>utseende</th>
#       <td>1.006853</td>
#     </tr>
#     <tr>
#       <th>beroligende</th>
#       <td>1.002898</td>
#     </tr>
#     <tr>
#       <th>skjelvende</th>
#       <td>0.996418</td>
#     </tr>
#     <tr>
#       <th>imponerende</th>
#       <td>0.995703</td>
#     </tr>
#     <tr>
#       <th>utfordrende</th>
#       <td>0.988005</td>
#     </tr>
#     <tr>
#       <th>bebreidende</th>
#       <td>0.987423</td>
#     </tr>
#     <tr>
#       <th>tvilende</th>
#       <td>0.982392</td>
#     </tr>
#     <tr>
#       <th>farende</th>
#       <td>0.981537</td>
#     </tr>
#     <tr>
#       <th>levende</th>
#       <td>0.977502</td>
#     </tr>
#     <tr>
#       <th>rullende</th>
#       <td>0.975996</td>
#     </tr>
#     <tr>
#       <th>gående</th>
#       <td>0.964652</td>
#     </tr>
#     <tr>
#       <th>irriterende</th>
#       <td>0.958513</td>
#     </tr>
#     <tr>
#       <th>stormende</th>
#       <td>0.947244</td>
#     </tr>
#     <tr>
#       <th>støyende</th>
#       <td>0.942463</td>
#     </tr>
#     <tr>
#       <th>dirrende</th>
#       <td>0.929397</td>
#     </tr>
#     <tr>
#       <th>spennende</th>
#       <td>0.928560</td>
#     </tr>
#     <tr>
#       <th>rykende</th>
#       <td>0.923510</td>
#     </tr>
#     <tr>
#       <th>gråtende</th>
#       <td>0.912040</td>
#     </tr>
#     <tr>
#       <th>brølende</th>
#       <td>0.911605</td>
#     </tr>
#     <tr>
#       <th>misbilligende</th>
#       <td>0.907975</td>
#     </tr>
#     <tr>
#       <th>pågående</th>
#       <td>0.904110</td>
#     </tr>
#     <tr>
#       <th>rørende</th>
#       <td>0.897745</td>
#     </tr>
#     <tr>
#       <th>glinsende</th>
#       <td>0.896617</td>
#     </tr>
#     <tr>
#       <th>svingende</th>
#       <td>0.882551</td>
#     </tr>
#     <tr>
#       <th>glødende</th>
#       <td>0.871248</td>
#     </tr>
#     <tr>
#       <th>reisende</th>
#       <td>0.866783</td>
#     </tr>
#     <tr>
#       <th>nedlatende</th>
#       <td>0.862222</td>
#     </tr>
#     <tr>
#       <th>overveldende</th>
#       <td>0.852182</td>
#     </tr>
#     <tr>
#       <th>stinkende</th>
#       <td>0.843208</td>
#     </tr>
#     <tr>
#       <th>smilende</th>
#       <td>0.833944</td>
#     </tr>
#     <tr>
#       <th>fascinerende</th>
#       <td>0.831229</td>
#     </tr>
#     <tr>
#       <

# %%
COUNTS['participle'].loc['glimrende']
# Out:
# 288.0

# %%
COUNTS_NOB['participle'].loc['verkende']
# Out:
# 68.0

# %%
all_participles = list(set(COUNTS.participle.index) | set(COUNTS_NOB.participle.index))

# %% [markdown]
# # Make concordances of all from both corpora

# %% [markdown]
# ## Aggregates of texts

# %%
TEXT_NOB.sum(axis=1).sum()
# Out:
# 15195470.0

# %%
TEXT.sum(axis=1).sum()
# Out:
# 22656570.0

# %%
verb_paradigme = lambda x: [p for p in nb.word_paradigm(x) if p[0] == 'verb'][0][1:][0] + [x]
paradigme_streng = lambda x: ', '.join(verb_paradigme(x))

# %%
verb_paradigme('leende')
# Out:
# ['le',
#  'ledd',
#  'ler',
#  'les',
#  'lo',
#  'lea',
#  'lee',
#  'leer',
#  'lees',
#  'leet',
#  'leende']

# %%
nb.nb_ngram(paradigme_streng('gående'), years=(1920, 2000)).plot(lw=8, alpha=0.7, figsize=(15, 10))

# %%
nb.nb_ngram(paradigme_streng('glimrende'), years=(1920, 2000)).plot(lw=8, alpha=0.7, figsize=(15, 10))

# %%
nb.nb_ngram(paradigme_streng('strålende'), years=(1920, 2000)).plot(lw=8, alpha=0.7, figsize=(15, 10))

# %%
nb.nb_ngram('* går', years=(1920, 2000)).plot(lw=8, alpha=0.7, figsize=(15, 10))

# %%
punkt = nb.unigram('.', ddk="8%", trans='eng', period=(1945, 2000))

# %%
like = nb.unigram('likestilling', ddk="8%", trans='eng', period = (1945, 2000))

# %%
def relfrekvens(word, **kwarg):
    punkt = nb.unigram('.', **kwarg)
    wd = nb.unigram(word, **kwarg)
    return nb.frame(wd/punkt, word)

# %%
relfrekvens('likestilling',media='bok', period=(1950, 1990)).plot()

# %%
relfrekvens('abort',media='bok', period=(1950, 1990)).plot()

# %%
nb.unigram('verkende', ddk="8%", trans='eng', period=(1945, 2000)).plot()

# %%
relfrekvens('verkende',ddk="8%", trans='eng', period=(1945, 2000)).plot()

# %%
relfrekvens('verkende', ddk="8%", trans='', period=(1945, 2000)).plot()

# %%
counts_tot = dict()
for w in participles:
    counts_tot[w] = max(1, TOT.loc[list(set(participles[w][0]) & set(TOT.index))].sum(axis=1).sum())

# %%
counts_tot
# Out:
# {'stående': 19437983,
#  'rasende': 635995,
#  'sittende': 19514023,
#  'levende': 5312408,
#  'liggende': 14864068,
#  'strålende': 323529,
#  'skinnende': 864480,
#  'smilende': 3740043,
#  'skjelvende': 683719,
#  'spennende': 751509,
#  'utseende': 73206,
#  'hengende': 2623103,
#  'gående': 39842605,
#  'truende': 2250953,
#  'skremmende': 643472,
#  'løpende': 4492046,
#  'passende': 3018854,
#  'lignende': 1124850,
#  'beroligende': 161135,
#  'brennende': 1559790,
#  'spørrende': 7493284,
#  'vedkommende': 67666,
#  'flytende': 644943,
#  'tiltrekkende': 202167,
#  'triumferende': 1,
#  'glitrende': 131025,
#  'følgende': 8535735,
#  'overraskende': 561859,
#  'nølende': 385535,
#  'imponerende': 200342,
#  'sjarmerende': 1,
#  'lysende': 5765415,
#  'utelukkende': 329885,
#  'oppmuntrende': 242364,
#  'glødende': 214013,
#  'døende': 4840940,
#  'forbausende': 400348,
#  'avgjørende': 1212211,
#  'forbløffende': 123009,
#  'besøkende': 1711432,
#  'overbevisende': 674140,
#  'overveldende': 91829,
#  'skingrende': 1,
#  'glimrende': 1,
#  'overlevende': 539336,
#  'omgående': 141789,
#  'utfordrende': 224945,
#  'ertende': 492511,
#  'beundrende': 310904,
#  'tilfredsstillende': 485378,
#  'unnskyldende': 186425,
#  'angående': 572794,
#  'advarende': 336853,
#  'flammende': 286779,
#  'sovende': 1918683,
#  'blendende': 45274,
#  'manglende': 1487689,
#  'bebreidende': 122541,
#  'granskende': 296067,
#  'skrikende': 1517043,
#  'undrende': 591936,
#  'bølgende': 428659,
#  'forvirrende': 425876,
#  'hviskende': 1065417,
#  'tiltalende': 361018,
#  'irriterende': 424946,
#  'inngående': 1462879,
#  'bitende': 2679536,
#  'tvilende': 1672519,
#  'leende': 11129835,
#  'beskyttende': 935404,
#  'drømmende': 1316239,
#  'drivende': 4946841,
#  'gjennomtrengende': 1,
#  'fristende': 555809,
#  'omfattende': 2236106,
#  'stinkende': 54910,
#  'farende': 209473618,
#  'skjærende': 1466481,
#  'tilsvarende': 429668,
#  'stigende': 2449803,
#  'hylende': 323015,
#  'dirrende': 152646,
#  'trykkende': 2244371,
#  'stirrende': 2031773,
#  'stikkende': 2465419,
#  'vitende': 20200355,
#  'bønnfallende': 38809,
#  'kjørende': 2925304,
#  'stormende': 530861,
#  'foruroligende': 1,
#  'klagende': 892211,
#  'trøstende': 562073,
#  'flakkende': 57799,
#  'glinsende': 32526,
#  'styrtende': 887095,
#  'svulmende': 37145,
#  'fascinerende': 64972,
#  'ledende': 3303148,
#  'værende': 456572224,
#  'dampende': 231783,
#  'støyende': 197402,
#  'dryppende': 168965,
#  'prøvende': 5113315,
#  'undersøkende': 1342556,
#  'dinglende': 46020,
#  'lovende': 6004705,
#  'dansende': 1756754,
#  'kommende': 50235401,
#  'rørende': 1620765,
#  'anstrengende': 247621,
#  'nedlatende': 1,
#  'forestående': 61255,
#  'kvelende': 220722,
#  'misbilligende': 1,
#  'anerkjennende': 361350,
#  'trettende': 710078,
#  'strømmende': 1067752,
#  'fortryllende': 1,
#  'blomstrende': 240663,
#  'gapende': 176804,
#  'bedende': 4314613,
#  'reisende': 7050128,
#  'gråtende': 1525995,
#  'fremstående': 302046,
#  'svingende': 1183951,
#  'skurrende': 1,
#  'gjeldende': 10220434,
#  'svevende': 198063,
#  'brølende': 359925,
#  'pågående': 236585,
#  'voksende': 2280580,
#  'verkende': 1757228,
#  'rykende': 451188,
#  'rullende': 761704,
#  'vaklende': 151315,
#  'flagrende': 43466,
#  'ventende': 5696101,
#  'krevende': 3374824,
#  'anklagende': 289970,
#  'bydende': 495097,
#  'troende': 11323581,
#  'fremtredende': 62699,
#  'krypende': 589197}

# %%
count_frame_tot = {x: {'verb_paradigm': counts_tot[x], 'participle': TOT.loc[x].sum()} for x in counts_tot if x in TOT.index}

# %%
TOTCOUNT = nb.frame(count_frame_tot)

# %%
TOTCOUNT
# Out:
#                    verb_paradigm  participle
# advarende                 336853       66111
# anerkjennende             361350       46021
# angående                  572794      267385
# anklagende                289970       36067
# anstrengende              247621       72006
# avgjørende               1212211     1008752
# bebreidende               122541       42515
# bedende                  4314613       62088
# beroligende               161135      171112
# beskyttende               935404      101438
# besøkende                1711432      124985
# beundrende                310904       55098
# bitende                  2679536       55127
# blendende                  45274       67854
# blomstrende               240663      102584
# brennende                1559790      243684
# brølende                  359925       30360
# bydende                   495097       39578
# bølgende                  428659       70373
# bønnfallende               38809       28097
# dampende                  231783       43486
# dansende                 1756754       56382
# dinglende                  46020       30994
# dirrende                  152646       69947
# drivende                 4946841      119152
# dryppende                 168965       35657
# drømmende                1316239       60895
# døende                   4840940      126117
# ertende                   492511       71882
# farende                209473618       71677
# ...                          ...         ...
# styrtende                 887095       42938
# stående                 19437983     1229940
# støyende                  197402       52225
# svevende                  198063       59025
# svingende                1183951       50676
# svulmende                  37145       45314
# tilfredsstillende         485378      507238
# tilsvarende               429668     1682439
# tiltalende                361018       90415
# tiltrekkende              202167      109016
# trettende                 710078       46913
# triumferende                   1       96177
# troende                 11323581      265522
# truende                  2250953      272187
# trykkende                2244371       72605
# trøstende                 562073       51994
# tvilende                 1672519       73501
# undersøkende             1342556       40720
# undrende                  591936       73672
# unnskyldende              186425       53705
# utelukkende               329885      389967
# utfordrende               224945      143066
# utseende                   73206      348198
# vaklende                  151315       61035
# vedkommende                67666     1744651
# ventende                 5696101       60326
# verkende                 1757228       35173
# vitende                 20200355       78416
# voksende                 2280580      202621
# værende                456572224      191340
#
# [144 rows x 2 columns]

# %%
TOTCOUNT['ratio'] = TOTCOUNT['participle']/(TOTCOUNT['participle']+TOTCOUNT['verb_paradigm'])

# %%
TOTCOUNT.sort_values(by='ratio', ascending=False)
# Out:
#                    verb_paradigm  participle     ratio
# glimrende                      1      185539  0.999995
# sjarmerende                    1      103095  0.999990
# triumferende                   1       96177  0.999990
# skingrende                     1       70651  0.999986
# gjennomtrengende               1       53225  0.999981
# nedlatende                     1       51633  0.999981
# foruroligende                  1       48308  0.999979
# fortryllende                   1       40939  0.999976
# misbilligende                  1       27242  0.999963
# skurrende                      1       22798  0.999956
# vedkommende                67666     1744651  0.962663
# utseende                   73206      348198  0.826281
# tilsvarende               429668     1682439  0.796569
# fremtredende               62699      177705  0.739193
# glinsende                  32526       81620  0.715049
# overveldende               91829      155546  0.628786
# blendende                  45274       67854  0.599798
# forestående                61255       84677  0.580250
# svulmende                  37145       45314  0.549534
# utelukkende               329885      389967  0.541732
# flagrende                  43466       48351  0.526602
# strålende                 323529      346513  0.517151
# beroligende               161135      171112  0.515014
# tilfredsstillende         485378      507238  0.511011
# fascinerende               64972       67227  0.508529
# imponerende               200342      204546  0.505192
# stinkende                  54910       55014  0.500473
# rasende                   635995      557062  0.466920
# lignende                 1124850      983244  0.466414
# glitrende                 131025      112910  0.462869
# ...                          ...         ...       ...
# tvilende                 1672519       73501  0.042096
# svingende                1183951       50676  0.041046
# skjærende                1466481       61048  0.039965
# strømmende               1067752       42239  0.038053
# gråtende                 1525995       59659  0.037624
# lysende                  5765415      205146  0.034360
# sittende                19514023      673395  0.033357
# trykkende                2244371       72605  0.031336
# dansende                 1756754       56382  0.031096
# undersøkende             1342556       40720  0.029437
# stikkende                2465419       66512  0.026269
# reisende                 7050128      185766  0.025673
# døende                   4840940      126117  0.025391
# kjørende                 2925304       75802  0.025258
# drivende                 4946841      119152  0.023520
# troende                 11323581      265522  0.022911
# spørrende                7493284      166140  0.021691
# stirrende                2031773       44874  0.021609
# bitende                  2679536       55127  0.020159
# verkende                 1757228       35173  0.019623
# lovende                  6004705      103428  0.016933
# bedende                  4314613       62088  0.014186
# prøvende                 5113315       54768  0.010597
# ventende                 5696101       60326  0.010480
# leende                  11129835       99493  0.008860
# gående                  39842605      296548  0.007388
# kommende                50235401      326006  0.006448
# vitende                 20200355       78416  0.003867
# værende                456572224      191340  0.000419
# farende                209473618       71677  0.000342
#
# [144 rows x 3 columns]

# %%
TOTCOUNT.sort_values(by='ratio', ascending=False)[:80]['ratio'].plot(kind='bar', figsize=(15, 8), rot=80)

# %%
relaterte = dict()
for w in TOTCOUNT.sort_values(by='ratio', ascending=False)[:50].index:
    try:
        relaterte[w] = nb.relaterte_ord(w)
    except:
        print('problem: ', w)
# Out:
# problem:  triumferende
# problem:  skingrende
# problem:  gjennomtrengende
# problem:  nedlatende
# problem:  misbilligende
# problem:  skurrende
# problem:  vedkommende
# problem:  glinsende
# problem:  overveldende
# problem:  utelukkende
# problem:  glitrende
# problem:  flakkende
# problem:  forbløffende
# problem:  bønnfallende
# problem:  dinglende
# problem:  flytende
# problem:  omgående
# problem:  angående
# problem:  dirrende

# %%
import dhlab.graph_networkx_louvain as gnl

# %%
for participle in relaterte:
    mu.printmd("## {p} \n {words}\n".format(p=participle, words = ", ".join(relaterte[participle])))
# Out:
# ## glimrende
#  snø, sol, sne, glimrende, kuldegrader, vind, regn, fint, kulde, slaps, is, sludd, frost, skiføre, isdekke, glatt, vindstille, tåke, fleksibel, nydelig
# ## sjarmerende
#  sjarmerende, morsom, hyggelig, underholdende, blid, utadvendt, innholdsrik, lærerik, dyktig, grei, kjekk, tiltalende, koselig, vittig, interessant, søt, spennende, inspirerende, omgjengelig, hjelpsom
# ## foruroligende
#  kraft, energi, vilje, styrke, fart, spenst, foruroligende, tyngde, fylde, farlig, uoversiktlig, vanskelig, uforutsigbar
# ## fortryllende
#  fargerik, poetisk, dramatisk, humoristisk, vakker, fortryllende, festlig, fantasifull, flott, frodig, spennende, variert, mangfoldig, morsom, vittig, vakkert, varm, musikalsk, burlesk, realistisk
# ## utseende
#  utseende, kvalitet, karakter, innhold, stil, størrelse, personlighet, smak, farge, sjarm, form, konsistens, omfang, soliditet, særpreg, væremåte, egenart, design, atmosfære, sunnhet
# ## tilsvarende
#  erfaring, kunnskap, praksis, kunnskaper, innsikt, rutine, utdannelse, kvalifikasjoner, kompetanse, relevant, fortrinnsvis, minimum, helst, allsidig, solid, tilsvarende, storhusholdning, servicehandel, ledererfaring, bakgrunn
# ## blendende
#  rent, blendende, tørt, hvitt, pent, blankt, ryddig, friskt, fint, vakkert, klart, velspilte, gammel, ny, spennende, reflekser
# ## forestående
#  pågående, frekk, aggressive, uredd, aktiv, utholdende, aggressiv, energisk
# ## svulmende
#  freidig, frodig
# ## flagrende
#  lys, flagrende, luft, romslig, vann, vand, pen, lyd, løst
# ## strålende
#  sol, strålende, vind, sne, kuldegrader, regn, fint, vindstille, varmegrader, plussgrader, himmel, varig, minusgrader, solskinn, frisk, tåke, varme, sjø, utsikt, tropevarme
# ## beroligende
#  amfetamin, alkohol, beroligende, avslappende, tabletter, piller, narkotiske, hasj, stimulerende, smertestillende, styrkende, ecstasy, LSD, rohypnol, hasjisj, kokain, marihuana, ecstacy, heroin, metamfetamin
# ## tilfredsstillende
#  forsvarlig, rasjonelt, betryggende, effektiv, tilfredsstillende, rimelig, stabil, tidsmessig, hurtig, billig, økonomisk, riktig, hensiktsmessig, fornuftig, effektivt, sikker, skånsom, målrettet, miljøvennlig, langsiktig
# ## fascinerende
#  utfordrende, inspirerende, spennende, interessant, lærerike, utviklende, lærerik, krevende, engasjerende, givende, lærerikt, fengslende, underholdende, fascinerende, variert, morsomt, interessante, varierende, morsom, gripende
# ## imponerende
#  spennende, inspirerende, skremmende, imponerende, rørende, morsomt, morsom, fengende, variert, utfordrende, engasjerende, utviklende, krevende, lærerik, lærerikt, givende, dramatisk, vakker, flott, storslått
# ## stinkende
#  forurensende, støyende
# ## rasende
#  oppgitt, skuffet, fortvilet, forbannet, lei, frustrerte, sint, opprørt, sjokkert, frustrert, irritert, sinte, rasende, provosert, deprimert, såret, desillusjonert, forbanna, føler, fortvilt
# ## lignende
#  konserter, messer, lignende, arrangementer, utstillinger, festivaler, seminarer, workshops, andre, turneer, teater, kunstutstillinger, plateinnspillinger, foredrag, forestillinger, teaterforestillinger, markeder, konferanser, kongresser, stands
# ## avgjørende
#  viktig, avgjørende, krevende, interessant, viktige, spennende, sentrale, verdifull, nødvendig, verdifullt, prinsipiell, riktig, sentral, positivt, nyttig, meningsfylt, gledelig, endelige, utfordrende, interessante
# ## glødende
#  røyk, aske, glødende, damp, sot, ild, støv, pliktoppfyllende, dyr, flammer, fyll, husdyr, alkohol, lukt, snus, slagg, svovel, lava, ruiner, stein
# ## spennende
#  spennende, utfordrende, interessant, utviklende, givende, lærerikt, krevende, lærerik, variert, inspirerende, underholdende, morsomt, interessante, engasjerende, morsom, selvstendig, hektisk, stimulerende, varierte, utfordrande
# ## utfordrende
#  utviklende, utfordrende, spennende, krevende, inspirerende, interessant, givende, lærerikt, stimulerende, interessante, lærerike, lærerik, Interessant, variert, selvstendig, varierende, selvstendige, varierte, allsidige, engasjerende
# ## overraskende
#  spennende, artig, morsom, morsomt, overraskende, interessant, hyggelig, utfordrende, underholdende, inspirerende, skremmende, lærerik, provoserende, variert, annerledes, lærerikt, givende, hektisk, nyttig, velspilt
# ## pågående
#  resultatorientert, utadvendt, målbevisst, selvstendig, pågående, utholdende, energisk, idérik, kreativ, offensiv, aktiv, initiativrik, uredd, ha, samarbeidsvillig, ansvarsbevisst, aggressiv, dyktig, systematisk, handlekraftig
# ## tiltrekkende
#  sjarmerende, tiltrekkende, spennende, skremmende, morsom, søt, underholdende, hyggelig, sexy, variert, pen, vakker, koselig, innholdsrik, tiltalende, ungdommelig, intelligent, frastøtende, sund, mystisk
# ## omfattende
#  omfattende, krevende, komplisert, tidkrevende, kostbar, kostbart, variert, vanskelig, kompliserte, allsidig, langvarig, ressurskrevende, grundig, utfordrende, kostbare, systematisk, detaljert, kompleks, langvarige, selvstendig
# ## blomstrende
#  gronne, grønne, trivelige, blomstrende, rolige, barnevennlige, landlige, rode, frodige, gule, solrike, hvite, gjestfrie, allsidige, blå, hyggelige, hjelpsomme, dyktige, brune, røde
# ## manglende
#  usikkerhet, manglende, mangel, uvitenhet, misforståelser, fattigdom, rot, frykt, forvirring, angst, utrygghet, fortvilelse, ensomhet, arbeidsledighet, korrupsjon, fordommer, ustabilitet, engstelse, uro, uklarhet
# ## oppmuntrende
#  inspirerende, stimulerende, hyggelig, spennende, overraskende, morsomt, utfordrende, trivelig, engasjerende, utviklende, krevende, faglig, lærerik, ekspansivt, uformelt, aktivt, oppmuntrende, gledelig, positivt, lærerikt
# ## vaklende
#  usikre, vaklende, utrygge, engstelige, frustrerte, forvirret, redde, vanskelige, urolige, nervøse, svak, sterk, splittet
# ## skremmende
#  skremmende, spennende, trist, tankevekkende, sjokkerende, farlig, overraskende, übehagelig, truende, fascinerende, skuffende, uvirkelig, vond, tiltrekkende, mystisk, uforutsigbare, uhyggelig, pirrende, morsom, interessant

# %%
TOTCOUNT
# Out:
#                    verb_paradigm  participle     ratio
# advarende                 336853       66111  0.164062
# anerkjennende             361350       46021  0.112971
# angående                  572794      267385  0.318248
# anklagende                289970       36067  0.110622
# anstrengende              247621       72006  0.225281
# avgjørende               1212211     1008752  0.454196
# bebreidende               122541       42515  0.257579
# bedende                  4314613       62088  0.014186
# beroligende               161135      171112  0.515014
# beskyttende               935404      101438  0.097834
# besøkende                1711432      124985  0.068059
# beundrende                310904       55098  0.150540
# bitende                  2679536       55127  0.020159
# blendende                  45274       67854  0.599798
# blomstrende               240663      102584  0.298864
# brennende                1559790      243684  0.135119
# brølende                  359925       30360  0.077789
# bydende                   495097       39578  0.074023
# bølgende                  428659       70373  0.141019
# bønnfallende               38809       28097  0.419947
# dampende                  231783       43486  0.157976
# dansende                 1756754       56382  0.031096
# dinglende                  46020       30994  0.402446
# dirrende                  152646       69947  0.314237
# drivende                 4946841      119152  0.023520
# dryppende                 168965       35657  0.174258
# drømmende                1316239       60895  0.044219
# døende                   4840940      126117  0.025391
# ertende                   492511       71882  0.127362
# farende                209473618       71677  0.000342
# ...                          ...         ...       ...
# styrtende                 887095       42938  0.046168
# stående                 19437983     1229940  0.059510
# støyende                  197402       52225  0.209212
# svevende                  198063       59025  0.229591
# svingende                1183951       50676  0.041046
# svulmende                  37145       45314  0.549534
# tilfredsstillende         485378      507238  0.511011
# tilsvarende               429668     1682439  0.796569
# tiltalende                361018       90415  0.200284
# tiltrekkende              202167      109016  0.350328
# trettende                 710078       46913  0.061973
# triumferende                   1       96177  0.999990
# troende                 11323581      265522  0.022911
# truende                  2250953      272187  0.107876
# trykkende                2244371       72605  0.031336
# trøstende                 562073       51994  0.084672
# tvilende                 1672519       73501  0.042096
# undersøkende             1342556       40720  0.029437
# undrende                  591936       73672  0.110684
# unnskyldende              186425       53705  0.223650
# utelukkende               329885      389967  0.541732
# utfordrende               224945      143066  0.388755
# utseende                   73206      348198  0.826281
# vaklende                  151315       61035  0.287426
# vedkommende                67666     1744651  0.962663
# ventende                 5696101       60326  0.010480
# verkende                 1757228       35173  0.019623
# vitende                 20200355       78416  0.003867
# voksende                 2280580      202621  0.081597
# værende                456572224      191340  0.000419
#
# [143 rows x 3 columns]

# %%
COMPTOT = COUNTS['ratio']/TOTCOUNT['ratio']

# %%
HTML(nb.frame(COMPTOT.sort_values(ascending=False)).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>verkende</th>
#       <td>6.321689</td>
#     </tr>
#     <tr>
#       <th>fremstående</th>
#       <td>5.488433</td>
#     </tr>
#     <tr>
#       <th>anerkjennende</th>
#       <td>4.457094</td>
#     </tr>
#     <tr>
#       <th>bitende</th>
#       <td>4.241693</td>
#     </tr>
#     <tr>
#       <th>leende</th>
#       <td>3.329909</td>
#     </tr>
#     <tr>
#       <th>inngående</th>
#       <td>3.174104</td>
#     </tr>
#     <tr>
#       <th>farende</th>
#       <td>2.876035</td>
#     </tr>
#     <tr>
#       <th>truende</th>
#       <td>2.856607</td>
#     </tr>
#     <tr>
#       <th>klagende</th>
#       <td>2.630188</td>
#     </tr>
#     <tr>
#       <th>bydende</th>
#       <td>2.517035</td>
#     </tr>
#     <tr>
#       <th>dansende</th>
#       <td>2.425508</td>
#     </tr>
#     <tr>
#       <th>ertende</th>
#       <td>2.370489</td>
#     </tr>
#     <tr>
#       <th>støyende</th>
#       <td>2.315698</td>
#     </tr>
#     <tr>
#       <th>undersøkende</th>
#       <td>2.312753</td>
#     </tr>
#     <tr>
#       <th>overlevende</th>
#       <td>2.172966</td>
#     </tr>
#     <tr>
#       <th>strømmende</th>
#       <td>2.147061</td>
#     </tr>
#     <tr>
#       <th>trykkende</th>
#       <td>1.965194</td>
#     </tr>
#     <tr>
#       <th>dampende</th>
#       <td>1.937270</td>
#     </tr>
#     <tr>
#       <th>gapende</th>
#       <td>1.892671</td>
#     </tr>
#     <tr>
#       <th>styrtende</th>
#       <td>1.889710</td>
#     </tr>
#     <tr>
#       <th>skjærende</th>
#       <td>1.877132</td>
#     </tr>
#     <tr>
#       <th>dryppende</th>
#       <td>1.822160</td>
#     </tr>
#     <tr>
#       <th>anklagende</th>
#       <td>1.813619</td>
#     </tr>
#     <tr>
#       <th>lovende</th>
#       <td>1.743419</td>
#     </tr>
#     <tr>
#       <th>krevende</th>
#       <td>1.694585</td>
#     </tr>
#     <tr>
#       <th>tiltalende</th>
#       <td>1.664300</td>
#     </tr>
#     <tr>
#       <th>bedende</th>
#       <td>1.621164</td>
#     </tr>
#     <tr>
#       <th>drømmende</th>
#       <td>1.598055</td>
#     </tr>
#     <tr>
#       <th>drivende</th>
#       <td>1.577066</td>
#     </tr>
#     <tr>
#       <th>omgående</th>
#       <td>1.565811</td>
#     </tr>
#     <tr>
#       <th>beundrende</th>
#       <td>1.548124</td>
#     </tr>
#     <tr>
#       <th>fristende</th>
#       <td>1.547213</td>
#     </tr>
#     <tr>
#       <th>oppmuntrende</th>
#       <td>1.542018</td>
#     </tr>
#     <tr>
#       <th>omfattende</th>
#       <td>1.513028</td>
#     </tr>
#     <tr>
#       <th>sittende</th>
#       <td>1.504831</td>
#     </tr>
#     <tr>
#       <th>utfordrende</th>
#       <td>1.498551</td>
#     </tr>
#     <tr>
#       <th>skinnende</th>
#       <td>1.489582</td>
#     </tr>
#     <tr>
#       <th>trøstende</th>
#       <td>1.487773</td>
#     </tr>
#     <tr>
#       <th>stående</th>
#       <td>1.481384</td>
#     </tr>
#     <tr>
#       <th>tiltrekkende</th>
#       <td>1.458144</td>
#     </tr>
#     <tr>
#       <th>tvilende</th>
#       <td>1.448301</td>
#     </tr>
#     <tr>
#       <th>hengende</th>
#       <td>1.441116</td>
#     </tr>
#     <tr>
#       <th>bebreidende</th>
#       <td>1.412332</td>
#     </tr>
#     <tr>
#       <th>granskende</th>
#       <td>1.407658</td>
#     </tr>
#     <tr>
#       <th>prøvende</th>
#       <td>1.403509</td>
#     </tr>
#     <tr>
#       <th>døende</th>
#       <td>1.386267</td>
#     </tr>
#     <tr>
#       <th>bølgende</th>
#       <td>1.372708</td>
#     </tr>
#     <tr>
#       <th>brennende</th>
#       <td>1.367105</td>
#     </tr>
#     <tr>
#       <th>beskyttende</th>
#       <td>1.349230</td>
#     </tr>
#     <tr>
#       <th>advarende</th>
#       <td>1.314773</td>
#     </tr>
#     <tr>
#       <th>rasende</th>
#       <td>1.314737</td>
#     </tr>
#     <tr>
#       <th>hylende</th>
#       <td>1.305316</td>
#     </tr>
#     <tr>
#       <th>besøkende</th>
#       <td>1.284067</td>
#     </tr>
#     <tr>
#       <th>forestående</th>
#       <td>1.268489</td>
#     </tr>
#     <tr>
#       <th>strålende</th>
#       <td>1.261090</td>
#     </tr>
#     <tr>
#       <th>pågående</th>
#       <td>1.246985</td>
#     </tr>
#     <tr>
#       <th>flammende</th>
#       <td>1.243423</td>
#     </tr>
#     <tr>
#       <th>liggende</th>
#       <td>1.242679</td>
#     </tr>
#     <tr>
#       <th>blomstrende</th>
#       <td>1.235045</td>
#     </tr>
#     <tr>
#       <th>utelukkende</th>
#       <td>1.183650</td>
#     </tr>
#     <tr>
#       <th>utseende</th>
#       <td>1.153416</td>
#     </tr>
#     <tr>
#       <th>gående</th>
#       <td>1.140130</td>
#     </tr>
#     <tr>
#       <th>stormende</th>
#       <td>1.107869</td>
#     </tr>
#     <tr>
#       <th>bønnfallende</th>
#       <td>1.095629</td>
#     </tr>
#     <tr>
#       <th>undrende</th>
#       <td>1.088710</td>
#     </tr>
#     <tr>
#       <th>unnskyldende</th>
#       <td>1.071151</td>
#     </tr>
#     <tr>
#       <th>skjelvende</th>
#       <td>1.061422</td>
#     </tr>
#     <tr>
#       <th>beroligende</th>
#       <td>1.051513</td>
#     </tr>
#     <tr>
#       <th>levende</th>
#       <td>1.040913</td>
#     </tr>
#     <tr>
#       <th>glitrende</th>
#       <td>1.023501</td>
#     </tr>
#     <tr>
#       <th>kvelende</th>
#       <td>1.011753</td>
#     </tr>
#     <tr>
#       <th>spørrende</th>
#       <td>1.010703</td>
#     </tr>
#     <tr>
#       <th>svevende</th>
#       <td>1.002235</td>
#     </tr>
#     <tr>
#       <th>gråtende</th>
#       <td>0.991311</td>
#     </tr>
#     <tr>
#       <th>tilsvarende</th>
#       <td>0.983384</td>
#     </tr>
#     <tr>
#       <th>dirrende</th>
#       <td>0.963352</td>
#     </tr>
#     <tr>
#       <th>svingende</th>
#       <td>0.961888</td>
#     </tr>
#     <tr>
#       <th>tilfredsstillende</th>
#       <td>0.960590</td>
#     </tr>
#     <tr>
#       <th>skrikende</th>
#       <td>0.956508</td>
#     </tr>
#     <tr>
#       <th>lysende</th>
#       <td>0.955637</td>
#     </tr>
#     <tr>
#       <th>rullende</th>
#       <td>0.951983</td>
#     </tr>
#     <tr>
#       <th>glimrende</th>
#       <td>0.950500</td>
#     </tr>
#     <tr>
#       <th>stikkende</th>
#       <td>0.942393</td>
#     </tr>
#     <tr>
#       <th>gjennomtrengende</th>
#       <td>0.942047</td>
#     </tr>
#     <tr>
#       <th>hviskende</th>
#       <td>0.940697</td>
#     </tr>
#     <tr>
#       <th>brølende</th>
#       <td>0.939938</td>
#     </tr>
#     <tr>
#       <th>rykende</th>
#       <td>0.937974</td>
#     </tr>
#     <tr>
#       <th>spennende</th>
#       <td>0.933784</td>
#     </tr>
#     <tr>
#       <th>stinkende</th>
#       <td>0.930492</td>
#     </tr>
#     <tr>
#       <th>blendende</th>
#       <td>0.927570</td>
#     </tr>
#     <tr>
#       <th>flytende</th>
#       <td>0.920432</td>
#     </tr>
#     <tr>
#       <th>sovende</th>
#       <td>0.911210</td>
#     </tr>
#     <tr>
#       <th>krypende</th>
#       <td>0.887444</td>
#     </tr>
#     <tr>
#       <th>sjarmerende</th>
#       <td>0.876177</td>
#     </tr>
#     <tr>
#       <th>smilende</th>
#       <td>0.871469</td>
#     </tr>
#     <tr>
#       <th>vedkommende</th>
#       <td>0.865981</td>
#     </tr>
#     <tr>
#       <th>stirrende</th>
#       <td>0.862066</td>
#     </tr>
#     <tr>
#       <th>flakkende</th>
#       <td>0.860720</td>
#     </tr>
#     <tr>
#       <th>misbilligende</th>
#       <td>0.857174</td>
#     </tr>
#     <tr>
#       <th>rørende</th>
#       <td>0.852607</td>
#     </tr>
#     <tr>
#       <th>triumferende</th>
#       <td>0.846817</td>
#     </tr>
#     <tr>
#       <th>skremmende</th>
#       <td>0.843480</td>
#     </tr>
#     <tr>
#       <th>overbevisende</th>
#       <td>0.840783</td>
#     </tr>
#     <tr>
#       <th>vitende</th>
#       <td>0.837392</td>
#     </tr>
#     <tr>
#       <th>glødende</th>
#       <td>0.834180</td>
#     </tr>
#     <tr>
#       <th>angående</th>
#       <td>0.823122</td>
#     </tr>
#     <tr>
#       <th>imponerende</th>
#       <td>0.822769</td>
#     </tr>
#     <tr>
#       <th>anstrengende</th>
#       <td>0.820777</td>
#     </tr>
#     <tr>
#       <th>svulmende</th>
#       <td>0.807631</td>
#     </tr>
#     <tr>
#       <th>dinglende</th>
#       <td>0.796815</td>
#     </tr>
#     <tr>
#       <th>passende</th>
#       <td>0.793191</td>
#     </tr>
#     <tr>
#       <th>skingrende</th>
#       <td>0.791792</td>
#     </tr>
#     <tr>
#       <th>foruroligende</th>
#       <td>0.784705</td>
#     </tr>
#     <tr>
#       <th>glinsende</th>
#       <td>0.777491</td>
#     </tr>
#     <tr>
#       <th>fortryllende</th>
#       <td>0.774744</td>
#     </tr>
#     <tr>

# %% [markdown]
# Henter kollokasjonene fra fil

# %%
def coll_to_dict_of_df(coll_):
    coll = dict()
    for i in coll_.index:
        coll[i] = pd.DataFrame(coll_.loc[i][0])
    return coll

# %%
collbefore = coll_to_dict_of_df(pd.read_json("ov_before.json"))
collafter = coll_to_dict_of_df(pd.read_json("ov_after.json"))
collbefore_nob = coll_to_dict_of_df(pd.read_json("bm_before.json"))
collafter_nob = coll_to_dict_of_df(pd.read_json('bm_after.json'))

# %%
left_coll = pd.read_json('left_coll.json')
right_coll = pd.read_json('right_coll.json')
left_nob = pd.read_json('left_nob.json')
right_nob = pd.read_json('right_nob.json')

# %%
ov_syntax = pd.concat([
    nb.frame(left_coll.loc[[x for x in hi_ov if x in left_coll.index]].sum(), 'høy oversatt før'),
    nb.frame(left_coll.loc[[x for x in lo_ov if x in left_coll.index]].sum(), 'lav oversatt før'),
    nb.frame(right_coll.loc[[x for x in hi_ov if x in right_coll.index]].sum(), 'høy oversatt etter'),
    nb.frame(right_coll.loc[[x for x in lo_ov if x in right_coll.index]].sum(), 'lav oversatt etter')],
         sort=False, axis=1).transpose()
           
ov_syntax = ov_syntax[sorted(ov_syntax)] 
ov_syntax['alle'] = ov_syntax.sum(axis=1)

# %%
ov_syntax[ov_syntax.columns[:-1]].style.background_gradient(axis = 1, cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col0 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col1 {
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col2 {
#             background-color:  #cddff1;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col3 {
#             background-color:  #3e8ec4;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col4 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col5 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col7 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col8 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col9 {
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col10 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col11 {
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row0_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col0 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col1 {
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col2 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col3 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col4 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col5 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col6 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col7 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col8 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col9 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col10 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col11 {
#             background-color:  #08509b;
#             color:  #f1f1f1;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row1_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col0 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col1 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col2 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col3 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col4 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col5 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col6 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col7 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col8 {
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col9 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col10 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row2_col13 {
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col0 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col1 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col2 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col3 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col6 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col7 {
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col8 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col9 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col10 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2row3_col13 {
#             background-color:  #64a9d3;
#             color:  #000000;
#         }</style><table id="T_c3c49bb0_10a9_11ea_89d8_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CLB</th>        <th class="col_heading level0 col1" >adj</th>        <th class="col_heading level0 col2" >adv</th>        <th class="col_heading level0 col3" >det</th>        <th class="col_heading level0 col4" >fork</th>        <th class="col_heading level0 col5" >henv</th>        <th class="col_heading level0 col6" >inte</th>        <th class="col

# %%
syntaks.style.background_gradient(axis=1, cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col0 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col1 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col2 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col3 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col4 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col5 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col6 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col7 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col8 {
#             background-color:  #c7dbef;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col9 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col10 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col13 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col0 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col1 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col2 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col3 {
#             background-color:  #71b1d7;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col4 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col5 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col7 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col8 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col9 {
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col10 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col11 {
#             background-color:  #2777b8;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col0 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col1 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col2 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col3 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col4 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col5 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col6 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col7 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col8 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col9 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col10 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col13 {
#             background-color:  #8abfdd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col0 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col1 {
#             background-color:  #2272b6;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col2 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col3 {
#             background-color:  #7cb7da;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col4 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col5 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col7 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col8 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col9 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col10 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col11 {
#             background-color:  #206fb4;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_80b92018_0f70_11ea_895c_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CLB</th>        <th class="col_heading level0 col1" >adj</th>        <th class="col_heading level0 col2" >adv</th>        <th class="col_heading level0 col3" >det</th>        <th class="col_heading level0 col4" >fork</th>        <th class="col_heading level0 col5" >henv</th>        <th class="col_heading level0 col6" >inte</th>        <th class="col

# %%
velg_form('veldig')
# Out:
# 'adj'

# %%
klassifikasjon(collbefore['glimrende'], num=50, column='0')
# Out:
#         det         verb ukjent      prep   pron      adv CLB      adj
# 0        en           så     En         i    meg  aldeles  og  taktisk
# 1        et          var      ,       for    seg     også         mest
# 2       det           er     Et  igjennom  denne                   mer
# 3      hans       passet      '
# 4       den        passe
# 5      sine       passer
# 6   hvilken          red
# 7    hennes       spilte
# 8      slik         like
# 9      noen        hadde
# 10      vår      oppnådd
# 11      sin  samarbeider
# 12    slike         sett
# 13                  tatt
# 14               snakket
# 15                   sov
# 16                   sto
# 17                  stod
# 18                  vært
# 19                  være
# 20                   nye

# %%
def show_class(df, num=50, column='0'):
    k = klassifikasjon(df, num=num, column=column)
    k = k[sorted(k.columns)]
    return k.style.set_table_styles(styles)

# %%
show_class(collbefore['glimrende'])
# Out:
# <style  type="text/css" >
#     #T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2 th {
#           font-size: 18px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7ffff;
#     }    #T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2 td {
#           font-size: 18px;
#     }</style><table id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CLB</th>        <th class="col_heading level0 col1" >adj</th>        <th class="col_heading level0 col2" >adv</th>        <th class="col_heading level0 col3" >det</th>        <th class="col_heading level0 col4" >prep</th>        <th class="col_heading level0 col5" >pron</th>        <th class="col_heading level0 col6" >ukjent</th>        <th class="col_heading level0 col7" >verb</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row0_col0" class="data row0 col0" >og</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row0_col1" class="data row0 col1" >taktisk</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row0_col2" class="data row0 col2" >aldeles</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row0_col3" class="data row0 col3" >en</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row0_col4" class="data row0 col4" >i</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row0_col5" class="data row0 col5" >meg</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row0_col6" class="data row0 col6" >En</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row0_col7" class="data row0 col7" >så</td>
#             </tr>
#             <tr>
#                         <th id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row1_col0" class="data row1 col0" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row1_col1" class="data row1 col1" >mest</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row1_col2" class="data row1 col2" >også</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row1_col3" class="data row1 col3" >et</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row1_col4" class="data row1 col4" >for</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row1_col5" class="data row1 col5" >seg</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row1_col6" class="data row1 col6" >,</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row1_col7" class="data row1 col7" >var</td>
#             </tr>
#             <tr>
#                         <th id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row2_col0" class="data row2 col0" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row2_col1" class="data row2 col1" >mer</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row2_col2" class="data row2 col2" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row2_col3" class="data row2 col3" >det</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row2_col4" class="data row2 col4" >igjennom</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row2_col5" class="data row2 col5" >denne</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row2_col6" class="data row2 col6" >Et</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row2_col7" class="data row2 col7" >er</td>
#             </tr>
#             <tr>
#                         <th id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row3_col0" class="data row3 col0" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row3_col1" class="data row3 col1" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row3_col2" class="data row3 col2" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row3_col3" class="data row3 col3" >hans</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row3_col4" class="data row3 col4" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row3_col5" class="data row3 col5" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row3_col6" class="data row3 col6" >'</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row3_col7" class="data row3 col7" >passet</td>
#             </tr>
#             <tr>
#                         <th id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row4_col0" class="data row4 col0" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row4_col1" class="data row4 col1" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row4_col2" class="data row4 col2" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row4_col3" class="data row4 col3" >den</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row4_col4" class="data row4 col4" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row4_col5" class="data row4 col5" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row4_col6" class="data row4 col6" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row4_col7" class="data row4 col7" >passe</td>
#             </tr>
#             <tr>
#                         <th id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row5_col0" class="data row5 col0" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row5_col1" class="data row5 col1" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row5_col2" class="data row5 col2" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row5_col3" class="data row5 col3" >sine</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row5_col4" class="data row5 col4" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row5_col5" class="data row5 col5" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row5_col6" class="data row5 col6" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row5_col7" class="data row5 col7" >passer</td>
#             </tr>
#             <tr>
#                         <th id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row6_col0" class="data row6 col0" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row6_col1" class="data row6 col1" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row6_col2" class="data row6 col2" ></td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row6_col3" class="data row6 col3" >hvilken</td>
#                         <td id="T_ec7e78d0_10b0_11ea_a5f4_000acd2bfab2row6_col4" class="data row6 col4" ></td>
#                         <td id="T_ec7e78d

# %%
show_class(collafter['glimrende'])
# Out:
# <style  type="text/css" >
#     #T_fa620698_10b0_11ea_8983_000acd2bfab2 th {
#           font-size: 18px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7ffff;
#     }    #T_fa620698_10b0_11ea_8983_000acd2bfab2 td {
#           font-size: 18px;
#     }</style><table id="T_fa620698_10b0_11ea_8983_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CLB</th>        <th class="col_heading level0 col1" >adj</th>        <th class="col_heading level0 col2" >adv</th>        <th class="col_heading level0 col3" >prep</th>        <th class="col_heading level0 col4" >sbu</th>        <th class="col_heading level0 col5" >subst</th>        <th class="col_heading level0 col6" >ukjent</th>        <th class="col_heading level0 col7" >verb</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fa620698_10b0_11ea_8983_000acd2bfab2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row0_col0" class="data row0 col0" >og</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row0_col1" class="data row0 col1" >ung</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row0_col2" class="data row0 col2" >sammen</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row0_col3" class="data row0 col3" >ut</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row0_col4" class="data row0 col4" >som</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row0_col5" class="data row0 col5" >idé</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row0_col6" class="data row0 col6" >.</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row0_col7" class="data row0 col7" >måte</td>
#             </tr>
#             <tr>
#                         <th id="T_fa620698_10b0_11ea_8983_000acd2bfab2level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row1_col0" class="data row1 col0" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row1_col1" class="data row1 col1" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row1_col2" class="data row1 col2" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row1_col3" class="data row1 col3" >til</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row1_col4" class="data row1 col4" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row1_col5" class="data row1 col5" >hukommelse</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row1_col6" class="data row1 col6" >,</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row1_col7" class="data row1 col7" >jobb</td>
#             </tr>
#             <tr>
#                         <th id="T_fa620698_10b0_11ea_8983_000acd2bfab2level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row2_col0" class="data row2 col0" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row2_col1" class="data row2 col1" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row2_col2" class="data row2 col2" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row2_col3" class="data row2 col3" >i</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row2_col4" class="data row2 col4" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row2_col5" class="data row2 col5" >anledning</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row2_col6" class="data row2 col6" >!</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row2_col7" class="data row2 col7" >plan</td>
#             </tr>
#             <tr>
#                         <th id="T_fa620698_10b0_11ea_8983_000acd2bfab2level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row3_col0" class="data row3 col0" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row3_col1" class="data row3 col1" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row3_col2" class="data row3 col2" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row3_col3" class="data row3 col3" >på</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row3_col4" class="data row3 col4" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row3_col5" class="data row3 col5" >rytter</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row3_col6" class="data row3 col6" >organisasjonstalent</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row3_col7" class="data row3 col7" >spøk</td>
#             </tr>
#             <tr>
#                         <th id="T_fa620698_10b0_11ea_8983_000acd2bfab2level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row4_col0" class="data row4 col0" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row4_col1" class="data row4 col1" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row4_col2" class="data row4 col2" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row4_col3" class="data row4 col3" >for</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row4_col4" class="data row4 col4" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row4_col5" class="data row4 col5" >kirurg</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row4_col6" class="data row4 col6" >utkikkspunkt</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row4_col7" class="data row4 col7" >stykke</td>
#             </tr>
#             <tr>
#                         <th id="T_fa620698_10b0_11ea_8983_000acd2bfab2level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row5_col0" class="data row5 col0" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row5_col1" class="data row5 col1" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row5_col2" class="data row5 col2" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row5_col3" class="data row5 col3" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row5_col4" class="data row5 col4" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row5_col5" class="data row5 col5" >skuespiller</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row5_col6" class="data row5 col6" >på-sparket-</td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row5_col7" class="data row5 col7" >lærer</td>
#             </tr>
#             <tr>
#                         <th id="T_fa620698_10b0_11ea_8983_000acd2bfab2level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row6_col0" class="data row6 col0" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row6_col1" class="data row6 col1" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row6_col2" class="data row6 col2" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row6_col3" class="data row6 col3" ></td>
#                         <td id="T_fa620698_10b0_11ea_8983_000acd2bfab2row6_col4" class="data row6 col4" ></td>

# %%
show_class(collbefore['kjørende'])
# Out:
# <style  type="text/css" >
#     #T_1cc3257e_10b1_11ea_90f2_000acd2bfab2 th {
#           font-size: 18px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7ffff;
#     }    #T_1cc3257e_10b1_11ea_90f2_000acd2bfab2 td {
#           font-size: 18px;
#     }</style><table id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >adj</th>        <th class="col_heading level0 col1" >adv</th>        <th class="col_heading level0 col2" >det</th>        <th class="col_heading level0 col3" >prep</th>        <th class="col_heading level0 col4" >pron</th>        <th class="col_heading level0 col5" >subst</th>        <th class="col_heading level0 col6" >ukjent</th>        <th class="col_heading level0 col7" >verb</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row0_col0" class="data row0 col0" >langsomt</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row0_col1" class="data row0 col1" >tilfeldigvis</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row0_col2" class="data row0 col2" >det</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row0_col3" class="data row0 col3" >de</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row0_col4" class="data row0 col4" >vi</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row0_col5" class="data row0 col5" >jeep</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row0_col6" class="data row0 col6" >Joe</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row0_col7" class="data row0 col7" >kom</td>
#             </tr>
#             <tr>
#                         <th id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row1_col0" class="data row1 col0" >mange</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row1_col1" class="data row1 col1" >aldri</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row1_col2" class="data row1 col2" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row1_col3" class="data row1 col3" >for</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row1_col4" class="data row1 col4" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row1_col5" class="data row1 col5" >limousinene</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row1_col6" class="data row1 col6" >limousine</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row1_col7" class="data row1 col7" >komme</td>
#             </tr>
#             <tr>
#                         <th id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row2_col0" class="data row2 col0" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row2_col1" class="data row2 col1" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row2_col2" class="data row2 col2" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row2_col3" class="data row2 col3" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row2_col4" class="data row2 col4" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row2_col5" class="data row2 col5" >konstabler</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row2_col6" class="data row2 col6" >renseribil</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row2_col7" class="data row2 col7" >kommer</td>
#             </tr>
#             <tr>
#                         <th id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row3_col0" class="data row3 col0" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row3_col1" class="data row3 col1" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row3_col2" class="data row3 col2" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row3_col3" class="data row3 col3" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row3_col4" class="data row3 col4" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row3_col5" class="data row3 col5" >limousinen</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row3_col6" class="data row3 col6" >120</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row3_col7" class="data row3 col7" >kommet</td>
#             </tr>
#             <tr>
#                         <th id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row4_col0" class="data row4 col0" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row4_col1" class="data row4 col1" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row4_col2" class="data row4 col2" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row4_col3" class="data row4 col3" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row4_col4" class="data row4 col4" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row4_col5" class="data row4 col5" >mannen</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row4_col6" class="data row4 col6" >Carthy</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row4_col7" class="data row4 col7" >bil</td>
#             </tr>
#             <tr>
#                         <th id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row5_col0" class="data row5 col0" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row5_col1" class="data row5 col1" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row5_col2" class="data row5 col2" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row5_col3" class="data row5 col3" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row5_col4" class="data row5 col4" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row5_col5" class="data row5 col5" >offiser</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row5_col6" class="data row5 col6" >Stikker</td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row5_col7" class="data row5 col7" >sett</td>
#             </tr>
#             <tr>
#                         <th id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row6_col0" class="data row6 col0" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row6_col1" class="data row6 col1" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row6_col2" class="data row6 col2" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row6_col3" class="data row6 col3" ></td>
#                         <td id="T_1cc3257e_10b1_11ea_90f2_000acd2bfab2row6_col4" class="data row6 col4

# %%
show_class(collafter['kjørende'])
# Out:
# <style  type="text/css" >
#     #T_427b7e4c_10b1_11ea_a862_000acd2bfab2 th {
#           font-size: 18px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7ffff;
#     }    #T_427b7e4c_10b1_11ea_a862_000acd2bfab2 td {
#           font-size: 18px;
#     }</style><table id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CLB</th>        <th class="col_heading level0 col1" >adj</th>        <th class="col_heading level0 col2" >adv</th>        <th class="col_heading level0 col3" >det</th>        <th class="col_heading level0 col4" >prep</th>        <th class="col_heading level0 col5" >pron</th>        <th class="col_heading level0 col6" >sbu</th>        <th class="col_heading level0 col7" >subst</th>        <th class="col_heading level0 col8" >ukjent</th>        <th class="col_heading level0 col9" >verb</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row0_col0" class="data row0 col0" >og</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row0_col1" class="data row0 col1" >samtidig</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row0_col2" class="data row0 col2" >sammen</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row0_col3" class="data row0 col3" >tjue</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row0_col4" class="data row0 col4" >i</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row0_col5" class="data row0 col5" >denne</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row0_col6" class="data row0 col6" >som</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row0_col7" class="data row0 col7" >trafikk</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row0_col8" class="data row0 col8" >.</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row0_col9" class="data row0 col9" >like</td>
#             </tr>
#             <tr>
#                         <th id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row1_col0" class="data row1 col0" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row1_col1" class="data row1 col1" >langsomt</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row1_col2" class="data row1 col2" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row1_col3" class="data row1 col3" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row1_col4" class="data row1 col4" >med</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row1_col5" class="data row1 col5" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row1_col6" class="data row1 col6" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row1_col7" class="data row1 col7" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row1_col8" class="data row1 col8" >,</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row1_col9" class="data row1 col9" >så</td>
#             </tr>
#             <tr>
#                         <th id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row2_col0" class="data row2 col0" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row2_col1" class="data row2 col1" >flere</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row2_col2" class="data row2 col2" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row2_col3" class="data row2 col3" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row2_col4" class="data row2 col4" >opp</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row2_col5" class="data row2 col5" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row2_col6" class="data row2 col6" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row2_col7" class="data row2 col7" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row2_col8" class="data row2 col8" >-</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row2_col9" class="data row2 col9" >når</td>
#             </tr>
#             <tr>
#                         <th id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row3_col0" class="data row3 col0" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row3_col1" class="data row3 col1" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row3_col2" class="data row3 col2" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row3_col3" class="data row3 col3" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row3_col4" class="data row3 col4" >nedover</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row3_col5" class="data row3 col5" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row3_col6" class="data row3 col6" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row3_col7" class="data row3 col7" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row3_col8" class="data row3 col8" >/</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row3_col9" class="data row3 col9" >meget</td>
#             </tr>
#             <tr>
#                         <th id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row4_col0" class="data row4 col0" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row4_col1" class="data row4 col1" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row4_col2" class="data row4 col2" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row4_col3" class="data row4 col3" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row4_col4" class="data row4 col4" >inn</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row4_col5" class="data row4 col5" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row4_col6" class="data row4 col6" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row4_col7" class="data row4 col7" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row4_col8" class="data row4 col8" >339</td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row4_col9" class="data row4 col9" ></td>
#             </tr>
#             <tr>
#                         <th id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row5_col0" class="data row5 col0" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row5_col1" class="data row5 col1" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row5_col2" class="data row5 col2" ></td>
#                         <td id="T_427b7e4c_10b1_11ea_a862_000acd2bfab2row5_col3" class="data row5 col3" ></td>

# %%
print(lo_ov, hi_ov)
# Out:
# ['værende', 'farende', 'kommende', 'vitende', 'troende', 'ventende', 'gående', 'reisende', 'prøvende', 'stirrende', 'tiende', 'kjørende', 'drepende', 'spørrende', 'boende', 'bedende', 'elskende', 'stikkende', 'leende', 'lovende'] ['fremtredende', 'glimrende', 'gjennomtrengende', 'utseende', 'sjarmerende', 'misbilligende', 'triumferende', 'unnvikende', 'vedkommende', 'aldrende', 'skingrende', 'fortryllende', 'foruroligende', 'tilsvarende', 'skurrende', 'frastøtende', 'forestående', 'fremstående', 'nedlatende', 'strålende']

# %%
lob = [x for y in lo_ov if y in collbefore for x in collbefore[y].sort_values(by='0', ascending=False)[:3].index ]
loa = [x for y in lo_ov if y in collafter for x in collafter[y].sort_values(by='0', ascending=False)[:3].index ]

hoa = [x for y in hi_ov if y in collafter for x in collafter[y].sort_values(by='0', ascending=False)[:3].index ]

hob = [x for y in hi_ov if y in collbefore for x in collbefore[y].sort_values(by='0', ascending=False)[:3].index ]

# %%
print(', '.join(list(set(lob))), "PART",
', '.join(list(set(loa))))

print(', '.join(list(set(hob))), "PART",
', '.join(list(set(hoa))))
# Out:
# mest, en, for, ble, det, kom, blir, komme, hun, og, de, vel, den, han, var, et, ,, jeg, så, bli, kommer, med PART opp, til, ut, blikk, inn, øyne, om, to, ukene, i, og, bilen, mot, ., her, som, ,, der, generasjoner, at, blikket, med, på
# mest, en, det, mer, av, hun, i, og, de, den, han, var, mitt, et, ,, rette, nær, sitt, at, noe, så, med PART kampen, smil, for, i, og, stemme, mann, ut, beløp, person, idé, blikk, som, ,, tanke, på, .

# %%
collbefore['gjennomtrengende'].sort_values(by='0', ascending=False)[:10]
# Out:
#             0     weight
# ,    0.169231   3.009468
# og   0.143590   5.151128
# en   0.107692   8.934372
# et   0.087179  16.369655
# den  0.076923   9.612290
# de   0.041026   5.362614
# så   0.035897  10.121567
# var  0.025641   2.989829
# med  0.025641   2.513973
# det  0.025641   1.677387

# %%
nb.heatmap(collbefore_nob['smilende'].sort_values(by='weight', ascending=False)[:50])
# Out:
# <style  type="text/css" >
#     #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row0_col0 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row1_col1 {
#             background-color:  #74c074;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row2_col0 {
#             background-color:  #7dc57d;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row2_col1 {
#             background-color:  #77c277;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row3_col1 {
#             background-color:  #7cc57c;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row4_col1 {
#             background-color:  #88cb88;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row5_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row5_col1 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row6_col0 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row6_col1 {
#             background-color:  #96d396;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row7_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row7_col1 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row8_col1 {
#             background-color:  #9ad59a;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row9_col1 {
#             background-color:  #abdfab;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row10_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row10_col1 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row11_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row11_col1 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row12_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row12_col1 {
#             background-color:  #b2e3b2;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row13_col0 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row13_col1 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row14_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row14_col1 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row15_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row15_col1 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row16_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row16_col1 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row17_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row17_col1 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row18_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row18_col1 {
#             background-color:  #c9efc9;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row19_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row19_col1 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row20_col0 {
#             background-color:  #a7dda7;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row20_col1 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row21_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row21_col1 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row22_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row22_col1 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row23_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row23_col1 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row24_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row24_col1 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row25_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row25_col1 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row26_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row26_col1 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row27_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row27_col1 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row28_col0 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row28_col1 {
#             background-color:  #d6f7d6;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row29_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_6d28d506_0fe9_11ea_8cd9_000acd2bfab2row29_col1 {
#             background-color:  #

# %% [markdown]
# Lag liste med fordeling av kategorier for ord

# %% [markdown]
# Lagre for å hente ut igjen

# %%
left_nob.fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col3 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col7 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col8 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col9 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col11 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row0_col13 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col0 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col1 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col3 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col7 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col8 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col9 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col11 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row1_col13 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col1 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col2 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col3 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col9 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col10 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row2_col13 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col1 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col3 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col7 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col8 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col9 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col10 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row3_col13 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row4_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row4_col1 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row4_col2 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_ee95ebc2_0f6e_11ea_a3e0_000acd2bfab2row4_col3 {
#             background-color:  #bcc7e1;
#             colo

# %%
left_coll.fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col1 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col3 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col7 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col8 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col11 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row0_col13 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col0 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col1 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col2 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col4 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col5 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col7 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col8 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col9 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col11 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row1_col13 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col1 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col3 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col8 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col9 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row2_col13 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col0 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col1 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col2 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col3 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col7 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col8 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col9 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row3_col13 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row4_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row4_col2 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_f057569a_0f6e_11ea_b4ed_000acd2bfab2row4_col3 {
#             background-color:  #d7d6e9;
#             colo

# %%
right_nob.fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col0 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col1 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col2 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col3 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col6 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col7 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col8 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row0_col13 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col1 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col2 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col3 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col7 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col8 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col10 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row1_col13 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col1 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col2 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col8 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col9 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col11 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col12 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row2_col13 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col2 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col7 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col8 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row3_col13 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row4_col0 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row4_col1 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row4_col2 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_ef7248a6_0f6e_11ea_b0f4_000acd2bfab2row4_col3 {
#             background-color:  #fff7fb;
#             colo

# %%
right_coll.fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col1 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col7 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col8 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col9 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col10 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row0_col13 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col1 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col2 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col3 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col7 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col8 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row1_col13 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col2 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col7 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col8 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col9 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col11 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col12 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row2_col13 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col2 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col7 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col8 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col9 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col10 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row3_col13 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row4_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row4_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row4_col2 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_f1367264_0f6e_11ea_a228_000acd2bfab2row4_col3 {
#             background-color:  #f4eef6;
#             colo

# %%
syntaks = nb.frame({'bm_før':left_nob.sum(), 'oversatt_før': left_coll.sum(), 'bm_etter':right_nob.sum(), 'oversatt_etter':right_coll.sum()})

# %%
syntaks.style.background_gradient(axis=1, cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col0 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col1 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col2 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col3 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col4 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col5 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col6 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col7 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col8 {
#             background-color:  #c7dbef;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col9 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col10 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row0_col13 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col0 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col1 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col2 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col3 {
#             background-color:  #71b1d7;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col4 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col5 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col7 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col8 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col9 {
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col10 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col11 {
#             background-color:  #2777b8;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row1_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col0 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col1 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col2 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col3 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col4 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col5 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col6 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col7 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col8 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col9 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col10 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row2_col13 {
#             background-color:  #8abfdd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col0 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col1 {
#             background-color:  #2272b6;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col2 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col3 {
#             background-color:  #7cb7da;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col4 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col5 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col7 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col8 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col9 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col10 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col11 {
#             background-color:  #206fb4;
#             color:  #f1f1f1;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_80b92018_0f70_11ea_895c_000acd2bfab2row3_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_80b92018_0f70_11ea_895c_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CLB</th>        <th class="col_heading level0 col1" >adj</th>        <th class="col_heading level0 col2" >adv</th>        <th class="col_heading level0 col3" >det</th>        <th class="col_heading level0 col4" >fork</th>        <th class="col_heading level0 col5" >henv</th>        <th class="col_heading level0 col6" >inte</th>        <th class="col

# %%
cbefore = pd.concat([collbefore[x] for x in collbefore], axis=1, sort=False)

# %%
cafter = pd.concat([collafter[x] for x in collafter], axis=1, sort=False)

# %%
mdprint??

# %%
klassifikasjon??

# %%
cbefore['weight'].fillna(0).mean(axis=1)
# Out:
# den                      7.466282
# de                       5.055027
# med                      3.107620
# og                       1.780477
# det                      2.442429
# en                       5.893974
# ,                        0.945440
# et                       6.784944
# mine                     2.297322
# De                       1.882372
# sitt                     2.939060
# sine                     1.931839
# sin                      1.768515
# dette                    0.708465
# Med                      4.026664
# slags                    4.841230
# om                       0.172595
# neglespreng,             0.000000
# minnet                   1.532123
# Den                      4.018852
# hennes                   3.539373
# gamlingen               14.860463
# for                      0.757849
# Andras                   0.000000
# enn                      0.468415
# eneste                   5.224934
# Marguerites              0.000000
# e                        0.066622
# utvilsomt                3.272960
# mest                    17.489790
#                           ...
# utføre                   0.412997
# rapporteres              6.052930
# utgitt                   0.661424
# overholde                5.632615
# derav                    1.024514
# datamaskinutskriften     0.000000
# bl.a                     7.332855
# besvarer                10.957546
# beskriver                0.536570
# belyse                   1.457221
# avleverte                0.000000
# Westerby                 0.000000
# Vietnam                  2.266681
# Tallinn                  0.000000
# Pop                      0.000000
# Kna                      0.000000
# Hvorpå                   0.000000
# Husk                     0.862837
# Helsinki                 3.628036
# Haven                    3.423643
# kildene                  2.163867
# innløp                  12.825661
# husk                     1.938620
# 60                       0.073789
# herved                   1.456791
# gir                      0.036711
# føyer                    5.363742
# frembragte              10.463615
# foreligger               0.310694
# åpenbarte                6.702383
# Length: 4815, dtype: float64

# %%
nb.word_form('med')
# Out:
# ['prep normert',
#  'subst nøyt appell ent ub normert',
#  'subst nøyt appell fl ub normert']

# %%
cbefore['0'].fillna(0).sum(axis=1)
# Out:
# ,                      7.904453
# Ayla                   0.013117
# Barlow                 0.005829
# Becky                  0.012051
# Bernardos              0.004184
# Blythe                 0.029445
# Brett                  0.004184
# Bruno                  0.007169
# Burger                 0.004184
# Chabris                0.004184
# Chris                  0.020176
# Crane                  0.004733
# Den                    0.826543
# Det                    0.310625
# En                     0.590799
# George                 0.008963
# Graveren               0.020695
# Gustafs                0.004184
# Heiden                 0.004184
# Jo                     0.006768
# Jupiter                0.006697
# Kjærlighetsprofeten    0.010357
# Leona                  0.004733
# Lucy                   0.028117
# Macklin                0.005829
# Manfred                0.011876
# Marcel                 0.004184
# Murdstone              0.012552
# Pinnie                 0.004184
# Rick                   0.004184
#                          ...
# neglespreng,           0.007634
# Grigorjevas            0.005747
# Hollandes              0.005747
# Partridges             0.005747
# Vei                    0.005747
# Vel                    0.017241
# dedre                  0.005747
# eierens                0.005747
# fulle                  0.011494
# intimt                 0.005747
# kones                  0.005747
# myndigheters           0.005747
# nikka                  0.011494
# styrets                0.005747
# tilfreds               0.005747
# Abigails               0.007576
# Graffitiens            0.007576
# Pats                   0.007576
# Whitehalls             0.007576
# ereksjon               0.007576
# hurtig                 0.015152
# revolusjonens          0.007576
# suiten                 0.007576
# Eleni                  0.006369
# derfor                 0.006369
# eksempel               0.006369
# nærheten               0.006369
# paradiset              0.006369
# steds                  0.006369
# åndsfra                0.006369
# Length: 4815, dtype: float64

# %%
th_props = [
  ('font-size', '18px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#6d6d6d'),
  ('background-color', '#f7ffff')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
  ('font-size', '18px')
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# %%
df = klassifikasjon(nb.frame(cbefore['0'].fillna(0).mean(axis=1)))

# %%
df.style.set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_ac579c3a_10af_11ea_bfc6_000acd2bfab2 th {
#           font-size: 18px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7ffff;
#     }    #T_ac579c3a_10af_11ea_bfc6_000acd2bfab2 td {
#           font-size: 18px;
#     }</style><table id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >det</th>        <th class="col_heading level0 col1" >ukjent</th>        <th class="col_heading level0 col2" >CLB</th>        <th class="col_heading level0 col3" >verb</th>        <th class="col_heading level0 col4" >prep</th>        <th class="col_heading level0 col5" >pron</th>        <th class="col_heading level0 col6" >adj</th>        <th class="col_heading level0 col7" >subst</th>        <th class="col_heading level0 col8" >sbu</th>        <th class="col_heading level0 col9" >adv</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row0_col0" class="data row0 col0" >en</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row0_col1" class="data row0 col1" >,</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row0_col2" class="data row0 col2" >og</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row0_col3" class="data row0 col3" >så</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row0_col4" class="data row0 col4" >de</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row0_col5" class="data row0 col5" >han</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row0_col6" class="data row0 col6" >mer</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row0_col7" class="data row0 col7" >nesten</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row0_col8" class="data row0 col8" >som</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row0_col9" class="data row0 col9" >ganske</td>
#             </tr>
#             <tr>
#                         <th id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row1_col0" class="data row1 col0" >den</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row1_col1" class="data row1 col1" >Den</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row1_col2" class="data row1 col2" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row1_col3" class="data row1 col3" >kom</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row1_col4" class="data row1 col4" >med</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row1_col5" class="data row1 col5" >seg</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row1_col6" class="data row1 col6" >mest</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row1_col7" class="data row1 col7" >ikke</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row1_col8" class="data row1 col8" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row1_col9" class="data row1 col9" >hvor</td>
#             </tr>
#             <tr>
#                         <th id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row2_col0" class="data row2 col0" >et</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row2_col1" class="data row2 col1" >En</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row2_col2" class="data row2 col2" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row2_col3" class="data row2 col3" >var</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row2_col4" class="data row2 col4" >av</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row2_col5" class="data row2 col5" >hun</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row2_col6" class="data row2 col6" >særlig</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row2_col7" class="data row2 col7" >vel</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row2_col8" class="data row2 col8" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row2_col9" class="data row2 col9" ></td>
#             </tr>
#             <tr>
#                         <th id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row3_col0" class="data row3 col0" >det</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row3_col1" class="data row3 col1" >De</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row3_col2" class="data row3 col2" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row3_col3" class="data row3 col3" >ble</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row3_col4" class="data row3 col4" >for</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row3_col5" class="data row3 col5" >jeg</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row3_col6" class="data row3 col6" >svært</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row3_col7" class="data row3 col7" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row3_col8" class="data row3 col8" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row3_col9" class="data row3 col9" ></td>
#             </tr>
#             <tr>
#                         <th id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row4_col0" class="data row4 col0" >noe</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row4_col1" class="data row4 col1" >Det</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row4_col2" class="data row4 col2" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row4_col3" class="data row4 col3" >er</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row4_col4" class="data row4 col4" >i</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row4_col5" class="data row4 col5" >denne</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row4_col6" class="data row4 col6" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row4_col7" class="data row4 col7" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row4_col8" class="data row4 col8" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row4_col9" class="data row4 col9" ></td>
#             </tr>
#             <tr>
#                         <th id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row5_col0" class="data row5 col0" >noen</td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row5_col1" class="data row5 col1" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row5_col2" class="data row5 col2" ></td>
#                         <td id="T_ac579c3a_10af_11ea_bfc6_000acd2bfab2row5_col3"

# %%
klassifikasjon(nb.frame(cafter[0].fillna(0).mean(axis=1)))
# Out:
#    ukjent     prep CLB    subst  sbu     verb    adv det  adj
# 0       .       på  og    blikk  som     øyne     at  en  våt
# 1       ,        i      blikket        stemme     da
# 2       :       ut       øynene             å    nok
# 3       ?      til        lyset          smil  igjen
# 4       !      inn      stemmen          måte
# 5       -      mot        lyden           var
# 6              med       vinden           ord
# 7              fra                       mann
# 8              for                       tone
# 9               av                    uttrykk
# 10            over                        lyd
# 11             opp                       varm
# 12              om                        lys
# 13             ved                      eller
# 14             ned                     skritt
# 15             enn
# 16             der
# 17           rundt
# 18         nedover
# 19           etter
# 20         tilbake
# 21             her
# 22            bort
# 23         gjennom

# %%
klassifikasjon(nb.frame(cbefore['weight'].fillna(0).mean(axis=1)))
# Out:
#            ukjent      verb        subst          adj    adv
# 0             Sue   knurret     skjerfet     moderlig  høyst
# 1          Franks   smattet        røken         hese
# 2         Manfred  plystret     blyanten    overdådig
# 3         Stephan   kretset       tårene    tordnende
# 4        Jondalar   stirret     krøllene      endeløs
# 5            Gage    humret         tåka      ytterst
# 6             Abe     smule  øyenbrynene       dovent
# 7            Toby    rystet     panikken  hensynsløst
# 8             Pat   flakset        harer      rytmisk
# 9           Candy       pep       barmen
# 10         pikens   smekket   høvdingene
# 11        Ytterst     dunke
# 12      Stephanie
# 13          Vicky
# 14       jentenes
# 15       Virkelig
# 16         Lørdag
# 17          Kathy
# 18         Pavens
# 19         Sharon
# 20         Rodney
# 21          Becky
# 22  revolusjonens
# 23           Ayla
# 24         Gerard
# 25        Aldeles
# 26           Tala

# %%
nb.urn_concordance(word='knurret', urns=nb.pure_urn(korpus))
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015082548139?searchText=knurret' target='_blank' style='text-decoration:none'>Exorcisten - djevleutdriveren, Blatty, William Peter, 1974</a>
#                 </td>
#                 <td>igjen . Forpulte ransmenn ,</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>han og drakk .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015082548139?searchText=knurret' target='_blank' style='text-decoration:none'>Exorcisten - djevleutdriveren, Blatty, William Peter, 1974</a>
#                 </td>
#                 <td>Ja , bare le ,</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>detektiven , men så smilte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015082548139?searchText=knurret' target='_blank' style='text-decoration:none'>Exorcisten - djevleutdriveren, Blatty, William Peter, 1974</a>
#                 </td>
#                 <td>er ingen som har ,</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>Dyer og rynket pannen mismodig</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015082548139?searchText=knurret' target='_blank' style='text-decoration:none'>Exorcisten - djevleutdriveren, Blatty, William Peter, 1974</a>
#                 </td>
#                 <td>ut herfrå , Joe ,</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>Karras og knuste sigaretten sin</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015082548139?searchText=knurret' target='_blank' style='text-decoration:none'>Exorcisten - djevleutdriveren, Blatty, William Peter, 1974</a>
#                 </td>
#                 <td>— En djevel ,</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>demonen .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012062806124?searchText=knurret' target='_blank' style='text-decoration:none'>Amys øyne, Kennedy, Richard, 1989</a>
#                 </td>
#                 <td>med lange bein . Han</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>da Amys far stod ved</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012062806124?searchText=knurret' target='_blank' style='text-decoration:none'>Amys øyne, Kennedy, Richard, 1989</a>
#                 </td>
#                 <td>da den nærmet seg og</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>, så stakk den snuta</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012062806124?searchText=knurret' target='_blank' style='text-decoration:none'>Amys øyne, Kennedy, Richard, 1989</a>
#                 </td>
#                 <td>side til side mens den</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>dypt og mye høyere nå</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012062806124?searchText=knurret' target='_blank' style='text-decoration:none'>Amys øyne, Kennedy, Richard, 1989</a>
#                 </td>
#                 <td>« Argghhhh , »</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>Davy . « Nei .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012062806124?searchText=knurret' target='_blank' style='text-decoration:none'>Amys øyne, Kennedy, Richard, 1989</a>
#                 </td>
#                 <td>deg av sted , »</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>Mister Cloud , « kom</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013012907209?searchText=knurret' target='_blank' style='text-decoration:none'>Gulldrømmen, Himes, Chester, 1979</a>
#                 </td>
#                 <td>å ta en risk ,</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>Rufus da han underskrev .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011022320037?searchText=knurret' target='_blank' style='text-decoration:none'>Ser deg siden, Sam, Brown, Carter, 1981</a>
#                 </td>
#                 <td>. — All right ,</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>han . — Men du</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011022320037?searchText=knurret' target='_blank' style='text-decoration:none'>Ser deg siden, Sam, Brown, Carter, 1981</a>
#                 </td>
#                 <td>etter . — OK ,</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>jeg . — Hvor stor</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015071308123?searchText=knurret' target='_blank' style='text-decoration:none'>Kanonene på Navarone, MacLean, Alistair, 1981</a>
#                 </td>
#                 <td>kaller for løgner , »</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>Miller . « Vi så</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015071308123?searchText=knurret' target='_blank' style='text-decoration:none'>Kanonene på Navarone, MacLean, Alistair, 1981</a>
#                 </td>
#                 <td>. - ene , »</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>Brown . « Lunefulle som</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015071308123?searchText=knurret' target='_blank' style='text-decoration:none'>Kanonene på Navarone, MacLean, Alistair, 1981</a>
#                 </td>
#                 <td>kjeft , gutt ! »</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>Miller .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015071308123?searchText=knurret' target='_blank' style='text-decoration:none'>Kanonene på Navarone, MacLean, Alistair, 1981</a>
#                 </td>
#                 <td>budskap og testamente . »</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>Miller . « Det er</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015071308123?searchText=knurret' target='_blank' style='text-decoration:none'>Kanonene på Navarone, MacLean, Alistair, 1981</a>
#                 </td>
#                 <td>kassen hit seiv , »</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>Miller . Skuffelsen over Mallory</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012011706054?searchText=knurret' target='_blank' style='text-decoration:none'>Nytt fra savannen, Achebe, Chinua, 1988</a>
#                 </td>
#                 <td>Bikkjene</td>
#                 <td>knurret</td>
#                 <td style='text-align:left'>mens de rev ham i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012011706054?searchText=knurret' targe

# %%
mdprint(cbefore[0].fillna(0).mean(axis=1).sort_values(ascending=False)[:50], cutoff=0)
# Out:
# ## Egennavn
# ,, Den, En, De
# ## verb
# en, så, et, kom, var, ble, seg, er, for, bli, litt, komme, stirret, meget, like, virket, smilte, sin, lite, kommer, være, sa, to
# ## pron
# den, de, det, han, denne
# ## CLB
# og
# ## subst
# med, hun, i, jeg, nesten, ikke, ham
# ## fork
# av
# ## adj
# mer, mest, særlig
# ## det
# noe, noen, hans
# ## sbu
# som
# ## prep
# på, til

# %%
mdprint(collbefore['smilende'].sort_values(by='weight', ascending=False)['weight'][:50], 0)
# Out:
# ## Egennavn
# Jondalar, Isabella, Hilary, Candy, Harding, Evan, Weber, Turner, Esther, Ursula, Sharon, Mørke, Leslie, Madeleine, Silver, Mason, Andrew, Wilson, Gunn, Jerry, Monica, K2N, Johns, Fremdeles, Jane, Nan, Alltid, Anderson, Lucy
# ## adj
# forventningsfullt, idyllisk, kynisk, tappert, hånlig, herlige
# ## verb
# kikka, rystet, flaut, hilste, ristet, sjenert, skottet, tilføyde, tittet, nikket
# ## subst
# guvernøren, politimesteren, obersten, halvt
# ## unknown
# halweis

# %%
mdprint(collafter['smilende'].sort_values(by='weight', ascending=False)['weight'][:50], cutoff=0)
# Out:
# ## Egennavn
# Rudi, Schiller, Buddha, Hamilton, Berthe
# ## subst
# fjes, kjempen, øyebrynene, nonne, løytnanten, besluttsomhet, honnør, ansikter, tiger, lepper, gudinne, fasade, ansiktene, majoren, nazistene, demonstrasjon, boller, ansikt, masken, knute, tilskuere, ironi, portrett, hilsen, undring, nysgjerrighet, pakken, fjeset, piken, dåmen, naboer, forvirring, ansiktet
# ## verb
# klovn, hekser, fyrer, forakt, munn, maske, hopper
# ## unknown
# gjenkjennelse, tjenestepike
# ## adj
# hjelpsom, hebraiske, muntert

# %%
import pandas as pd
import networkx as nx
import graph_networkx_louvain as gnl

# %%
def coll_array_to_df(coll, column):
    df_colls = pd.DataFrame()
    for x in coll:
        df_colls[x] = coll[x][column]
    return df_colls
    
def coll_to_graph(df_colls, limit = 1000):
    df_colls = df_colls.fillna(0)
    cross = df_colls.transpose().dot(df_colls).stack()
    edges = []
    for x in cross.index:
        if x[0] != x[1] and cross[x] > limit:
            edges.append((x[0], x[1], cross[x]))
    G = nx.Graph()
    G.add_weighted_edges_from(edges)
    return G

# %%
df_colls = coll_array_to_df(collafter,'weight')

# %%
df_colls.sort_values(by='styrtende', ascending=False).head(10)

# %%
velg_form('meget')
# Out:
# 'verb'

# %%
nb.word_form('meget')
# Out:
# ['adv normert',
#  'subst mask appell ent ub normert',
#  'subst mask appell fl ub normert',
#  'adj <perf-part> m/f ub ent <intrans1> normert',
#  'adj <perf-part> nøyt ub ent <intrans1> normert',
#  'verb perf-part <intrans1> normert']

# %%
df_colls = coll_array_to_df(collafter, 'weight')

# %%
G = coll_to_graph(df_colls)

# %%
gnl.show_graph(G, spread=4)

# %%
gnl.show_communities(G)

# %%
df_before = coll_array_to_df(collbefore, 'weight')

# %%
Gb = coll_to_graph(df_before, limit=500)

# %%
gnl.show_graph(Gb, spread=0.6);

# %%
gnl.show_communities(Gb)
